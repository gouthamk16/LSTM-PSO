# %%
# !pip install --upgrade mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mplfinance) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mplfinance) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mplfinance) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.10b0

# %%
import numpy as np
import pandas as pd
import math
import random
import datetime as dt
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
from mplfinance.original_flavor import candlestick_ohlc
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import metrics
from sklearn.metrics import mean_squared_error
import yfinance as yf
# Out:
# /usr/local/lib/python3.10/dist-packages/yfinance/base.py:48: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _empty_series = pd.Series()

# %%
# Downloading stock data for American Express Company (AXP) from Yahoo Finance
stock_data = yf.download('AXP', start='2020-01-01', end='2024-01-01')
specific_df = pd.DataFrame(stock_data).reset_index()
specific_df['Name'] = 'AAPL'
print(specific_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2020-01-02  124.660004  126.269997  124.230003  125.849998  118.922508
# 1 2020-01-03  124.320000  125.099998  123.940002  124.599998  117.741325
# 2 2020-01-06  123.370003  124.160004  123.120003  124.059998  117.231033
# 3 2020-01-07  123.470001  124.400002  123.360001  123.410004  116.616837
# 4 2020-01-08  124.050003  126.360001  123.800003  125.540001  118.629601
#
#     Volume  Name
# 0  2708000  AAPL
# 1  2090600  AAPL
# 2  2855200  AAPL
# 3  2042300  AAPL
# 4  3458200  AAPL

# %%
plt.figure(figsize=(15,6))
plt.plot(specific_df['Date'], specific_df['Close'], marker='.')
plt.title('Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
matplotlib_date = mdates.date2num(specific_df['Date'])
ohlc = np.vstack((matplotlib_date, specific_df['Open'], specific_df['High'], specific_df['Low'], specific_df['Close'])).T
plt.figure(figsize=(15,6))
ax=plt.subplot()
candlestick_ohlc(ax, ohlc, width=0.6, colorup='g', colordown='r')
ax.xaxis_date()
plt.title('Candlestick Chart')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
window = 30
plt.figure(figsize=(15,6))
plt.plot(specific_df['Date'], specific_df['Close'], label='Closing Price', linewidth=2)
plt.plot(specific_df['Date'], specific_df['Close'].rolling(window=window).mean(), label=f'{window}-Day Moving Avg', linestyle='--')
plt.title(f'Closing Prices and {window}-Day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %%
company_name = 'AXP'
specific_df['Month'] = specific_df['Date'].dt.month
monthly_average = specific_df.groupby('Month')['Close'].mean()

plt.figure(figsize=(15,6))
plt.plot(monthly_average.index, monthly_average.values, marker='o')
plt.title(f'Monthly Seasonality of {company_name}')
plt.xlabel('Months')
plt.ylabel('Average Closing Price')
plt.xticks(range(1,13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %%
new_df = specific_df.reset_index()['Close']
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(np.array(new_df).reshape(-1,1))

# %%
from sklearn.model_selection import train_test_split
test_size = 0.2
train_data, test_data = train_test_split(scaled_data, test_size=test_size, shuffle=False)

# %%
def generate_sequences_and_labels(data, n_past):
    sequences = [data[i - n_past:i, 0] for i in range(n_past, len(data))]
    labels = [data[i, 0] for i in range(n_past, len(data))]
    return np.array(sequences), np.array(labels)

# %%
n_past = 60
x_train, y_train = generate_sequences_and_labels(train_data, n_past)
x_test, y_test = generate_sequences_and_labels(test_data, n_past)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=[input_shape, 1]))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    return model

# %%
def compile_lstm_model(model):
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
def train_lstm_model(model, x_train, y_train, x_test, y_test):
    model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=300, batch_size=32, verbose=1)

# %%
model = build_lstm_model(x_train.shape[1])
compile_lstm_model(model)
train_lstm_model(model, x_train, y_train, x_test, y_test)
# Out:
# Epoch 1/300
# 24/24 [==============================] - 9s 62ms/step - loss: 0.0762 - mean_absolute_error: 0.2082 - val_loss: 0.0043 - val_mean_absolute_error: 0.0546
# Epoch 2/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0147 - mean_absolute_error: 0.0994 - val_loss: 0.0048 - val_mean_absolute_error: 0.0594
# Epoch 3/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0105 - mean_absolute_error: 0.0812 - val_loss: 0.0038 - val_mean_absolute_error: 0.0524
# Epoch 4/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0089 - mean_absolute_error: 0.0731 - val_loss: 0.0044 - val_mean_absolute_error: 0.0524
# Epoch 5/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0078 - mean_absolute_error: 0.0685 - val_loss: 0.0048 - val_mean_absolute_error: 0.0534
# Epoch 6/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0073 - mean_absolute_error: 0.0656 - val_loss: 0.0036 - val_mean_absolute_error: 0.0517
# Epoch 7/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0071 - mean_absolute_error: 0.0646 - val_loss: 0.0047 - val_mean_absolute_error: 0.0593
# Epoch 8/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0073 - mean_absolute_error: 0.0659 - val_loss: 0.0032 - val_mean_absolute_error: 0.0473
# Epoch 9/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0075 - mean_absolute_error: 0.0667 - val_loss: 0.0034 - val_mean_absolute_error: 0.0469
# Epoch 10/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0071 - mean_absolute_error: 0.0644 - val_loss: 0.0037 - val_mean_absolute_error: 0.0480
# Epoch 11/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0072 - mean_absolute_error: 0.0650 - val_loss: 0.0047 - val_mean_absolute_error: 0.0533
# Epoch 12/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0062 - mean_absolute_error: 0.0611 - val_loss: 0.0033 - val_mean_absolute_error: 0.0456
# Epoch 13/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0060 - mean_absolute_error: 0.0604 - val_loss: 0.0041 - val_mean_absolute_error: 0.0497
# Epoch 14/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0064 - mean_absolute_error: 0.0616 - val_loss: 0.0037 - val_mean_absolute_error: 0.0476
# Epoch 15/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0070 - mean_absolute_error: 0.0649 - val_loss: 0.0027 - val_mean_absolute_error: 0.0447
# Epoch 16/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0066 - mean_absolute_error: 0.0629 - val_loss: 0.0027 - val_mean_absolute_error: 0.0430
# Epoch 17/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0062 - mean_absolute_error: 0.0596 - val_loss: 0.0027 - val_mean_absolute_error: 0.0424
# Epoch 18/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0063 - mean_absolute_error: 0.0618 - val_loss: 0.0030 - val_mean_absolute_error: 0.0433
# Epoch 19/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0060 - mean_absolute_error: 0.0607 - val_loss: 0.0032 - val_mean_absolute_error: 0.0442
# Epoch 20/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0057 - mean_absolute_error: 0.0579 - val_loss: 0.0028 - val_mean_absolute_error: 0.0419
# Epoch 21/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0060 - mean_absolute_error: 0.0607 - val_loss: 0.0024 - val_mean_absolute_error: 0.0399
# Epoch 22/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0061 - mean_absolute_error: 0.0598 - val_loss: 0.0049 - val_mean_absolute_error: 0.0568
# Epoch 23/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0063 - mean_absolute_error: 0.0601 - val_loss: 0.0022 - val_mean_absolute_error: 0.0394
# Epoch 24/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0066 - mean_absolute_error: 0.0635 - val_loss: 0.0055 - val_mean_absolute_error: 0.0609
# Epoch 25/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0065 - mean_absolute_error: 0.0623 - val_loss: 0.0021 - val_mean_absolute_error: 0.0387
# Epoch 26/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0057 - mean_absolute_error: 0.0573 - val_loss: 0.0023 - val_mean_absolute_error: 0.0381
# Epoch 27/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0056 - mean_absolute_error: 0.0567 - val_loss: 0.0034 - val_mean_absolute_error: 0.0466
# Epoch 28/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0053 - mean_absolute_error: 0.0547 - val_loss: 0.0020 - val_mean_absolute_error: 0.0366
# Epoch 29/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0057 - mean_absolute_error: 0.0587 - val_loss: 0.0065 - val_mean_absolute_error: 0.0688
# Epoch 30/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0060 - mean_absolute_error: 0.0605 - val_loss: 0.0037 - val_mean_absolute_error: 0.0496
# Epoch 31/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0055 - mean_absolute_error: 0.0552 - val_loss: 0.0020 - val_mean_absolute_error: 0.0362
# Epoch 32/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0052 - mean_absolute_error: 0.0542 - val_loss: 0.0018 - val_mean_absolute_error: 0.0346
# Epoch 33/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0052 - mean_absolute_error: 0.0552 - val_loss: 0.0018 - val_mean_absolute_error: 0.0357
# Epoch 34/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0051 - mean_absolute_error: 0.0547 - val_loss: 0.0021 - val_mean_absolute_error: 0.0369
# Epoch 35/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0051 - mean_absolute_error: 0.0550 - val_loss: 0.0019 - val_mean_absolute_error: 0.0371
# Epoch 36/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0058 - mean_absolute_error: 0.0592 - val_loss: 0.0040 - val_mean_absolute_error: 0.0532
# Epoch 37/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0053 - mean_absolute_error: 0.0561 - val_loss: 0.0017 - val_mean_absolute_error: 0.0343
# Epoch 38/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0046 - mean_absolute_error: 0.0517 - val_loss: 0.0024 - val_mean_absolute_error: 0.0396
# Epoch 39/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0051 - mean_absolute_error: 0.0541 - val_loss: 0.0022 - val_mean_absolute_error: 0.0369
# Epoch 40/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0045 - mean_absolute_error: 0.0505 - val_loss: 0.0033 - val_mean_absolute_error: 0.0475
# Epoch 41/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0058 - mean_absolute_error: 0.0590 - val_loss: 0.0040 - val_mean_absolute_error: 0.0530
# Epoch 42/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0050 - mean_absolute_error: 0.0542 - val_loss: 0.0065 - val_mean_absolute_error: 0.0702
# Epoch 43/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0053 - mean_absolute_error: 0.0568 - val_loss: 0.0021 - val_mean_absolute_error: 0.0367
# Epoch 44/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0043 - mean_absolute_error: 0.0509 - val_loss: 0.0016 - val_mean_absolute_error: 0.0325
# Epoch 45/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0045 - mean_absolute_error: 0.0515 - val_loss: 0.0015 - val_mean_absolute_error: 0.0319
# Epoch 46/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0043 - mean_absolute_error: 0.0495 - val_loss: 0.0013 - val_mean_absolute_error: 0.0303
# Epoch 47/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0048 - mean_absolute_error: 0.0532 - val_loss: 0.0015 - val_mean_absolute_error: 0.0309
# Epoch 48/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0043 - mean_absolute_error: 0.0502 - val_loss: 0.0014 - val_mean_absolute_error: 0.0309
# Epoch 49/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0041 - mean_absolute_error: 0.0491 - val_loss: 0.0028 - val_mean_absolute_error: 0.0440
# Epoch 50/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0047 - mean_absolute_error: 0.0528 - val_loss: 0.0019 - val_mean_absolute_error: 0.0352
# Epoch 51/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0047 - mean_absolute_error: 0.0536 - val_loss: 0.0013 - val_mean_absolute_error: 0.0291
# Epoch 52/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0038 - mean_absolute_error: 0.0471 - val_loss: 0.0018 - val_mean_absolute_error: 0.0345
# Epoch 53/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0037 - mean_absolute_error: 0.0472 - val_loss: 0.0012 - val_mean_absolute_error: 0.0284
# Epoch 54/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0042 - mean_absolute_error: 0.0500 - val_loss: 0.0012 - val_mean_absolute_error: 0.0278
# Epoch 55/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0042 - mean_absolute_error: 0.0500 - val_loss: 0.0012 - val_mean_absolute_error: 0.0282
# Epoch 56/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0038 - mean_absolute_error: 0.0465 - val_loss: 0.0011 - val_mean_absolute_error: 0.0271
# Epoch 57/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0039 - mean_absolute_error: 0.0482 - val_loss: 0.0013 - val_mean_absolute_error: 0.0294
# Epoch 58/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0038 - mean_absolute_error: 0.0481 - val_loss: 0.0016 - val_mean_absolute_error: 0.0318
# Epoch 59/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0036 - mean_absolute_error: 0.0458 - val_loss: 0.0012 - val_mean_absolute_error: 0.0273
# Epoch 60/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0037 - mean_absolute_error: 0.0473 - val_loss: 0.0018 - val_mean_absolute_error: 0.0336
# Epoch 61/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0038 - mean_absolute_error: 0.0476 - val_loss: 0.0013 - val_mean_absolute_error: 0.0287
# Epoch 62/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0034 - mean_absolute_error: 0.0459 - val_loss: 0.0010 - val_mean_absolute_error: 0.0259
# Epoch 63/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0035 - mean_absolute_error: 0.0456 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 64/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0036 - mean_absolute_error: 0.0463 - val_loss: 0.0010 - val_mean_absolute_error: 0.0257
# Epoch 65/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0038 - mean_absolute_error: 0.0474 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 66/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0034 - mean_absolute_error: 0.0444 - val_loss: 9.8574e-04 - val_mean_absolute_error: 0.0254
# Epoch 67/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0032 - mean_absolute_error: 0.0436 - val_loss: 0.0011 - val_mean_absolute_error: 0.0260
# Epoch 68/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0033 - mean_absolute_error: 0.0442 - val_loss: 9.4169e-04 - val_mean_absolute_error: 0.0246
# Epoch 69/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0032 - mean_absolute_error: 0.0433 - val_loss: 0.0013 - val_mean_absolute_error: 0.0292
# Epoch 70/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0033 - mean_absolute_error: 0.0449 - val_loss: 0.0019 - val_mean_absolute_error: 0.0349
# Epoch 71/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0033 - mean_absolute_error: 0.0435 - val_loss: 9.7368e-04 - val_mean_absolute_error: 0.0249
# Epoch 72/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0029 - mean_absolute_error: 0.0418 - val_loss: 9.4190e-04 - val_mean_absolute_error: 0.0248
# Epoch 73/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0034 - mean_absolute_error: 0.0446 - val_loss: 9.0756e-04 - val_mean_absolute_error: 0.0242
# Epoch 74/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0032 - mean_absolute_error: 0.0429 - val_loss: 9.7972e-04 - val_mean_absolute_error: 0.0253
# Epoch 75/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0032 - mean_absolute_error: 0.0444 - val_loss: 0.0015 - val_mean_absolute_error: 0.0323
# Epoch 76/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0033 - mean_absolute_error: 0.0446 - val_loss: 9.2750e-04 - val_mean_absolute_error: 0.0248
# Epoch 77/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0032 - mean_absolute_error: 0.0428 - val_loss: 9.4953e-04 - val_mean_absolute_error: 0.0247
# Epoch 78/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0029 - mean_absolute_error: 0.0424 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265
# Epoch 79/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0034 - mean_absolute_error: 0.0444 - val_loss: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 80/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0029 - mean_absolute_error: 0.0412 - val_loss: 9.0693e-04 - val_mean_absolute_error: 0.0245
# Epoch 81/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0031 - mean_absolute_error: 0.0434 - val_loss: 9.1909e-04 - val_mean_absolute_error: 0.0238
# Epoch 82/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0028 - mean_absolute_error: 0.0409 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
# Epoch 83/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0427 - val_loss: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 84/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0029 - mean_absolute_error: 0.0417 - val_loss: 7.7844e-04 - val_mean_absolute_error: 0.0223
# Epoch 85/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0031 - mean_absolute_error: 0.0424 - val_loss: 0.0010 - val_mean_absolute_error: 0.0263
# Epoch 86/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0426 - val_loss: 8.1259e-04 - val_mean_absolute_error: 0.0227
# Epoch 87/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0031 - mean_absolute_error: 0.0421 - val_loss: 0.0012 - val_mean_absolute_error: 0.0282
# Epoch 88/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0422 - val_loss: 8.0070e-04 - val_mean_absolute_error: 0.0226
# Epoch 89/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0028 - mean_absolute_error: 0.0407 - val_loss: 7.6064e-04 - val_mean_absolute_error: 0.0220
# Epoch 90/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0427 - val_loss: 7.5110e-04 - val_mean_absolute_error: 0.0219
# Epoch 91/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0028 - mean_absolute_error: 0.0410 - val_loss: 0.0010 - val_mean_absolute_error: 0.0251
# Epoch 92/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0027 - mean_absolute_error: 0.0395 - val_loss: 8.6045e-04 - val_mean_absolute_error: 0.0239
# Epoch 93/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0028 - mean_absolute_error: 0.0402 - val_loss: 8.4370e-04 - val_mean_absolute_error: 0.0230
# Epoch 94/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0030 - mean_absolute_error: 0.0420 - val_loss: 0.0011 - val_mean_absolute_error: 0.0274
# Epoch 95/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0027 - mean_absolute_error: 0.0402 - val_loss: 0.0010 - val_mean_absolute_error: 0.0267
# Epoch 96/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0030 - mean_absolute_error: 0.0419 - val_loss: 7.4872e-04 - val_mean_absolute_error: 0.0223
# Epoch 97/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0025 - mean_absolute_error: 0.0385 - val_loss: 0.0012 - val_mean_absolute_error: 0.0286
# Epoch 98/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0026 - mean_absolute_error: 0.0399 - val_loss: 7.3983e-04 - val_mean_absolute_error: 0.0218
# Epoch 99/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0034 - mean_absolute_error: 0.0453 - val_loss: 0.0012 - val_mean_absolute_error: 0.0277
# Epoch 100/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0028 - mean_absolute_error: 0.0406 - val_loss: 7.1268e-04 - val_mean_absolute_error: 0.0216
# Epoch 101/300
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0028 - mean_absolute_error: 0.0408 - val_loss: 7.3442e-04 - val_mean_absolute_error: 0.0215
# Epoch 102/300
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0026 - mean_absolute_error: 0.0386 - val_loss: 6.6424e-04 - val_mean_absolute_error: 0.0208
# Epoch 103/300
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0024 - mean_absolute_error: 0.0381 - val_loss: 0.0012 - val_mean_absolute_error: 0.0281
# Epoch 104/300
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0028 - mean_absolute_error: 0.0403 - val_loss: 8.0109e-04 - val_mean_absolute_error: 0.0230
# Epoch 105/300
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0026 - mean_absolute_error: 0.0386 - val_loss: 6.8753e-04 - val_mean_absolute_error: 0.0212
# Epoch 106/300
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0024 - mean_absolute_error: 0.0378 - val_loss: 6.4326e-04 - val_mean_absolute_error: 0.0204
# Epoch 107/300
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0023 - mean_absolute_error: 0.0364 - val_loss: 8.2006e-04 - val_mean_absolute_error: 0.0227
# Epoch 108/300
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0026 - mean_absolute_error: 0.0398 - val_loss: 7.0924e-04 - val_mean_absolute_error: 0.0214
# Epoch 109/300
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0026 - mean_absolute_error: 0.0388 - val_loss: 6.8365e-04 - val_mean_absolute_error: 0.0211
# Epoch 110/300
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0025 - mean_absolute_error: 0.0387 - val_loss: 6.2092e-04 - val_mean_absolute_error: 0.0201
# Epoch 111/300
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0022 - mean_absolute_error: 0.0363 - val_loss: 8.2134e-04 - val_mean_absolute_error: 0.0235
# Epoch 112/300
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0027 - mean_absolute_error: 0.0399 - val_loss: 6.3056e-04 - val_mean_absolute_error: 0.0203
# Epoch 113/300
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0025 - mean_absolute_error: 0.0382 - val_loss: 7.1203e-04 - val_mean_absolute_error: 0.0214
# Epoch 114/300
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0023 - mean_absolute_error: 0.0373 - val_loss: 7.9534e-04 - val_mean_absolute_error: 0.0224
# Epoch 115/300
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0023 - mean_absolute_error: 0.0371 - val_loss: 7.3193e-04 - val_mean_absolute_error: 0.0218
# Epoch 116/300
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0024 - mean_absolute_error: 0.0378 - val_loss: 6.9008e-04 - val_mean_absolute_error: 0.0212
# Epoch 117/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0023 - mean_absolute_error: 0.0367 - val_loss: 9.1682e-04 - val_mean_absolute_error: 0.0241
# Epoch 118/300
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0025 - mean_absolute_error: 0.0377 - val_loss: 8.8857e-04 - val_mean_absolute_error: 0.0238
# Epoch 119/300
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0024 - mean_absolute_error: 0.0368 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 120/300
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0024 - mean_absolute_error: 0.0378 - val_loss: 8.1209e-04 - val_mean_absolute_error: 0.0226
# Epoch 121/300
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0024 - mean_absolute_error: 0.0380 - val_loss: 6.6740e-04 - val_mean_absolute_error: 0.0209
# Epoch 122/300
# 24/24 [==============================] - 1s 34ms/step - loss: 0.0022 - mean_absolute_error: 0.0358 - val_loss: 5.3625e-04 - val_mean_absolute_error: 0.0187
# Epoch 123/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0022 - mean_absolute_error: 0.0361 - val_loss: 5.6825e-04 - val_mean_absolute_error: 0.0194
# Epoch 124/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0022 - mean_absolute_error: 0.0358 - val_loss: 5.1453e-04 - val_mean_absolute_error: 0.0182
# Epoch 125/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0024 - mean_absolute_error: 0.0374 - val_loss: 8.8398e-04 - val_mean_absolute_error: 0.0236
# Epoch 126/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0023 - mean_absolute_error: 0.0374 - val_loss: 0.0010 - val_mean_absolute_error: 0.0263
# Epoch 127/300
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0025 - mean_absolute_error: 0.0380 - val_loss: 6.6589e-04 - val_mean_absolute_error: 0.0207
# Epoch 128/300
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0021 - mean_absolute_error: 0.0354 - val_loss: 5.3419e-04 - val_mean_absolute_error: 0.0189
# Epoch 129/300
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0020 - mean_absolute_error: 0.0349 - val_loss: 5.1148e-04 - val_mean_absolute_error: 0.0183
# Epoch 130/300
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0021 - mean_absolute_error: 0.0355 - val_loss: 5.0169e-04 - val_mean_absolute_error: 0.0181
# Epoch 131/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0022 - mean_absolute_error: 0.0357 - val_loss: 4.9949e-04 - val_mean_absolute_error: 0.0177
# Epoch 132/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0021 - mean_absolute_error: 0.0348 - val_loss: 9.8467e-04 - val_mean_absolute_error: 0.0254
# Epoch 133/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0353 - val_loss: 5.1483e-04 - val_mean_absolute_error: 0.0181
# Epoch 134/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0021 - mean_absolute_error: 0.0345 - val_loss: 0.0011 - val_mean_absolute_error: 0.0273
# Epoch 135/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0022 - mean_absolute_error: 0.0357 - val_loss: 5.3451e-04 - val_mean_absolute_error: 0.0188
# Epoch 136/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0340 - val_loss: 6.4699e-04 - val_mean_absolute_error: 0.0201
# Epoch 137/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0020 - mean_absolute_error: 0.0340 - val_loss: 5.1736e-04 - val_mean_absolute_error: 0.0178
# Epoch 138/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0326 - val_loss: 4.6877e-04 - val_mean_absolute_error: 0.0175
# Epoch 139/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0329 - val_loss: 0.0010 - val_mean_absolute_error: 0.0264
# Epoch 140/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0349 - val_loss: 9.0966e-04 - val_mean_absolute_error: 0.0246
# Epoch 141/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0340 - val_loss: 0.0012 - val_mean_absolute_error: 0.0293
# Epoch 142/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0339 - val_loss: 6.4449e-04 - val_mean_absolute_error: 0.0206
# Epoch 143/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0019 - mean_absolute_error: 0.0334 - val_loss: 4.5785e-04 - val_mean_absolute_error: 0.0171
# Epoch 144/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0331 - val_loss: 5.4614e-04 - val_mean_absolute_error: 0.0183
# Epoch 145/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0327 - val_loss: 6.8036e-04 - val_mean_absolute_error: 0.0209
# Epoch 146/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0340 - val_loss: 0.0014 - val_mean_absolute_error: 0.0312
# Epoch 147/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0331 - val_loss: 6.7539e-04 - val_mean_absolute_error: 0.0206
# Epoch 148/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0340 - val_loss: 4.3991e-04 - val_mean_absolute_error: 0.0165
# Epoch 149/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0340 - val_loss: 6.0561e-04 - val_mean_absolute_error: 0.0194
# Epoch 150/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0329 - val_loss: 4.3013e-04 - val_mean_absolute_error: 0.0165
# Epoch 151/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0332 - val_loss: 4.6313e-04 - val_mean_absolute_error: 0.0176
# Epoch 152/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0325 - val_loss: 6.7656e-04 - val_mean_absolute_error: 0.0212
# Epoch 153/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0338 - val_loss: 4.1192e-04 - val_mean_absolute_error: 0.0158
# Epoch 154/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0333 - val_loss: 7.3250e-04 - val_mean_absolute_error: 0.0217
# Epoch 155/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0322 - val_loss: 5.1717e-04 - val_mean_absolute_error: 0.0184
# Epoch 156/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0324 - val_loss: 5.1588e-04 - val_mean_absolute_error: 0.0183
# Epoch 157/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0314 - val_loss: 4.8674e-04 - val_mean_absolute_error: 0.0180
# Epoch 158/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0327 - val_loss: 6.7223e-04 - val_mean_absolute_error: 0.0210
# Epoch 159/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0340 - val_loss: 5.5777e-04 - val_mean_absolute_error: 0.0192
# Epoch 160/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0018 - mean_absolute_error: 0.0329 - val_loss: 4.3067e-04 - val_mean_absolute_error: 0.0168
# Epoch 161/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0325 - val_loss: 9.9092e-04 - val_mean_absolute_error: 0.0261
# Epoch 162/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0017 - mean_absolute_error: 0.0319 - val_loss: 4.0316e-04 - val_mean_absolute_error: 0.0161
# Epoch 163/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0016 - mean_absolute_error: 0.0310 - val_loss: 8.2736e-04 - val_mean_absolute_error: 0.0237
# Epoch 164/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0020 - mean_absolute_error: 0.0345 - val_loss: 4.3522e-04 - val_mean_absolute_error: 0.0162
# Epoch 165/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0327 - val_loss: 4.4915e-04 - val_mean_absolute_error: 0.0171
# Epoch 166/300
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0017 - mean_absolute_error: 0.0317 - val_loss: 4.0899e-04 - val_mean_absolute_error: 0.0162
# Epoch 167/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0313 - val_loss: 7.0392e-04 - val_mean_absolute_error: 0.0212
# Epoch 168/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0345 - val_loss: 4.1275e-04 - val_mean_absolute_error: 0.0162
# Epoch 169/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0325 - val_loss: 4.0359e-04 - val_mean_absolute_error: 0.0156
# Epoch 170/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0317 - val_loss: 4.1729e-04 - val_mean_absolute_error: 0.0165
# Epoch 171/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0308 - val_loss: 4.0008e-04 - val_mean_absolute_error: 0.0161
# Epoch 172/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0303 - val_loss: 7.3246e-04 - val_mean_absolute_error: 0.0221
# Epoch 173/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0319 - val_loss: 7.5956e-04 - val_mean_absolute_error: 0.0225
# Epoch 174/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0311 - val_loss: 4.7015e-04 - val_mean_absolute_error: 0.0175
# Epoch 175/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0016 - mean_absolute_error: 0.0311 - val_loss: 5.8061e-04 - val_mean_absolute_error: 0.0198
# Epoch 176/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0019 - mean_absolute_error: 0.0331 - val_loss: 4.5759e-04 - val_mean_absolute_error: 0.0168
# Epoch 177/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0298 - val_loss: 6.6720e-04 - val_mean_absolute_error: 0.0209
# Epoch 178/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0315 - val_loss: 9.0656e-04 - val_mean_absolute_error: 0.0254
# Epoch 179/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0311 - val_loss: 3.7566e-04 - val_mean_absolute_error: 0.0150
# Epoch 180/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0311 - val_loss: 4.3232e-04 - val_mean_absolute_error: 0.0162
# Epoch 181/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0299 - val_loss: 5.3380e-04 - val_mean_absolute_error: 0.0187
# Epoch 182/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0302 - val_loss: 3.9130e-04 - val_mean_absolute_error: 0.0159
# Epoch 183/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0299 - val_loss: 4.0493e-04 - val_mean_absolute_error: 0.0162
# Epoch 184/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0016 - mean_absolute_error: 0.0308 - val_loss: 0.0016 - val_mean_absolute_error: 0.0363
# Epoch 185/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0343 - val_loss: 7.0675e-04 - val_mean_absolute_error: 0.0219
# Epoch 186/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0313 - val_loss: 3.8047e-04 - val_mean_absolute_error: 0.0156
# Epoch 187/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0310 - val_loss: 3.9639e-04 - val_mean_absolute_error: 0.0159
# Epoch 188/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - val_loss: 3.5332e-04 - val_mean_absolute_error: 0.0144
# Epoch 189/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0016 - mean_absolute_error: 0.0291 - val_loss: 4.2632e-04 - val_mean_absolute_error: 0.0161
# Epoch 190/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0312 - val_loss: 4.0723e-04 - val_mean_absolute_error: 0.0156
# Epoch 191/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0016 - mean_absolute_error: 0.0310 - val_loss: 3.7952e-04 - val_mean_absolute_error: 0.0150
# Epoch 192/300
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0015 - mean_absolute_error: 0.0294 - val_loss: 3.9072e-04 - val_mean_absolute_error: 0.0152
# Epoch 193/300
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0015 - mean_absolute_error: 0.0290 - val_loss: 5.1664e-04 - val_mean_absolute_error: 0.0184
# Epoch 194/300
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0015 - mean_absolute_error: 0.0300 - val_loss: 5.7472e-04 - val_mean_absolute_error: 0.0197
# Epoch 195/300
# 24/24 [==============================] - 1s 39ms/step - loss: 0.0016 - mean_absolute_error: 0.0307 - val_loss: 4.4983e-04 - val_mean_absolute_error: 0.0172
# Epoch 196/300
# 24/24 [==============================] - 1s 47ms/step - loss: 0.0015 - mean_absolute_error: 0.0290 - val_loss: 6.1683e-04 - val_mean_absolute_error: 0.0198
# Epoch 197/300
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0015 - mean_absolute_error: 0.0303 - val_loss: 3.3389e-04 - val_mean_absolute_error: 0.0142
# Epoch 198/300
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0015 - mean_absolute_error: 0.0296 - val_loss: 3.5082e-04 - val_mean_absolute_error: 0.0149
# Epoch 199/300
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0015 - mean_absolute_error: 0.0285 - val_loss: 4.2895e-04 - val_mean_absolute_error: 0.0162
# Epoch 200/300
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0014 - mean_absolute_error: 0.0287 - val_loss: 3.9291e-04 - val_mean_absolute_error: 0.0155
# Epoch 201/300
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0015 - mean_absolute_error: 0.0293 - val_loss: 3.9462e-04 - val_mean_absolute_error: 0.0158
# Epoch 202/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0016 - mean_absolute_error: 0.0304 - val_loss: 8.1646e-04 - val_mean_absolute_error: 0.0242
# Epoch 203/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0310 - val_loss: 3.5853e-04 - val_mean_absolute_error: 0.0148
# Epoch 204/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0334 - val_loss: 3.3226e-04 - val_mean_absolute_error: 0.0141
# Epoch 205/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0293 - val_loss: 3.7955e-04 - val_mean_absolute_error: 0.0150
# Epoch 206/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0305 - val_loss: 3.4490e-04 - val_mean_absolute_error: 0.0143
# Epoch 207/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0015 - mean_absolute_error: 0.0298 - val_loss: 4.6757e-04 - val_mean_absolute_error: 0.0170
# Epoch 208/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0299 - val_loss: 7.7868e-04 - val_mean_absolute_error: 0.0229
# Epoch 209/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0316 - val_loss: 4.0874e-04 - val_mean_absolute_error: 0.0161
# Epoch 210/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0291 - val_loss: 4.2049e-04 - val_mean_absolute_error: 0.0164
# Epoch 211/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0292 - val_loss: 3.8789e-04 - val_mean_absolute_error: 0.0157
# Epoch 212/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0016 - mean_absolute_error: 0.0302 - val_loss: 3.9402e-04 - val_mean_absolute_error: 0.0157
# Epoch 213/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0301 - val_loss: 6.7572e-04 - val_mean_absolute_error: 0.0220
# Epoch 214/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0016 - mean_absolute_error: 0.0303 - val_loss: 8.1231e-04 - val_mean_absolute_error: 0.0245
# Epoch 215/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0291 - val_loss: 3.4708e-04 - val_mean_absolute_error: 0.0150
# Epoch 216/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0278 - val_loss: 5.0339e-04 - val_mean_absolute_error: 0.0186
# Epoch 217/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0283 - val_loss: 6.5881e-04 - val_mean_absolute_error: 0.0217
# Epoch 218/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0015 - mean_absolute_error: 0.0297 - val_loss: 8.1613e-04 - val_mean_absolute_error: 0.0241
# Epoch 219/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0283 - val_loss: 3.0399e-04 - val_mean_absolute_error: 0.0132
# Epoch 220/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0296 - val_loss: 3.4864e-04 - val_mean_absolute_error: 0.0144
# Epoch 221/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0287 - val_loss: 3.3753e-04 - val_mean_absolute_error: 0.0144
# Epoch 222/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0280 - val_loss: 2.9917e-04 - val_mean_absolute_error: 0.0131
# Epoch 223/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0014 - mean_absolute_error: 0.0283 - val_loss: 4.7002e-04 - val_mean_absolute_error: 0.0180
# Epoch 224/300
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0013 - mean_absolute_error: 0.0284 - val_loss: 2.9125e-04 - val_mean_absolute_error: 0.0129
# Epoch 225/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0012 - mean_absolute_error: 0.0270 - val_loss: 7.4994e-04 - val_mean_absolute_error: 0.0233
# Epoch 226/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0015 - mean_absolute_error: 0.0293 - val_loss: 3.5635e-04 - val_mean_absolute_error: 0.0144
# Epoch 227/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0281 - val_loss: 3.0387e-04 - val_mean_absolute_error: 0.0133
# Epoch 228/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0014 - mean_absolute_error: 0.0289 - val_loss: 2.9714e-04 - val_mean_absolute_error: 0.0130
# Epoch 229/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0014 - mean_absolute_error: 0.0281 - val_loss: 3.2203e-04 - val_mean_absolute_error: 0.0135
# Epoch 230/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0293 - val_loss: 4.0577e-04 - val_mean_absolute_error: 0.0164
# Epoch 231/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0285 - val_loss: 3.2688e-04 - val_mean_absolute_error: 0.0135
# Epoch 232/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0275 - val_loss: 4.1333e-04 - val_mean_absolute_error: 0.0157
# Epoch 233/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0290 - val_loss: 3.3408e-04 - val_mean_absolute_error: 0.0139
# Epoch 234/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0279 - val_loss: 3.6388e-04 - val_mean_absolute_error: 0.0151
# Epoch 235/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0012 - mean_absolute_error: 0.0264 - val_loss: 2.9576e-04 - val_mean_absolute_error: 0.0129
# Epoch 236/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0269 - val_loss: 3.5328e-04 - val_mean_absolute_error: 0.0143
# Epoch 237/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0014 - mean_absolute_error: 0.0281 - val_loss: 3.4806e-04 - val_mean_absolute_error: 0.0141
# Epoch 238/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0284 - val_loss: 3.8069e-04 - val_mean_absolute_error: 0.0156
# Epoch 239/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0275 - val_loss: 3.8583e-04 - val_mean_absolute_error: 0.0150
# Epoch 240/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0293 - val_loss: 3.7299e-04 - val_mean_absolute_error: 0.0155
# Epoch 241/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0273 - val_loss: 3.1511e-04 - val_mean_absolute_error: 0.0134
# Epoch 242/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0282 - val_loss: 2.9548e-04 - val_mean_absolute_error: 0.0130
# Epoch 243/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0268 - val_loss: 4.9473e-04 - val_mean_absolute_error: 0.0174
# Epoch 244/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0270 - val_loss: 2.9234e-04 - val_mean_absolute_error: 0.0132
# Epoch 245/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0014 - mean_absolute_error: 0.0283 - val_loss: 3.2433e-04 - val_mean_absolute_error: 0.0144
# Epoch 246/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0268 - val_loss: 2.8574e-04 - val_mean_absolute_error: 0.0129
# Epoch 247/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0266 - val_loss: 2.9617e-04 - val_mean_absolute_error: 0.0133
# Epoch 248/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0264 - val_loss: 3.7729e-04 - val_mean_absolute_error: 0.0149
# Epoch 249/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0013 - mean_absolute_error: 0.0275 - val_loss: 2.8139e-04 - val_mean_absolute_error: 0.0127
# Epoch 250/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0271 - val_loss: 7.9284e-04 - val_mean_absolute_error: 0.0245
# Epoch 251/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0285 - val_loss: 3.4343e-04 - val_mean_absolute_error: 0.0146
# Epoch 252/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0274 - val_loss: 3.3445e-04 - val_mean_absolute_error: 0.0143
# Epoch 253/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0276 - val_loss: 5.8481e-04 - val_mean_absolute_error: 0.0196
# Epoch 254/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0290 - val_loss: 3.0594e-04 - val_mean_absolute_error: 0.0138
# Epoch 255/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0280 - val_loss: 6.1309e-04 - val_mean_absolute_error: 0.0208
# Epoch 256/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0013 - mean_absolute_error: 0.0281 - val_loss: 3.2946e-04 - val_mean_absolute_error: 0.0140
# Epoch 257/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0272 - val_loss: 3.6131e-04 - val_mean_absolute_error: 0.0154
# Epoch 258/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0014 - mean_absolute_error: 0.0290 - val_loss: 8.5888e-04 - val_mean_absolute_error: 0.0253
# Epoch 259/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0014 - mean_absolute_error: 0.0286 - val_loss: 6.8131e-04 - val_mean_absolute_error: 0.0215
# Epoch 260/300
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0015 - mean_absolute_error: 0.0300 - val_loss: 4.0158e-04 - val_mean_absolute_error: 0.0166
# Epoch 261/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0275 - val_loss: 3.0807e-04 - val_mean_absolute_error: 0.0140
# Epoch 262/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0267 - val_loss: 4.1843e-04 - val_mean_absolute_error: 0.0167
# Epoch 263/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0285 - val_loss: 3.0367e-04 - val_mean_absolute_error: 0.0136
# Epoch 264/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0289 - val_loss: 4.1352e-04 - val_mean_absolute_error: 0.0157
# Epoch 265/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0277 - val_loss: 4.6844e-04 - val_mean_absolute_error: 0.0168
# Epoch 266/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0294 - val_loss: 4.3064e-04 - val_mean_absolute_error: 0.0160
# Epoch 267/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0280 - val_loss: 2.9897e-04 - val_mean_absolute_error: 0.0133
# Epoch 268/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0265 - val_loss: 2.9183e-04 - val_mean_absolute_error: 0.0132
# Epoch 269/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0262 - val_loss: 4.5694e-04 - val_mean_absolute_error: 0.0176
# Epoch 270/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0268 - val_loss: 3.3744e-04 - val_mean_absolute_error: 0.0139
# Epoch 271/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0012 - mean_absolute_error: 0.0263 - val_loss: 4.2722e-04 - val_mean_absolute_error: 0.0167
# Epoch 272/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0265 - val_loss: 3.3361e-04 - val_mean_absolute_error: 0.0148
# Epoch 273/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0013 - mean_absolute_error: 0.0276 - val_loss: 3.4135e-04 - val_mean_absolute_error: 0.0148
# Epoch 274/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0254 - val_loss: 2.8665e-04 - val_mean_absolute_error: 0.0128
# Epoch 275/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0266 - val_loss: 3.0291e-04 - val_mean_absolute_error: 0.0133
# Epoch 276/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0283 - val_loss: 7.1172e-04 - val_mean_absolute_error: 0.0219
# Epoch 277/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0013 - mean_absolute_error: 0.0277 - val_loss: 3.0677e-04 - val_mean_absolute_error: 0.0133
# Epoch 278/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0264 - val_loss: 3.0454e-04 - val_mean_absolute_error: 0.0136
# Epoch 279/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0272 - val_loss: 2.8873e-04 - val_mean_absolute_error: 0.0131
# Epoch 280/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0012 - mean_absolute_error: 0.0265 - val_loss: 3.2008e-04 - val_mean_absolute_error: 0.0140
# Epoch 281/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0260 - val_loss: 4.6787e-04 - val_mean_absolute_error: 0.0179
# Epoch 282/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0013 - mean_absolute_error: 0.0273 - val_loss: 2.9988e-04 - val_mean_absolute_error: 0.0134
# Epoch 283/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0011 - mean_absolute_error: 0.0258 - val_loss: 2.9290e-04 - val_mean_absolute_error: 0.0133
# Epoch 284/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0268 - val_loss: 3.0190e-04 - val_mean_absolute_error: 0.0134
# Epoch 285/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0262 - val_loss: 3.9190e-04 - val_mean_absolute_error: 0.0151
# Epoch 286/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0281 - val_loss: 3.8594e-04 - val_mean_absolute_error: 0.0155
# Epoch 287/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0265 - val_loss: 3.5623e-04 - val_mean_absolute_error: 0.0143
# Epoch 288/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0012 - mean_absolute_error: 0.0264 - val_loss: 3.1924e-04 - val_mean_absolute_error: 0.0139
# Epoch 289/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0273 - val_loss: 2.8948e-04 - val_mean_absolute_error: 0.0128
# Epoch 290/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0012 - mean_absolute_error: 0.0264 - val_loss: 3.1183e-04 - val_mean_absolute_error: 0.0136
# Epoch 291/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0260 - val_loss: 3.2019e-04 - val_mean_absolute_error: 0.0141
# Epoch 292/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0012 - mean_absolute_error: 0.0261 - val_loss: 3.2183e-04 - val_mean_absolute_error: 0.0143
# Epoch 293/300
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0012 - mean_absolute_error: 0.0273 - val_loss: 3.4235e-04 - val_mean_absolute_error: 0.0150
# Epoch 294/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0013 - mean_absolute_error: 0.0273 - val_loss: 4.1137e-04 - val_mean_absolute_error: 0.0165
# Epoch 295/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0260 - val_loss: 3.3582e-04 - val_mean_absolute_error: 0.0138
# Epoch 296/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0012 - mean_absolute_error: 0.0267 - val_loss: 3.2463e-04 - val_mean_absolute_error: 0.0138
# Epoch 297/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0011 - mean_absolute_error: 0.0254 - val_loss: 4.8973e-04 - val_mean_absolute_error: 0.0182
# Epoch 298/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0011 - mean_absolute_error: 0.0253 - val_loss: 3.7604e-04 - val_mean_absolute_error: 0.0148
# Epoch 299/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0274 - val_loss: 3.3681e-04 - val_mean_absolute_error: 0.0144
# Epoch 300/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0011 - mean_absolute_error: 0.0255 - val_loss: 3.0543e-04 - val_mean_absolute_error: 0.0138

# %%
def make_predictions(model, x_train, x_test):
    train_predict = model.predict(x_train)
    test_predict = model.predict(x_test)
    return train_predict, test_predict

# %%
train_predict, test_predict = make_predictions(model, x_train, x_test)
# Out:
# 24/24 [==============================] - 1s 6ms/step
# 5/5 [==============================] - 0s 6ms/step

# %%
def inverse_transform(scaler, y_train, train_predict, y_test, test_predict):
    train_predict = scaler.inverse_transform(train_predict)
    test_predict = scaler.inverse_transform(test_predict)
    return train_predict, test_predict

# %%
train_predict, test_predict = inverse_transform(scaler, y_train, train_predict, y_test, test_predict)

# %%
def evaluate_model(y_train, train_predict, y_test, test_predict):
    train_rmse = math.sqrt(mean_squared_error(y_train, train_predict))
    test_rmse = math.sqrt(mean_squared_error(y_test, test_predict))
    print(f"Training RMSE: {train_rmse}")
    print(f"Testing RMSE: {test_rmse}")

# %%
evaluate_model(y_train, train_predict, y_test, test_predict)
# Out:
# Training RMSE: 146.0452615238573
# Testing RMSE: 162.22216625936792

# %%
def plot_predictions(original_data, train_predict, test_predict, company_name):
    look_back = 60
    train_predict_plot = np.empty_like(original_data)
    train_predict_plot[:] = np.nan
    train_predict_plot[look_back : len(train_predict) + look_back] = train_predict.flatten()

    test_predict_plot = np.empty_like(original_data)
    test_predict_plot[:] = np.nan
    test_start = len(original_data) - len(test_predict)
    test_predict_plot[test_start:] = test_predict.flatten()

    plt.figure(figsize=(15, 6))
    plt.plot(original_data, color='black', label=f"Actual {company_name} price")
    plt.plot(train_predict_plot, color='red', label=f'Predicted {company_name} price (train_set)')
    plt.plot(test_predict_plot, color='blue', label=f"Predicted {company_name} price (test_set)")
    plt.title(f"{company_name} share price")
    plt.xlabel("Time")
    plt.ylabel(f"{company_name} share price")
    plt.legend()
    plt.show()

# %%
plot_predictions(new_df, train_predict, test_predict, company_name)

# %%
predictions = model.predict(x_test)

actual_values_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))
predicted_values_inverse = scaler.inverse_transform(predictions)

comparison_df = pd.DataFrame({'Actual Close Prices': actual_values_inverse.flatten(), 'Predicted Close Prices': predicted_values_inverse.flatten()})
print(comparison_df.head())

plt.figure(figsize=(10, 5))
plt.plot(actual_values_inverse.flatten(), marker='.', label="Actual Close Prices")
plt.plot(predicted_values_inverse.flatten(), 'r', label="Predicted Close Prices")
plt.ylabel('Close Price')
plt.xlabel('Time Step')
plt.legend()
plt.title('Comparison of Actual vs Predicted Close Prices')
plt.show()
# Out:
# 5/5 [==============================] - 0s 6ms/step
#    Actual Close Prices  Predicted Close Prices
# 0           171.139999              170.734161
# 1           171.720001              170.348129
# 2           173.639999              170.715561
# 3           175.139999              172.435959
# 4           174.470001              173.926819
