# %%
# !pip install --upgrade mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mplfinance) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mplfinance) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mplfinance) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.10b0

# %%
import numpy as np
import pandas as pd
import math
import random
import datetime as dt
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
from mplfinance.original_flavor import candlestick_ohlc
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import metrics
from sklearn.metrics import mean_squared_error
import yfinance as yf
# Out:
# /usr/local/lib/python3.10/dist-packages/yfinance/base.py:48: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _empty_series = pd.Series()

# %%
# Downloading stock data for Amgen Inc (AMGN) from Yahoo Finance
stock_data = yf.download('AMGN', start='2020-01-01', end='2024-01-01')
specific_df = pd.DataFrame(stock_data).reset_index()
specific_df['Name'] = 'AMGN'
print(specific_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2020-01-02  243.000000  243.190002  238.979996  240.100006  212.332336
# 1 2020-01-03  237.160004  240.259995  236.240005  238.470001  210.890854
# 2 2020-01-06  237.199997  240.449997  236.559998  240.300003  212.509186
# 3 2020-01-07  239.309998  240.000000  237.589996  238.039993  210.510544
# 4 2020-01-08  237.929993  239.580002  236.610001  238.220001  210.669739
#
#     Volume  Name
# 0  2088000  AMGN
# 1  1879000  AMGN
# 2  1802800  AMGN
# 3  1518900  AMGN
# 4  2214700  AMGN

# %%
plt.figure(figsize=(15,6))
plt.plot(specific_df['Date'], specific_df['Close'], marker='.')
plt.title('Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
matplotlib_date = mdates.date2num(specific_df['Date'])
ohlc = np.vstack((matplotlib_date, specific_df['Open'], specific_df['High'], specific_df['Low'], specific_df['Close'])).T
plt.figure(figsize=(15,6))
ax=plt.subplot()
candlestick_ohlc(ax, ohlc, width=0.6, colorup='g', colordown='r')
ax.xaxis_date()
plt.title('Candlestick Chart')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
window = 30
plt.figure(figsize=(15,6))
plt.plot(specific_df['Date'], specific_df['Close'], label='Closing Price', linewidth=2)
plt.plot(specific_df['Date'], specific_df['Close'].rolling(window=window).mean(), label=f'{window}-Day Moving Avg', linestyle='--')
plt.title(f'Closing Prices and {window}-Day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %%
company_name = 'AMGN'
specific_df['Month'] = specific_df['Date'].dt.month
monthly_average = specific_df.groupby('Month')['Close'].mean()

plt.figure(figsize=(15,6))
plt.plot(monthly_average.index, monthly_average.values, marker='o')
plt.title(f'Monthly Seasonality of {company_name}')
plt.xlabel('Months')
plt.ylabel('Average Closing Price')
plt.xticks(range(1,13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %%
new_df = specific_df.reset_index()['Close']
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(np.array(new_df).reshape(-1,1))

# %%
from sklearn.model_selection import train_test_split
test_size = 0.2
train_data, test_data = train_test_split(scaled_data, test_size=test_size, shuffle=False)

# %%
def generate_sequences_and_labels(data, n_past):
    sequences = [data[i - n_past:i, 0] for i in range(n_past, len(data))]
    labels = [data[i, 0] for i in range(n_past, len(data))]
    return np.array(sequences), np.array(labels)

# %%
n_past = 60
x_train, y_train = generate_sequences_and_labels(train_data, n_past)
x_test, y_test = generate_sequences_and_labels(test_data, n_past)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=[input_shape, 1]))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    return model

# %%
def compile_lstm_model(model):
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
def train_lstm_model(model, x_train, y_train, x_test, y_test):
    model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=300, batch_size=32, verbose=1)

# %%
model = build_lstm_model(x_train.shape[1])
compile_lstm_model(model)
train_lstm_model(model, x_train, y_train, x_test, y_test)
# Out:
# Epoch 1/300
# 24/24 [==============================] - 7s 66ms/step - loss: 0.0470 - mean_absolute_error: 0.1586 - val_loss: 0.0106 - val_mean_absolute_error: 0.0836
# Epoch 2/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0124 - mean_absolute_error: 0.0898 - val_loss: 0.0175 - val_mean_absolute_error: 0.1099
# Epoch 3/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0100 - mean_absolute_error: 0.0803 - val_loss: 0.0108 - val_mean_absolute_error: 0.0829
# Epoch 4/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0093 - mean_absolute_error: 0.0759 - val_loss: 0.0140 - val_mean_absolute_error: 0.0973
# Epoch 5/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0087 - mean_absolute_error: 0.0750 - val_loss: 0.0110 - val_mean_absolute_error: 0.0846
# Epoch 6/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0083 - mean_absolute_error: 0.0730 - val_loss: 0.0111 - val_mean_absolute_error: 0.0852
# Epoch 7/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0078 - mean_absolute_error: 0.0697 - val_loss: 0.0057 - val_mean_absolute_error: 0.0596
# Epoch 8/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0070 - mean_absolute_error: 0.0671 - val_loss: 0.0079 - val_mean_absolute_error: 0.0718
# Epoch 9/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0075 - mean_absolute_error: 0.0675 - val_loss: 0.0080 - val_mean_absolute_error: 0.0723
# Epoch 10/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0076 - mean_absolute_error: 0.0700 - val_loss: 0.0061 - val_mean_absolute_error: 0.0630
# Epoch 11/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0069 - mean_absolute_error: 0.0665 - val_loss: 0.0059 - val_mean_absolute_error: 0.0621
# Epoch 12/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0062 - mean_absolute_error: 0.0617 - val_loss: 0.0079 - val_mean_absolute_error: 0.0714
# Epoch 13/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0064 - mean_absolute_error: 0.0630 - val_loss: 0.0048 - val_mean_absolute_error: 0.0548
# Epoch 14/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0063 - mean_absolute_error: 0.0628 - val_loss: 0.0103 - val_mean_absolute_error: 0.0829
# Epoch 15/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0074 - mean_absolute_error: 0.0673 - val_loss: 0.0131 - val_mean_absolute_error: 0.0945
# Epoch 16/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0064 - mean_absolute_error: 0.0624 - val_loss: 0.0051 - val_mean_absolute_error: 0.0562
# Epoch 17/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0059 - mean_absolute_error: 0.0598 - val_loss: 0.0057 - val_mean_absolute_error: 0.0599
# Epoch 18/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0057 - mean_absolute_error: 0.0601 - val_loss: 0.0058 - val_mean_absolute_error: 0.0603
# Epoch 19/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0062 - mean_absolute_error: 0.0624 - val_loss: 0.0067 - val_mean_absolute_error: 0.0648
# Epoch 20/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0059 - mean_absolute_error: 0.0596 - val_loss: 0.0082 - val_mean_absolute_error: 0.0732
# Epoch 21/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0055 - mean_absolute_error: 0.0584 - val_loss: 0.0053 - val_mean_absolute_error: 0.0569
# Epoch 22/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0050 - mean_absolute_error: 0.0565 - val_loss: 0.0109 - val_mean_absolute_error: 0.0857
# Epoch 23/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0060 - mean_absolute_error: 0.0600 - val_loss: 0.0050 - val_mean_absolute_error: 0.0549
# Epoch 24/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0053 - mean_absolute_error: 0.0577 - val_loss: 0.0040 - val_mean_absolute_error: 0.0476
# Epoch 25/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0060 - mean_absolute_error: 0.0622 - val_loss: 0.0039 - val_mean_absolute_error: 0.0469
# Epoch 26/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0052 - mean_absolute_error: 0.0570 - val_loss: 0.0072 - val_mean_absolute_error: 0.0671
# Epoch 27/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0054 - mean_absolute_error: 0.0583 - val_loss: 0.0044 - val_mean_absolute_error: 0.0505
# Epoch 28/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0047 - mean_absolute_error: 0.0543 - val_loss: 0.0087 - val_mean_absolute_error: 0.0747
# Epoch 29/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0057 - mean_absolute_error: 0.0589 - val_loss: 0.0037 - val_mean_absolute_error: 0.0454
# Epoch 30/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0049 - mean_absolute_error: 0.0552 - val_loss: 0.0043 - val_mean_absolute_error: 0.0491
# Epoch 31/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0048 - mean_absolute_error: 0.0541 - val_loss: 0.0037 - val_mean_absolute_error: 0.0470
# Epoch 32/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0045 - mean_absolute_error: 0.0518 - val_loss: 0.0043 - val_mean_absolute_error: 0.0492
# Epoch 33/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0047 - mean_absolute_error: 0.0537 - val_loss: 0.0044 - val_mean_absolute_error: 0.0504
# Epoch 34/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0045 - mean_absolute_error: 0.0520 - val_loss: 0.0032 - val_mean_absolute_error: 0.0428
# Epoch 35/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0049 - mean_absolute_error: 0.0551 - val_loss: 0.0034 - val_mean_absolute_error: 0.0452
# Epoch 36/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0044 - mean_absolute_error: 0.0521 - val_loss: 0.0041 - val_mean_absolute_error: 0.0479
# Epoch 37/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0045 - mean_absolute_error: 0.0527 - val_loss: 0.0047 - val_mean_absolute_error: 0.0522
# Epoch 38/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0044 - mean_absolute_error: 0.0516 - val_loss: 0.0052 - val_mean_absolute_error: 0.0551
# Epoch 39/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0041 - mean_absolute_error: 0.0501 - val_loss: 0.0062 - val_mean_absolute_error: 0.0619
# Epoch 40/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0044 - mean_absolute_error: 0.0517 - val_loss: 0.0035 - val_mean_absolute_error: 0.0434
# Epoch 41/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0041 - mean_absolute_error: 0.0497 - val_loss: 0.0032 - val_mean_absolute_error: 0.0416
# Epoch 42/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0040 - mean_absolute_error: 0.0496 - val_loss: 0.0045 - val_mean_absolute_error: 0.0514
# Epoch 43/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0038 - mean_absolute_error: 0.0483 - val_loss: 0.0027 - val_mean_absolute_error: 0.0398
# Epoch 44/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0040 - mean_absolute_error: 0.0492 - val_loss: 0.0027 - val_mean_absolute_error: 0.0378
# Epoch 45/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0040 - mean_absolute_error: 0.0495 - val_loss: 0.0038 - val_mean_absolute_error: 0.0463
# Epoch 46/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0039 - mean_absolute_error: 0.0489 - val_loss: 0.0030 - val_mean_absolute_error: 0.0397
# Epoch 47/300
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0038 - mean_absolute_error: 0.0471 - val_loss: 0.0028 - val_mean_absolute_error: 0.0384
# Epoch 48/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0038 - mean_absolute_error: 0.0474 - val_loss: 0.0050 - val_mean_absolute_error: 0.0552
# Epoch 49/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0040 - mean_absolute_error: 0.0491 - val_loss: 0.0043 - val_mean_absolute_error: 0.0500
# Epoch 50/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0035 - mean_absolute_error: 0.0459 - val_loss: 0.0043 - val_mean_absolute_error: 0.0505
# Epoch 51/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0034 - mean_absolute_error: 0.0451 - val_loss: 0.0027 - val_mean_absolute_error: 0.0374
# Epoch 52/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0036 - mean_absolute_error: 0.0461 - val_loss: 0.0037 - val_mean_absolute_error: 0.0461
# Epoch 53/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0033 - mean_absolute_error: 0.0451 - val_loss: 0.0026 - val_mean_absolute_error: 0.0364
# Epoch 54/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0038 - mean_absolute_error: 0.0475 - val_loss: 0.0048 - val_mean_absolute_error: 0.0552
# Epoch 55/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0036 - mean_absolute_error: 0.0480 - val_loss: 0.0024 - val_mean_absolute_error: 0.0352
# Epoch 56/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0033 - mean_absolute_error: 0.0450 - val_loss: 0.0022 - val_mean_absolute_error: 0.0348
# Epoch 57/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0037 - mean_absolute_error: 0.0471 - val_loss: 0.0032 - val_mean_absolute_error: 0.0427
# Epoch 58/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0033 - mean_absolute_error: 0.0437 - val_loss: 0.0025 - val_mean_absolute_error: 0.0358
# Epoch 59/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0031 - mean_absolute_error: 0.0434 - val_loss: 0.0021 - val_mean_absolute_error: 0.0332
# Epoch 60/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0034 - mean_absolute_error: 0.0449 - val_loss: 0.0027 - val_mean_absolute_error: 0.0381
# Epoch 61/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0032 - mean_absolute_error: 0.0430 - val_loss: 0.0030 - val_mean_absolute_error: 0.0414
# Epoch 62/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0036 - mean_absolute_error: 0.0454 - val_loss: 0.0020 - val_mean_absolute_error: 0.0325
# Epoch 63/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0030 - mean_absolute_error: 0.0421 - val_loss: 0.0026 - val_mean_absolute_error: 0.0379
# Epoch 64/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0032 - mean_absolute_error: 0.0444 - val_loss: 0.0019 - val_mean_absolute_error: 0.0317
# Epoch 65/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0420 - val_loss: 0.0050 - val_mean_absolute_error: 0.0575
# Epoch 66/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0031 - mean_absolute_error: 0.0443 - val_loss: 0.0038 - val_mean_absolute_error: 0.0488
# Epoch 67/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0027 - mean_absolute_error: 0.0406 - val_loss: 0.0046 - val_mean_absolute_error: 0.0558
# Epoch 68/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0030 - mean_absolute_error: 0.0424 - val_loss: 0.0021 - val_mean_absolute_error: 0.0332
# Epoch 69/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0033 - mean_absolute_error: 0.0432 - val_loss: 0.0019 - val_mean_absolute_error: 0.0313
# Epoch 70/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0031 - mean_absolute_error: 0.0426 - val_loss: 0.0029 - val_mean_absolute_error: 0.0415
# Epoch 71/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0030 - mean_absolute_error: 0.0418 - val_loss: 0.0020 - val_mean_absolute_error: 0.0340
# Epoch 72/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0027 - mean_absolute_error: 0.0402 - val_loss: 0.0019 - val_mean_absolute_error: 0.0318
# Epoch 73/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0028 - mean_absolute_error: 0.0410 - val_loss: 0.0022 - val_mean_absolute_error: 0.0346
# Epoch 74/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0026 - mean_absolute_error: 0.0403 - val_loss: 0.0024 - val_mean_absolute_error: 0.0374
# Epoch 75/300
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0026 - mean_absolute_error: 0.0386 - val_loss: 0.0016 - val_mean_absolute_error: 0.0300
# Epoch 76/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0026 - mean_absolute_error: 0.0398 - val_loss: 0.0016 - val_mean_absolute_error: 0.0289
# Epoch 77/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0028 - mean_absolute_error: 0.0407 - val_loss: 0.0015 - val_mean_absolute_error: 0.0288
# Epoch 78/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0027 - mean_absolute_error: 0.0397 - val_loss: 0.0016 - val_mean_absolute_error: 0.0293
# Epoch 79/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0026 - mean_absolute_error: 0.0399 - val_loss: 0.0015 - val_mean_absolute_error: 0.0286
# Epoch 80/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0027 - mean_absolute_error: 0.0389 - val_loss: 0.0022 - val_mean_absolute_error: 0.0358
# Epoch 81/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0026 - mean_absolute_error: 0.0390 - val_loss: 0.0020 - val_mean_absolute_error: 0.0339
# Epoch 82/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0026 - mean_absolute_error: 0.0390 - val_loss: 0.0025 - val_mean_absolute_error: 0.0396
# Epoch 83/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0025 - mean_absolute_error: 0.0382 - val_loss: 0.0016 - val_mean_absolute_error: 0.0297
# Epoch 84/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0028 - mean_absolute_error: 0.0391 - val_loss: 0.0015 - val_mean_absolute_error: 0.0286
# Epoch 85/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0027 - mean_absolute_error: 0.0393 - val_loss: 0.0019 - val_mean_absolute_error: 0.0329
# Epoch 86/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0022 - mean_absolute_error: 0.0356 - val_loss: 0.0017 - val_mean_absolute_error: 0.0307
# Epoch 87/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0025 - mean_absolute_error: 0.0387 - val_loss: 0.0024 - val_mean_absolute_error: 0.0384
# Epoch 88/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0023 - mean_absolute_error: 0.0359 - val_loss: 0.0018 - val_mean_absolute_error: 0.0326
# Epoch 89/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0027 - mean_absolute_error: 0.0387 - val_loss: 0.0014 - val_mean_absolute_error: 0.0283
# Epoch 90/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0028 - mean_absolute_error: 0.0407 - val_loss: 0.0013 - val_mean_absolute_error: 0.0270
# Epoch 91/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0025 - mean_absolute_error: 0.0378 - val_loss: 0.0029 - val_mean_absolute_error: 0.0438
# Epoch 92/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0023 - mean_absolute_error: 0.0363 - val_loss: 0.0035 - val_mean_absolute_error: 0.0489
# Epoch 93/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0026 - mean_absolute_error: 0.0392 - val_loss: 0.0015 - val_mean_absolute_error: 0.0290
# Epoch 94/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0023 - mean_absolute_error: 0.0361 - val_loss: 0.0019 - val_mean_absolute_error: 0.0331
# Epoch 95/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0024 - mean_absolute_error: 0.0365 - val_loss: 0.0023 - val_mean_absolute_error: 0.0385
# Epoch 96/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0025 - mean_absolute_error: 0.0371 - val_loss: 0.0026 - val_mean_absolute_error: 0.0406
# Epoch 97/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0024 - mean_absolute_error: 0.0371 - val_loss: 0.0022 - val_mean_absolute_error: 0.0365
# Epoch 98/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0022 - mean_absolute_error: 0.0357 - val_loss: 0.0014 - val_mean_absolute_error: 0.0282
# Epoch 99/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0022 - mean_absolute_error: 0.0358 - val_loss: 0.0012 - val_mean_absolute_error: 0.0260
# Epoch 100/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0021 - mean_absolute_error: 0.0343 - val_loss: 0.0022 - val_mean_absolute_error: 0.0368
# Epoch 101/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0021 - mean_absolute_error: 0.0367 - val_loss: 0.0013 - val_mean_absolute_error: 0.0264
# Epoch 102/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0021 - mean_absolute_error: 0.0353 - val_loss: 0.0019 - val_mean_absolute_error: 0.0339
# Epoch 103/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0021 - mean_absolute_error: 0.0358 - val_loss: 0.0013 - val_mean_absolute_error: 0.0268
# Epoch 104/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0349 - val_loss: 0.0013 - val_mean_absolute_error: 0.0264
# Epoch 105/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0021 - mean_absolute_error: 0.0345 - val_loss: 0.0017 - val_mean_absolute_error: 0.0314
# Epoch 106/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0350 - val_loss: 0.0017 - val_mean_absolute_error: 0.0318
# Epoch 107/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0023 - mean_absolute_error: 0.0364 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 108/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0339 - val_loss: 0.0028 - val_mean_absolute_error: 0.0431
# Epoch 109/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0357 - val_loss: 0.0014 - val_mean_absolute_error: 0.0284
# Epoch 110/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0021 - mean_absolute_error: 0.0349 - val_loss: 0.0015 - val_mean_absolute_error: 0.0289
# Epoch 111/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0333 - val_loss: 0.0012 - val_mean_absolute_error: 0.0256
# Epoch 112/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0022 - mean_absolute_error: 0.0357 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 113/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0326 - val_loss: 0.0015 - val_mean_absolute_error: 0.0293
# Epoch 114/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0347 - val_loss: 0.0023 - val_mean_absolute_error: 0.0383
# Epoch 115/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0340 - val_loss: 0.0014 - val_mean_absolute_error: 0.0279
# Epoch 116/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0324 - val_loss: 0.0018 - val_mean_absolute_error: 0.0328
# Epoch 117/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0338 - val_loss: 0.0012 - val_mean_absolute_error: 0.0258
# Epoch 118/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0343 - val_loss: 0.0012 - val_mean_absolute_error: 0.0261
# Epoch 119/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0022 - mean_absolute_error: 0.0360 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 120/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0321 - val_loss: 0.0015 - val_mean_absolute_error: 0.0289
# Epoch 121/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0020 - mean_absolute_error: 0.0339 - val_loss: 0.0012 - val_mean_absolute_error: 0.0254
# Epoch 122/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0323 - val_loss: 0.0011 - val_mean_absolute_error: 0.0244
# Epoch 123/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0330 - val_loss: 0.0011 - val_mean_absolute_error: 0.0244
# Epoch 124/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0327 - val_loss: 0.0018 - val_mean_absolute_error: 0.0331
# Epoch 125/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0318 - val_loss: 0.0019 - val_mean_absolute_error: 0.0341
# Epoch 126/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0334 - val_loss: 0.0012 - val_mean_absolute_error: 0.0258
# Epoch 127/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0320 - val_loss: 0.0014 - val_mean_absolute_error: 0.0278
# Epoch 128/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0019 - mean_absolute_error: 0.0333 - val_loss: 0.0012 - val_mean_absolute_error: 0.0260
# Epoch 129/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0321 - val_loss: 0.0014 - val_mean_absolute_error: 0.0282
# Epoch 130/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0337 - val_loss: 0.0012 - val_mean_absolute_error: 0.0255
# Epoch 131/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0319 - val_loss: 0.0013 - val_mean_absolute_error: 0.0264
# Epoch 132/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0312 - val_loss: 0.0014 - val_mean_absolute_error: 0.0284
# Epoch 133/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0019 - mean_absolute_error: 0.0324 - val_loss: 0.0016 - val_mean_absolute_error: 0.0310
# Epoch 134/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0019 - mean_absolute_error: 0.0328 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252
# Epoch 135/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0017 - mean_absolute_error: 0.0311 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 136/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0018 - mean_absolute_error: 0.0328 - val_loss: 0.0016 - val_mean_absolute_error: 0.0310
# Epoch 137/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0019 - mean_absolute_error: 0.0319 - val_loss: 0.0013 - val_mean_absolute_error: 0.0274
# Epoch 138/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0306 - val_loss: 0.0014 - val_mean_absolute_error: 0.0276
# Epoch 139/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0312 - val_loss: 0.0017 - val_mean_absolute_error: 0.0321
# Epoch 140/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0316 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 141/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0017 - mean_absolute_error: 0.0306 - val_loss: 0.0014 - val_mean_absolute_error: 0.0276
# Epoch 142/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0314 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 143/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0316 - val_loss: 0.0013 - val_mean_absolute_error: 0.0267
# Epoch 144/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0317 - val_loss: 0.0016 - val_mean_absolute_error: 0.0303
# Epoch 145/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0302 - val_loss: 0.0013 - val_mean_absolute_error: 0.0284
# Epoch 146/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0345 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 147/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0305 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 148/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0307 - val_loss: 0.0016 - val_mean_absolute_error: 0.0305
# Epoch 149/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0016 - mean_absolute_error: 0.0298 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 150/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0309 - val_loss: 0.0015 - val_mean_absolute_error: 0.0297
# Epoch 151/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0304 - val_loss: 0.0016 - val_mean_absolute_error: 0.0312
# Epoch 152/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0291 - val_loss: 0.0012 - val_mean_absolute_error: 0.0265
# Epoch 153/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0019 - mean_absolute_error: 0.0322 - val_loss: 0.0011 - val_mean_absolute_error: 0.0242
# Epoch 154/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0295 - val_loss: 0.0011 - val_mean_absolute_error: 0.0249
# Epoch 155/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0299 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 156/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0293 - val_loss: 0.0012 - val_mean_absolute_error: 0.0255
# Epoch 157/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0299 - val_loss: 0.0013 - val_mean_absolute_error: 0.0262
# Epoch 158/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0303 - val_loss: 0.0011 - val_mean_absolute_error: 0.0245
# Epoch 159/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0292 - val_loss: 0.0013 - val_mean_absolute_error: 0.0272
# Epoch 160/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0304 - val_loss: 0.0011 - val_mean_absolute_error: 0.0245
# Epoch 161/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0291 - val_loss: 0.0024 - val_mean_absolute_error: 0.0393
# Epoch 162/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0308 - val_loss: 0.0018 - val_mean_absolute_error: 0.0328
# Epoch 163/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0302 - val_loss: 0.0019 - val_mean_absolute_error: 0.0347
# Epoch 164/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0016 - mean_absolute_error: 0.0302 - val_loss: 0.0012 - val_mean_absolute_error: 0.0257
# Epoch 165/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0340 - val_loss: 0.0012 - val_mean_absolute_error: 0.0262
# Epoch 166/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0019 - mean_absolute_error: 0.0325 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252
# Epoch 167/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0017 - mean_absolute_error: 0.0305 - val_loss: 0.0012 - val_mean_absolute_error: 0.0257
# Epoch 168/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0015 - mean_absolute_error: 0.0286 - val_loss: 0.0013 - val_mean_absolute_error: 0.0265
# Epoch 169/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0015 - mean_absolute_error: 0.0285 - val_loss: 0.0012 - val_mean_absolute_error: 0.0254
# Epoch 170/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0016 - mean_absolute_error: 0.0303 - val_loss: 0.0011 - val_mean_absolute_error: 0.0249
# Epoch 171/300
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 172/300
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0016 - mean_absolute_error: 0.0298 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 173/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0305 - val_loss: 0.0012 - val_mean_absolute_error: 0.0259
# Epoch 174/300
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0016 - mean_absolute_error: 0.0296 - val_loss: 0.0011 - val_mean_absolute_error: 0.0250
# Epoch 175/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0306 - val_loss: 0.0011 - val_mean_absolute_error: 0.0244
# Epoch 176/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0015 - mean_absolute_error: 0.0278 - val_loss: 0.0017 - val_mean_absolute_error: 0.0322
# Epoch 177/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0016 - mean_absolute_error: 0.0307 - val_loss: 0.0011 - val_mean_absolute_error: 0.0260
# Epoch 178/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0283 - val_loss: 0.0011 - val_mean_absolute_error: 0.0242
# Epoch 179/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0291 - val_loss: 0.0013 - val_mean_absolute_error: 0.0263
# Epoch 180/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0285 - val_loss: 0.0011 - val_mean_absolute_error: 0.0244
# Epoch 181/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0015 - mean_absolute_error: 0.0285 - val_loss: 0.0012 - val_mean_absolute_error: 0.0262
# Epoch 182/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0292 - val_loss: 0.0012 - val_mean_absolute_error: 0.0253
# Epoch 183/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - val_loss: 0.0014 - val_mean_absolute_error: 0.0279
# Epoch 184/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0290 - val_loss: 0.0010 - val_mean_absolute_error: 0.0245
# Epoch 185/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0293 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 186/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0293 - val_loss: 0.0012 - val_mean_absolute_error: 0.0260
# Epoch 187/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0283 - val_loss: 0.0012 - val_mean_absolute_error: 0.0257
# Epoch 188/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0291 - val_loss: 0.0011 - val_mean_absolute_error: 0.0245
# Epoch 189/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0287 - val_loss: 0.0013 - val_mean_absolute_error: 0.0275
# Epoch 190/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0015 - mean_absolute_error: 0.0290 - val_loss: 0.0019 - val_mean_absolute_error: 0.0343
# Epoch 191/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0297 - val_loss: 0.0013 - val_mean_absolute_error: 0.0271
# Epoch 192/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0279 - val_loss: 0.0017 - val_mean_absolute_error: 0.0316
# Epoch 193/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0283 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258
# Epoch 194/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0302 - val_loss: 0.0012 - val_mean_absolute_error: 0.0258
# Epoch 195/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0286 - val_loss: 0.0011 - val_mean_absolute_error: 0.0249
# Epoch 196/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0016 - mean_absolute_error: 0.0302 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252
# Epoch 197/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0282 - val_loss: 0.0018 - val_mean_absolute_error: 0.0328
# Epoch 198/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - val_loss: 0.0012 - val_mean_absolute_error: 0.0251
# Epoch 199/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0281 - val_loss: 0.0013 - val_mean_absolute_error: 0.0270
# Epoch 200/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0291 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 201/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0288 - val_loss: 0.0014 - val_mean_absolute_error: 0.0278
# Epoch 202/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0016 - mean_absolute_error: 0.0302 - val_loss: 0.0018 - val_mean_absolute_error: 0.0325
# Epoch 203/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0014 - mean_absolute_error: 0.0285 - val_loss: 0.0018 - val_mean_absolute_error: 0.0324
# Epoch 204/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0288 - val_loss: 0.0011 - val_mean_absolute_error: 0.0245
# Epoch 205/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0014 - mean_absolute_error: 0.0284 - val_loss: 0.0015 - val_mean_absolute_error: 0.0298
# Epoch 206/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0016 - mean_absolute_error: 0.0299 - val_loss: 0.0014 - val_mean_absolute_error: 0.0285
# Epoch 207/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0293 - val_loss: 0.0013 - val_mean_absolute_error: 0.0269
# Epoch 208/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0288 - val_loss: 0.0016 - val_mean_absolute_error: 0.0306
# Epoch 209/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0278 - val_loss: 0.0013 - val_mean_absolute_error: 0.0262
# Epoch 210/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0015 - mean_absolute_error: 0.0286 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248
# Epoch 211/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0276 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 212/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0290 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 213/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0286 - val_loss: 0.0010 - val_mean_absolute_error: 0.0245
# Epoch 214/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0271 - val_loss: 0.0014 - val_mean_absolute_error: 0.0277
# Epoch 215/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0282 - val_loss: 0.0013 - val_mean_absolute_error: 0.0263
# Epoch 216/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0286 - val_loss: 0.0011 - val_mean_absolute_error: 0.0241
# Epoch 217/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0283 - val_loss: 0.0013 - val_mean_absolute_error: 0.0264
# Epoch 218/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0287 - val_loss: 0.0010 - val_mean_absolute_error: 0.0242
# Epoch 219/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0280 - val_loss: 0.0012 - val_mean_absolute_error: 0.0256
# Epoch 220/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0287 - val_loss: 0.0017 - val_mean_absolute_error: 0.0317
# Epoch 221/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0295 - val_loss: 0.0013 - val_mean_absolute_error: 0.0262
# Epoch 222/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0265 - val_loss: 0.0013 - val_mean_absolute_error: 0.0263
# Epoch 223/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0271 - val_loss: 0.0016 - val_mean_absolute_error: 0.0303
# Epoch 224/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0286 - val_loss: 0.0012 - val_mean_absolute_error: 0.0258
# Epoch 225/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0278 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 226/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - val_loss: 0.0013 - val_mean_absolute_error: 0.0267
# Epoch 227/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0286 - val_loss: 0.0013 - val_mean_absolute_error: 0.0262
# Epoch 228/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0286 - val_loss: 0.0011 - val_mean_absolute_error: 0.0249
# Epoch 229/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0282 - val_loss: 0.0021 - val_mean_absolute_error: 0.0366
# Epoch 230/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - val_loss: 0.0015 - val_mean_absolute_error: 0.0291
# Epoch 231/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0288 - val_loss: 0.0010 - val_mean_absolute_error: 0.0240
# Epoch 232/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0270 - val_loss: 0.0010 - val_mean_absolute_error: 0.0242
# Epoch 233/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0278 - val_loss: 0.0012 - val_mean_absolute_error: 0.0258
# Epoch 234/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0288 - val_loss: 0.0010 - val_mean_absolute_error: 0.0245
# Epoch 235/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0277 - val_loss: 0.0015 - val_mean_absolute_error: 0.0292
# Epoch 236/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0288 - val_loss: 0.0013 - val_mean_absolute_error: 0.0273
# Epoch 237/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0274 - val_loss: 0.0014 - val_mean_absolute_error: 0.0282
# Epoch 238/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0016 - mean_absolute_error: 0.0298 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259
# Epoch 239/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0014 - mean_absolute_error: 0.0277 - val_loss: 0.0012 - val_mean_absolute_error: 0.0252
# Epoch 240/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0014 - mean_absolute_error: 0.0278 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 241/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0013 - mean_absolute_error: 0.0272 - val_loss: 0.0011 - val_mean_absolute_error: 0.0249
# Epoch 242/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0271 - val_loss: 0.0015 - val_mean_absolute_error: 0.0294
# Epoch 243/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - val_loss: 0.0011 - val_mean_absolute_error: 0.0250
# Epoch 244/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0280 - val_loss: 0.0019 - val_mean_absolute_error: 0.0349
# Epoch 245/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248
# Epoch 246/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0279 - val_loss: 0.0014 - val_mean_absolute_error: 0.0280
# Epoch 247/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0274 - val_loss: 0.0016 - val_mean_absolute_error: 0.0309
# Epoch 248/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0014 - mean_absolute_error: 0.0279 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 249/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0285 - val_loss: 0.0013 - val_mean_absolute_error: 0.0268
# Epoch 250/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0278 - val_loss: 0.0013 - val_mean_absolute_error: 0.0269
# Epoch 251/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0281 - val_loss: 0.0016 - val_mean_absolute_error: 0.0314
# Epoch 252/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0015 - mean_absolute_error: 0.0281 - val_loss: 0.0014 - val_mean_absolute_error: 0.0287
# Epoch 253/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0282 - val_loss: 0.0010 - val_mean_absolute_error: 0.0243
# Epoch 254/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0283 - val_loss: 0.0010 - val_mean_absolute_error: 0.0241
# Epoch 255/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0280 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
# Epoch 256/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0274 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 257/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0267 - val_loss: 0.0010 - val_mean_absolute_error: 0.0250
# Epoch 258/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0014 - mean_absolute_error: 0.0283 - val_loss: 0.0012 - val_mean_absolute_error: 0.0256
# Epoch 259/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0286 - val_loss: 0.0013 - val_mean_absolute_error: 0.0263
# Epoch 260/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0281 - val_loss: 0.0010 - val_mean_absolute_error: 0.0244
# Epoch 261/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 262/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0280 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 263/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0278 - val_loss: 0.0021 - val_mean_absolute_error: 0.0366
# Epoch 264/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0293 - val_loss: 0.0016 - val_mean_absolute_error: 0.0301
# Epoch 265/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0274 - val_loss: 0.0019 - val_mean_absolute_error: 0.0338
# Epoch 266/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0286 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 267/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0276 - val_loss: 0.0014 - val_mean_absolute_error: 0.0279
# Epoch 268/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0276 - val_loss: 0.0012 - val_mean_absolute_error: 0.0258
# Epoch 269/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0283 - val_loss: 0.0011 - val_mean_absolute_error: 0.0243
# Epoch 270/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0273 - val_loss: 0.0010 - val_mean_absolute_error: 0.0242
# Epoch 271/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0283 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 272/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0014 - mean_absolute_error: 0.0280 - val_loss: 0.0020 - val_mean_absolute_error: 0.0350
# Epoch 273/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0014 - mean_absolute_error: 0.0285 - val_loss: 0.0011 - val_mean_absolute_error: 0.0240
# Epoch 274/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0267 - val_loss: 0.0010 - val_mean_absolute_error: 0.0245
# Epoch 275/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0273 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 276/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0015 - mean_absolute_error: 0.0285 - val_loss: 0.0010 - val_mean_absolute_error: 0.0243
# Epoch 277/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0014 - mean_absolute_error: 0.0276 - val_loss: 0.0012 - val_mean_absolute_error: 0.0263
# Epoch 278/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0266 - val_loss: 0.0010 - val_mean_absolute_error: 0.0244
# Epoch 279/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0274 - val_loss: 0.0013 - val_mean_absolute_error: 0.0265
# Epoch 280/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0269 - val_loss: 0.0013 - val_mean_absolute_error: 0.0272
# Epoch 281/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0269 - val_loss: 0.0010 - val_mean_absolute_error: 0.0244
# Epoch 282/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0267 - val_loss: 0.0012 - val_mean_absolute_error: 0.0262
# Epoch 283/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0263 - val_loss: 0.0013 - val_mean_absolute_error: 0.0277
# Epoch 284/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0272 - val_loss: 0.0016 - val_mean_absolute_error: 0.0312
# Epoch 285/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0276 - val_loss: 0.0010 - val_mean_absolute_error: 0.0253
# Epoch 286/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0281 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248
# Epoch 287/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0278 - val_loss: 0.0012 - val_mean_absolute_error: 0.0255
# Epoch 288/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0270 - val_loss: 0.0014 - val_mean_absolute_error: 0.0287
# Epoch 289/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0275 - val_loss: 0.0010 - val_mean_absolute_error: 0.0241
# Epoch 290/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0267 - val_loss: 0.0016 - val_mean_absolute_error: 0.0305
# Epoch 291/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0279 - val_loss: 0.0010 - val_mean_absolute_error: 0.0245
# Epoch 292/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0274 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 293/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0270 - val_loss: 0.0010 - val_mean_absolute_error: 0.0256
# Epoch 294/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0275 - val_loss: 0.0015 - val_mean_absolute_error: 0.0292
# Epoch 295/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0274 - val_loss: 0.0010 - val_mean_absolute_error: 0.0252
# Epoch 296/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0271 - val_loss: 0.0010 - val_mean_absolute_error: 0.0243
# Epoch 297/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0013 - mean_absolute_error: 0.0272 - val_loss: 0.0012 - val_mean_absolute_error: 0.0265
# Epoch 298/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0261 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 299/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0272 - val_loss: 0.0014 - val_mean_absolute_error: 0.0283
# Epoch 300/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0283 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257

# %%
def make_predictions(model, x_train, x_test):
    train_predict = model.predict(x_train)
    test_predict = model.predict(x_test)
    return train_predict, test_predict

# %%
train_predict, test_predict = make_predictions(model, x_train, x_test)
# Out:
# 24/24 [==============================] - 1s 4ms/step
# 5/5 [==============================] - 0s 5ms/step

# %%
def inverse_transform(scaler, y_train, train_predict, y_test, test_predict):
    train_predict = scaler.inverse_transform(train_predict)
    test_predict = scaler.inverse_transform(test_predict)
    return train_predict, test_predict

# %%
train_predict, test_predict = inverse_transform(scaler, y_train, train_predict, y_test, test_predict)

# %%
def evaluate_model(y_train, train_predict, y_test, test_predict):
    train_rmse = math.sqrt(mean_squared_error(y_train, train_predict))
    test_rmse = math.sqrt(mean_squared_error(y_test, test_predict))
    print(f"Training RMSE: {train_rmse}")
    print(f"Testing RMSE: {test_rmse}")

# %%
evaluate_model(y_train, train_predict, y_test, test_predict)
# Out:
# Training RMSE: 238.4393187144316
# Testing RMSE: 257.14622030044643

# %%
def plot_predictions(original_data, train_predict, test_predict, company_name):
    look_back = 60
    train_predict_plot = np.empty_like(original_data)
    train_predict_plot[:] = np.nan
    train_predict_plot[look_back : len(train_predict) + look_back] = train_predict.flatten()

    test_predict_plot = np.empty_like(original_data)
    test_predict_plot[:] = np.nan
    test_start = len(original_data) - len(test_predict)
    test_predict_plot[test_start:] = test_predict.flatten()

    plt.figure(figsize=(15, 6))
    plt.plot(original_data, color='black', label=f"Actual {company_name} price")
    plt.plot(train_predict_plot, color='red', label=f'Predicted {company_name} price (train_set)')
    plt.plot(test_predict_plot, color='blue', label=f"Predicted {company_name} price (test_set)")
    plt.title(f"{company_name} share price")
    plt.xlabel("Time")
    plt.ylabel(f"{company_name} share price")
    plt.legend()
    plt.show()

# %%
plot_predictions(new_df, train_predict, test_predict, company_name)

# %%
predictions = model.predict(x_test)

actual_values_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))
predicted_values_inverse = scaler.inverse_transform(predictions)

comparison_df = pd.DataFrame({'Actual Close Prices': actual_values_inverse.flatten(), 'Predicted Close Prices': predicted_values_inverse.flatten()})
print(comparison_df.head())

plt.figure(figsize=(10, 5))
plt.plot(actual_values_inverse.flatten(), marker='.', label="Actual Close Prices")
plt.plot(predicted_values_inverse.flatten(), 'r', label="Predicted Close Prices")
plt.ylabel('Close Price')
plt.xlabel('Time Step')
plt.legend()
plt.title('Comparison of Actual vs Predicted Close Prices')
plt.show()
# Out:
# 5/5 [==============================] - 0s 5ms/step
#    Actual Close Prices  Predicted Close Prices
# 0           220.759995              220.340515
# 1           218.759995              220.184067
# 2           217.360001              218.427322
# 3           221.990005              216.815399
# 4           222.279999              220.374130
