# %%
# !pip install --upgrade mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mplfinance) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mplfinance) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mplfinance) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.10b0

# %%
import numpy as np
import pandas as pd
import math
import random
import datetime as dt
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
from mplfinance.original_flavor import candlestick_ohlc
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import metrics
from sklearn.metrics import mean_squared_error
import yfinance as yf
# Out:
# /usr/local/lib/python3.10/dist-packages/yfinance/base.py:48: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _empty_series = pd.Series()

# %%
# Downloading stock data for Boeing Co (BO) from Yahoo Finance
stock_data = yf.download('BA', start='2020-01-01', end='2024-01-01')
specific_df = pd.DataFrame(stock_data).reset_index()
specific_df['Name'] = 'BA'
print(specific_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2020-01-02  328.549988  333.350006  327.700012  333.320007  331.348572
# 1 2020-01-03  330.630005  334.890015  330.299988  332.760010  330.791901
# 2 2020-01-06  329.299988  334.859985  327.880005  333.739990  331.766083
# 3 2020-01-07  334.260010  344.190002  330.709991  337.279999  335.285156
# 4 2020-01-08  332.399994  334.029999  329.600006  331.369995  329.410095
#
#     Volume Name
# 0  4544400   BA
# 1  3875900   BA
# 2  5355000   BA
# 3  9898600   BA
# 4  8239200   BA

# %%
plt.figure(figsize=(15,6))
plt.plot(specific_df['Date'], specific_df['Close'], marker='.')
plt.title('Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
matplotlib_date = mdates.date2num(specific_df['Date'])
ohlc = np.vstack((matplotlib_date, specific_df['Open'], specific_df['High'], specific_df['Low'], specific_df['Close'])).T
plt.figure(figsize=(15,6))
ax=plt.subplot()
candlestick_ohlc(ax, ohlc, width=0.6, colorup='g', colordown='r')
ax.xaxis_date()
plt.title('Candlestick Chart')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
window = 30
plt.figure(figsize=(15,6))
plt.plot(specific_df['Date'], specific_df['Close'], label='Closing Price', linewidth=2)
plt.plot(specific_df['Date'], specific_df['Close'].rolling(window=window).mean(), label=f'{window}-Day Moving Avg', linestyle='--')
plt.title(f'Closing Prices and {window}-Day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %%
company_name = 'BA'
specific_df['Month'] = specific_df['Date'].dt.month
monthly_average = specific_df.groupby('Month')['Close'].mean()

plt.figure(figsize=(15,6))
plt.plot(monthly_average.index, monthly_average.values, marker='o')
plt.title(f'Monthly Seasonality of {company_name}')
plt.xlabel('Months')
plt.ylabel('Average Closing Price')
plt.xticks(range(1,13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %%
new_df = specific_df.reset_index()['Close']
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(np.array(new_df).reshape(-1,1))

# %%
from sklearn.model_selection import train_test_split
test_size = 0.2
train_data, test_data = train_test_split(scaled_data, test_size=test_size, shuffle=False)

# %%
def generate_sequences_and_labels(data, n_past):
    sequences = [data[i - n_past:i, 0] for i in range(n_past, len(data))]
    labels = [data[i, 0] for i in range(n_past, len(data))]
    return np.array(sequences), np.array(labels)

# %%
n_past = 60
x_train, y_train = generate_sequences_and_labels(train_data, n_past)
x_test, y_test = generate_sequences_and_labels(test_data, n_past)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=[input_shape, 1]))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    return model

# %%
def compile_lstm_model(model):
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
def train_lstm_model(model, x_train, y_train, x_test, y_test):
    model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=300, batch_size=32, verbose=1)

# %%
model = build_lstm_model(x_train.shape[1])
compile_lstm_model(model)
train_lstm_model(model, x_train, y_train, x_test, y_test)
# Out:
# Epoch 1/300
# 24/24 [==============================] - 6s 56ms/step - loss: 0.0245 - mean_absolute_error: 0.1183 - val_loss: 0.0044 - val_mean_absolute_error: 0.0578
# Epoch 2/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0066 - mean_absolute_error: 0.0638 - val_loss: 0.0050 - val_mean_absolute_error: 0.0564
# Epoch 3/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0057 - mean_absolute_error: 0.0589 - val_loss: 0.0033 - val_mean_absolute_error: 0.0472
# Epoch 4/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0049 - mean_absolute_error: 0.0530 - val_loss: 0.0026 - val_mean_absolute_error: 0.0436
# Epoch 5/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0043 - mean_absolute_error: 0.0499 - val_loss: 0.0025 - val_mean_absolute_error: 0.0412
# Epoch 6/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0039 - mean_absolute_error: 0.0480 - val_loss: 0.0020 - val_mean_absolute_error: 0.0378
# Epoch 7/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0041 - mean_absolute_error: 0.0496 - val_loss: 0.0019 - val_mean_absolute_error: 0.0379
# Epoch 8/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0039 - mean_absolute_error: 0.0480 - val_loss: 0.0038 - val_mean_absolute_error: 0.0487
# Epoch 9/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0039 - mean_absolute_error: 0.0481 - val_loss: 0.0031 - val_mean_absolute_error: 0.0437
# Epoch 10/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0037 - mean_absolute_error: 0.0467 - val_loss: 0.0031 - val_mean_absolute_error: 0.0441
# Epoch 11/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0040 - mean_absolute_error: 0.0491 - val_loss: 0.0016 - val_mean_absolute_error: 0.0336
# Epoch 12/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0035 - mean_absolute_error: 0.0452 - val_loss: 0.0031 - val_mean_absolute_error: 0.0441
# Epoch 13/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0031 - mean_absolute_error: 0.0431 - val_loss: 0.0029 - val_mean_absolute_error: 0.0426
# Epoch 14/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0037 - mean_absolute_error: 0.0476 - val_loss: 0.0038 - val_mean_absolute_error: 0.0497
# Epoch 15/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0036 - mean_absolute_error: 0.0465 - val_loss: 0.0015 - val_mean_absolute_error: 0.0323
# Epoch 16/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0033 - mean_absolute_error: 0.0436 - val_loss: 0.0013 - val_mean_absolute_error: 0.0299
# Epoch 17/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0028 - mean_absolute_error: 0.0405 - val_loss: 0.0011 - val_mean_absolute_error: 0.0279
# Epoch 18/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0029 - mean_absolute_error: 0.0415 - val_loss: 0.0017 - val_mean_absolute_error: 0.0333
# Epoch 19/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0027 - mean_absolute_error: 0.0403 - val_loss: 0.0012 - val_mean_absolute_error: 0.0285
# Epoch 20/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0026 - mean_absolute_error: 0.0392 - val_loss: 0.0011 - val_mean_absolute_error: 0.0270
# Epoch 21/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0027 - mean_absolute_error: 0.0399 - val_loss: 0.0015 - val_mean_absolute_error: 0.0312
# Epoch 22/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0026 - mean_absolute_error: 0.0393 - val_loss: 0.0013 - val_mean_absolute_error: 0.0288
# Epoch 23/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0420 - val_loss: 0.0031 - val_mean_absolute_error: 0.0455
# Epoch 24/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0026 - mean_absolute_error: 0.0386 - val_loss: 0.0011 - val_mean_absolute_error: 0.0268
# Epoch 25/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0381 - val_loss: 0.0012 - val_mean_absolute_error: 0.0280
# Epoch 26/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0025 - mean_absolute_error: 0.0387 - val_loss: 0.0014 - val_mean_absolute_error: 0.0297
# Epoch 27/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0026 - mean_absolute_error: 0.0392 - val_loss: 0.0015 - val_mean_absolute_error: 0.0306
# Epoch 28/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0027 - mean_absolute_error: 0.0389 - val_loss: 0.0012 - val_mean_absolute_error: 0.0274
# Epoch 29/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0377 - val_loss: 0.0017 - val_mean_absolute_error: 0.0348
# Epoch 30/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0029 - mean_absolute_error: 0.0409 - val_loss: 8.7725e-04 - val_mean_absolute_error: 0.0242
# Epoch 31/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0027 - mean_absolute_error: 0.0397 - val_loss: 8.9374e-04 - val_mean_absolute_error: 0.0248
# Epoch 32/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0025 - mean_absolute_error: 0.0379 - val_loss: 8.9687e-04 - val_mean_absolute_error: 0.0247
# Epoch 33/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0023 - mean_absolute_error: 0.0361 - val_loss: 8.0377e-04 - val_mean_absolute_error: 0.0233
# Epoch 34/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0023 - mean_absolute_error: 0.0367 - val_loss: 7.6585e-04 - val_mean_absolute_error: 0.0227
# Epoch 35/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0349 - val_loss: 8.7235e-04 - val_mean_absolute_error: 0.0237
# Epoch 36/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0022 - mean_absolute_error: 0.0354 - val_loss: 8.8491e-04 - val_mean_absolute_error: 0.0240
# Epoch 37/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0023 - mean_absolute_error: 0.0357 - val_loss: 0.0021 - val_mean_absolute_error: 0.0367
# Epoch 38/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0348 - val_loss: 6.7020e-04 - val_mean_absolute_error: 0.0211
# Epoch 39/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0349 - val_loss: 6.6778e-04 - val_mean_absolute_error: 0.0209
# Epoch 40/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0021 - mean_absolute_error: 0.0354 - val_loss: 0.0010 - val_mean_absolute_error: 0.0254
# Epoch 41/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0353 - val_loss: 7.1364e-04 - val_mean_absolute_error: 0.0219
# Epoch 42/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0022 - mean_absolute_error: 0.0358 - val_loss: 7.0431e-04 - val_mean_absolute_error: 0.0219
# Epoch 43/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0343 - val_loss: 6.6739e-04 - val_mean_absolute_error: 0.0211
# Epoch 44/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0350 - val_loss: 0.0012 - val_mean_absolute_error: 0.0275
# Epoch 45/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0020 - mean_absolute_error: 0.0336 - val_loss: 7.3514e-04 - val_mean_absolute_error: 0.0218
# Epoch 46/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0327 - val_loss: 0.0014 - val_mean_absolute_error: 0.0296
# Epoch 47/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0336 - val_loss: 6.7331e-04 - val_mean_absolute_error: 0.0213
# Epoch 48/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0335 - val_loss: 6.0957e-04 - val_mean_absolute_error: 0.0202
# Epoch 49/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0336 - val_loss: 7.2018e-04 - val_mean_absolute_error: 0.0217
# Epoch 50/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0333 - val_loss: 8.9329e-04 - val_mean_absolute_error: 0.0236
# Epoch 51/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0019 - mean_absolute_error: 0.0333 - val_loss: 5.9746e-04 - val_mean_absolute_error: 0.0199
# Epoch 52/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0334 - val_loss: 6.8191e-04 - val_mean_absolute_error: 0.0212
# Epoch 53/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0330 - val_loss: 6.7873e-04 - val_mean_absolute_error: 0.0208
# Epoch 54/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0019 - mean_absolute_error: 0.0332 - val_loss: 7.0836e-04 - val_mean_absolute_error: 0.0212
# Epoch 55/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0019 - mean_absolute_error: 0.0325 - val_loss: 5.6476e-04 - val_mean_absolute_error: 0.0193
# Epoch 56/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0320 - val_loss: 5.6726e-04 - val_mean_absolute_error: 0.0195
# Epoch 57/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0315 - val_loss: 6.6734e-04 - val_mean_absolute_error: 0.0205
# Epoch 58/300
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0016 - mean_absolute_error: 0.0303 - val_loss: 6.9377e-04 - val_mean_absolute_error: 0.0206
# Epoch 59/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0319 - val_loss: 5.5033e-04 - val_mean_absolute_error: 0.0186
# Epoch 60/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0018 - mean_absolute_error: 0.0325 - val_loss: 5.2890e-04 - val_mean_absolute_error: 0.0188
# Epoch 61/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0019 - mean_absolute_error: 0.0335 - val_loss: 0.0010 - val_mean_absolute_error: 0.0272
# Epoch 62/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0017 - mean_absolute_error: 0.0319 - val_loss: 5.1543e-04 - val_mean_absolute_error: 0.0185
# Epoch 63/300
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0016 - mean_absolute_error: 0.0302 - val_loss: 4.6956e-04 - val_mean_absolute_error: 0.0176
# Epoch 64/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0303 - val_loss: 4.8756e-04 - val_mean_absolute_error: 0.0178
# Epoch 65/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0303 - val_loss: 5.6125e-04 - val_mean_absolute_error: 0.0187
# Epoch 66/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0308 - val_loss: 4.8089e-04 - val_mean_absolute_error: 0.0178
# Epoch 67/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0302 - val_loss: 5.5300e-04 - val_mean_absolute_error: 0.0189
# Epoch 68/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0279 - val_loss: 4.7199e-04 - val_mean_absolute_error: 0.0171
# Epoch 69/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - val_loss: 4.4755e-04 - val_mean_absolute_error: 0.0169
# Epoch 70/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0290 - val_loss: 5.4859e-04 - val_mean_absolute_error: 0.0184
# Epoch 71/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0282 - val_loss: 5.3463e-04 - val_mean_absolute_error: 0.0180
# Epoch 72/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0286 - val_loss: 6.6161e-04 - val_mean_absolute_error: 0.0199
# Epoch 73/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0292 - val_loss: 4.1258e-04 - val_mean_absolute_error: 0.0161
# Epoch 74/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0281 - val_loss: 4.0565e-04 - val_mean_absolute_error: 0.0157
# Epoch 75/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0277 - val_loss: 4.0835e-04 - val_mean_absolute_error: 0.0164
# Epoch 76/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0295 - val_loss: 4.0402e-04 - val_mean_absolute_error: 0.0160
# Epoch 77/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0279 - val_loss: 4.6964e-04 - val_mean_absolute_error: 0.0177
# Epoch 78/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0287 - val_loss: 4.6308e-04 - val_mean_absolute_error: 0.0168
# Epoch 79/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0290 - val_loss: 4.4693e-04 - val_mean_absolute_error: 0.0173
# Epoch 80/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0271 - val_loss: 4.0879e-04 - val_mean_absolute_error: 0.0162
# Epoch 81/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0277 - val_loss: 4.3049e-04 - val_mean_absolute_error: 0.0164
# Epoch 82/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0269 - val_loss: 4.1393e-04 - val_mean_absolute_error: 0.0165
# Epoch 83/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0291 - val_loss: 3.8475e-04 - val_mean_absolute_error: 0.0158
# Epoch 84/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0254 - val_loss: 3.5440e-04 - val_mean_absolute_error: 0.0149
# Epoch 85/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0272 - val_loss: 5.5208e-04 - val_mean_absolute_error: 0.0180
# Epoch 86/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0267 - val_loss: 4.6850e-04 - val_mean_absolute_error: 0.0165
# Epoch 87/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0259 - val_loss: 3.5411e-04 - val_mean_absolute_error: 0.0150
# Epoch 88/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0269 - val_loss: 3.2728e-04 - val_mean_absolute_error: 0.0143
# Epoch 89/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0277 - val_loss: 3.9828e-04 - val_mean_absolute_error: 0.0151
# Epoch 90/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0263 - val_loss: 6.7910e-04 - val_mean_absolute_error: 0.0204
# Epoch 91/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0012 - mean_absolute_error: 0.0269 - val_loss: 7.0338e-04 - val_mean_absolute_error: 0.0206
# Epoch 92/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0268 - val_loss: 3.3744e-04 - val_mean_absolute_error: 0.0144
# Epoch 93/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0278 - val_loss: 3.8174e-04 - val_mean_absolute_error: 0.0158
# Epoch 94/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0266 - val_loss: 5.2413e-04 - val_mean_absolute_error: 0.0176
# Epoch 95/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0259 - val_loss: 3.3114e-04 - val_mean_absolute_error: 0.0137
# Epoch 96/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0258 - val_loss: 3.0534e-04 - val_mean_absolute_error: 0.0132
# Epoch 97/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0012 - mean_absolute_error: 0.0266 - val_loss: 2.7949e-04 - val_mean_absolute_error: 0.0129
# Epoch 98/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0255 - val_loss: 3.0321e-04 - val_mean_absolute_error: 0.0137
# Epoch 99/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0260 - val_loss: 3.9428e-04 - val_mean_absolute_error: 0.0152
# Epoch 100/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0248 - val_loss: 4.6744e-04 - val_mean_absolute_error: 0.0167
# Epoch 101/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0268 - val_loss: 8.9498e-04 - val_mean_absolute_error: 0.0244
# Epoch 102/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0281 - val_loss: 3.7515e-04 - val_mean_absolute_error: 0.0149
# Epoch 103/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0257 - val_loss: 5.1187e-04 - val_mean_absolute_error: 0.0175
# Epoch 104/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.7035e-04 - mean_absolute_error: 0.0241 - val_loss: 2.9611e-04 - val_mean_absolute_error: 0.0130
# Epoch 105/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0240 - val_loss: 3.0155e-04 - val_mean_absolute_error: 0.0132
# Epoch 106/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0010 - mean_absolute_error: 0.0246 - val_loss: 2.8150e-04 - val_mean_absolute_error: 0.0128
# Epoch 107/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0245 - val_loss: 6.3275e-04 - val_mean_absolute_error: 0.0203
# Epoch 108/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - mean_absolute_error: 0.0255 - val_loss: 2.8144e-04 - val_mean_absolute_error: 0.0128
# Epoch 109/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0247 - val_loss: 3.4686e-04 - val_mean_absolute_error: 0.0152
# Epoch 110/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0264 - val_loss: 2.8202e-04 - val_mean_absolute_error: 0.0131
# Epoch 111/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - mean_absolute_error: 0.0245 - val_loss: 2.9049e-04 - val_mean_absolute_error: 0.0127
# Epoch 112/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0010 - mean_absolute_error: 0.0242 - val_loss: 3.0885e-04 - val_mean_absolute_error: 0.0132
# Epoch 113/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0010 - mean_absolute_error: 0.0244 - val_loss: 2.9009e-04 - val_mean_absolute_error: 0.0128
# Epoch 114/300
# 24/24 [==============================] - 0s 13ms/step - loss: 9.9865e-04 - mean_absolute_error: 0.0241 - val_loss: 4.2861e-04 - val_mean_absolute_error: 0.0159
# Epoch 115/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.4986e-04 - mean_absolute_error: 0.0235 - val_loss: 2.6158e-04 - val_mean_absolute_error: 0.0121
# Epoch 116/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.9554e-04 - mean_absolute_error: 0.0236 - val_loss: 2.5848e-04 - val_mean_absolute_error: 0.0121
# Epoch 117/300
# 24/24 [==============================] - 0s 13ms/step - loss: 9.6415e-04 - mean_absolute_error: 0.0242 - val_loss: 3.2385e-04 - val_mean_absolute_error: 0.0136
# Epoch 118/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.8900e-04 - mean_absolute_error: 0.0235 - val_loss: 2.9114e-04 - val_mean_absolute_error: 0.0127
# Epoch 119/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.6729e-04 - mean_absolute_error: 0.0239 - val_loss: 3.7845e-04 - val_mean_absolute_error: 0.0148
# Epoch 120/300
# 24/24 [==============================] - 0s 14ms/step - loss: 9.6564e-04 - mean_absolute_error: 0.0232 - val_loss: 3.3738e-04 - val_mean_absolute_error: 0.0139
# Epoch 121/300
# 24/24 [==============================] - 0s 13ms/step - loss: 9.7938e-04 - mean_absolute_error: 0.0235 - val_loss: 7.8493e-04 - val_mean_absolute_error: 0.0238
# Epoch 122/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.8009e-04 - mean_absolute_error: 0.0234 - val_loss: 2.9247e-04 - val_mean_absolute_error: 0.0128
# Epoch 123/300
# 24/24 [==============================] - 0s 16ms/step - loss: 9.5153e-04 - mean_absolute_error: 0.0233 - val_loss: 2.9401e-04 - val_mean_absolute_error: 0.0128
# Epoch 124/300
# 24/24 [==============================] - 0s 16ms/step - loss: 9.7606e-04 - mean_absolute_error: 0.0238 - val_loss: 4.1225e-04 - val_mean_absolute_error: 0.0158
# Epoch 125/300
# 24/24 [==============================] - 0s 16ms/step - loss: 9.2974e-04 - mean_absolute_error: 0.0230 - val_loss: 3.2359e-04 - val_mean_absolute_error: 0.0135
# Epoch 126/300
# 24/24 [==============================] - 0s 18ms/step - loss: 9.4453e-04 - mean_absolute_error: 0.0236 - val_loss: 5.2955e-04 - val_mean_absolute_error: 0.0185
# Epoch 127/300
# 24/24 [==============================] - 0s 19ms/step - loss: 9.6002e-04 - mean_absolute_error: 0.0238 - val_loss: 2.6014e-04 - val_mean_absolute_error: 0.0125
# Epoch 128/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - mean_absolute_error: 0.0247 - val_loss: 2.4860e-04 - val_mean_absolute_error: 0.0118
# Epoch 129/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.9857e-04 - mean_absolute_error: 0.0227 - val_loss: 2.8140e-04 - val_mean_absolute_error: 0.0125
# Epoch 130/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0010 - mean_absolute_error: 0.0242 - val_loss: 2.5844e-04 - val_mean_absolute_error: 0.0123
# Epoch 131/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.7087e-04 - mean_absolute_error: 0.0224 - val_loss: 2.7819e-04 - val_mean_absolute_error: 0.0124
# Epoch 132/300
# 24/24 [==============================] - 0s 14ms/step - loss: 9.7665e-04 - mean_absolute_error: 0.0237 - val_loss: 2.4985e-04 - val_mean_absolute_error: 0.0119
# Epoch 133/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.9961e-04 - mean_absolute_error: 0.0224 - val_loss: 3.1069e-04 - val_mean_absolute_error: 0.0132
# Epoch 134/300
# 24/24 [==============================] - 0s 14ms/step - loss: 9.7438e-04 - mean_absolute_error: 0.0236 - val_loss: 2.8508e-04 - val_mean_absolute_error: 0.0126
# Epoch 135/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.7465e-04 - mean_absolute_error: 0.0219 - val_loss: 3.1398e-04 - val_mean_absolute_error: 0.0133
# Epoch 136/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.8326e-04 - mean_absolute_error: 0.0229 - val_loss: 3.0229e-04 - val_mean_absolute_error: 0.0130
# Epoch 137/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.9266e-04 - mean_absolute_error: 0.0224 - val_loss: 3.5757e-04 - val_mean_absolute_error: 0.0142
# Epoch 138/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.8291e-04 - mean_absolute_error: 0.0226 - val_loss: 2.7331e-04 - val_mean_absolute_error: 0.0122
# Epoch 139/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.9606e-04 - mean_absolute_error: 0.0223 - val_loss: 3.1783e-04 - val_mean_absolute_error: 0.0134
# Epoch 140/300
# 24/24 [==============================] - 0s 13ms/step - loss: 9.2718e-04 - mean_absolute_error: 0.0230 - val_loss: 3.6094e-04 - val_mean_absolute_error: 0.0147
# Epoch 141/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.3122e-04 - mean_absolute_error: 0.0225 - val_loss: 2.8611e-04 - val_mean_absolute_error: 0.0125
# Epoch 142/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.4374e-04 - mean_absolute_error: 0.0220 - val_loss: 2.4485e-04 - val_mean_absolute_error: 0.0119
# Epoch 143/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.2633e-04 - mean_absolute_error: 0.0219 - val_loss: 4.1176e-04 - val_mean_absolute_error: 0.0160
# Epoch 144/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.7135e-04 - mean_absolute_error: 0.0223 - val_loss: 3.8702e-04 - val_mean_absolute_error: 0.0154
# Epoch 145/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.0367e-04 - mean_absolute_error: 0.0217 - val_loss: 4.6746e-04 - val_mean_absolute_error: 0.0173
# Epoch 146/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.4123e-04 - mean_absolute_error: 0.0219 - val_loss: 2.7335e-04 - val_mean_absolute_error: 0.0122
# Epoch 147/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.5215e-04 - mean_absolute_error: 0.0236 - val_loss: 3.2278e-04 - val_mean_absolute_error: 0.0134
# Epoch 148/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.1215e-04 - mean_absolute_error: 0.0217 - val_loss: 3.0045e-04 - val_mean_absolute_error: 0.0129
# Epoch 149/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.6696e-04 - mean_absolute_error: 0.0220 - val_loss: 5.5611e-04 - val_mean_absolute_error: 0.0201
# Epoch 150/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.4397e-04 - mean_absolute_error: 0.0236 - val_loss: 2.8774e-04 - val_mean_absolute_error: 0.0126
# Epoch 151/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.2613e-04 - mean_absolute_error: 0.0213 - val_loss: 3.5231e-04 - val_mean_absolute_error: 0.0141
# Epoch 152/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.3174e-04 - mean_absolute_error: 0.0221 - val_loss: 5.4774e-04 - val_mean_absolute_error: 0.0187
# Epoch 153/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.0248e-04 - mean_absolute_error: 0.0213 - val_loss: 3.2774e-04 - val_mean_absolute_error: 0.0135
# Epoch 154/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.6322e-04 - mean_absolute_error: 0.0216 - val_loss: 2.9504e-04 - val_mean_absolute_error: 0.0136
# Epoch 155/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.8315e-04 - mean_absolute_error: 0.0228 - val_loss: 3.3814e-04 - val_mean_absolute_error: 0.0149
# Epoch 156/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.7040e-04 - mean_absolute_error: 0.0227 - val_loss: 2.6690e-04 - val_mean_absolute_error: 0.0126
# Epoch 157/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.5990e-04 - mean_absolute_error: 0.0233 - val_loss: 2.4267e-04 - val_mean_absolute_error: 0.0118
# Epoch 158/300
# 24/24 [==============================] - 0s 14ms/step - loss: 9.0395e-04 - mean_absolute_error: 0.0226 - val_loss: 4.0650e-04 - val_mean_absolute_error: 0.0166
# Epoch 159/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.7260e-04 - mean_absolute_error: 0.0225 - val_loss: 2.4271e-04 - val_mean_absolute_error: 0.0114
# Epoch 160/300
# 24/24 [==============================] - 0s 17ms/step - loss: 9.1677e-04 - mean_absolute_error: 0.0230 - val_loss: 2.5739e-04 - val_mean_absolute_error: 0.0124
# Epoch 161/300
# 24/24 [==============================] - 0s 17ms/step - loss: 8.4406e-04 - mean_absolute_error: 0.0218 - val_loss: 2.5674e-04 - val_mean_absolute_error: 0.0123
# Epoch 162/300
# 24/24 [==============================] - 0s 17ms/step - loss: 8.1201e-04 - mean_absolute_error: 0.0219 - val_loss: 2.9839e-04 - val_mean_absolute_error: 0.0127
# Epoch 163/300
# 24/24 [==============================] - 0s 19ms/step - loss: 7.6571e-04 - mean_absolute_error: 0.0205 - val_loss: 2.3615e-04 - val_mean_absolute_error: 0.0113
# Epoch 164/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.8848e-04 - mean_absolute_error: 0.0218 - val_loss: 2.9577e-04 - val_mean_absolute_error: 0.0136
# Epoch 165/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.8792e-04 - mean_absolute_error: 0.0226 - val_loss: 2.7401e-04 - val_mean_absolute_error: 0.0122
# Epoch 166/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.6062e-04 - mean_absolute_error: 0.0219 - val_loss: 2.5306e-04 - val_mean_absolute_error: 0.0116
# Epoch 167/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.2250e-04 - mean_absolute_error: 0.0207 - val_loss: 2.4393e-04 - val_mean_absolute_error: 0.0113
# Epoch 168/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.9423e-04 - mean_absolute_error: 0.0212 - val_loss: 3.3698e-04 - val_mean_absolute_error: 0.0140
# Epoch 169/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.2967e-04 - mean_absolute_error: 0.0221 - val_loss: 5.2581e-04 - val_mean_absolute_error: 0.0185
# Epoch 170/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.4787e-04 - mean_absolute_error: 0.0235 - val_loss: 4.5277e-04 - val_mean_absolute_error: 0.0167
# Epoch 171/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.6185e-04 - mean_absolute_error: 0.0223 - val_loss: 2.5534e-04 - val_mean_absolute_error: 0.0123
# Epoch 172/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.1854e-04 - mean_absolute_error: 0.0206 - val_loss: 4.1107e-04 - val_mean_absolute_error: 0.0157
# Epoch 173/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.1943e-04 - mean_absolute_error: 0.0218 - val_loss: 2.5896e-04 - val_mean_absolute_error: 0.0122
# Epoch 174/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.5433e-04 - mean_absolute_error: 0.0213 - val_loss: 2.6848e-04 - val_mean_absolute_error: 0.0121
# Epoch 175/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.5777e-04 - mean_absolute_error: 0.0223 - val_loss: 2.3315e-04 - val_mean_absolute_error: 0.0111
# Epoch 176/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.1369e-04 - mean_absolute_error: 0.0213 - val_loss: 2.9712e-04 - val_mean_absolute_error: 0.0129
# Epoch 177/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.6530e-04 - mean_absolute_error: 0.0220 - val_loss: 2.7268e-04 - val_mean_absolute_error: 0.0129
# Epoch 178/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.3865e-04 - mean_absolute_error: 0.0221 - val_loss: 2.6600e-04 - val_mean_absolute_error: 0.0127
# Epoch 179/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.0248e-04 - mean_absolute_error: 0.0216 - val_loss: 2.4421e-04 - val_mean_absolute_error: 0.0113
# Epoch 180/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.1851e-04 - mean_absolute_error: 0.0216 - val_loss: 3.1129e-04 - val_mean_absolute_error: 0.0141
# Epoch 181/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.4981e-04 - mean_absolute_error: 0.0224 - val_loss: 2.3427e-04 - val_mean_absolute_error: 0.0114
# Epoch 182/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.5427e-04 - mean_absolute_error: 0.0220 - val_loss: 2.8045e-04 - val_mean_absolute_error: 0.0131
# Epoch 183/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.4130e-04 - mean_absolute_error: 0.0224 - val_loss: 2.3141e-04 - val_mean_absolute_error: 0.0110
# Epoch 184/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.7917e-04 - mean_absolute_error: 0.0211 - val_loss: 3.3658e-04 - val_mean_absolute_error: 0.0139
# Epoch 185/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.0479e-04 - mean_absolute_error: 0.0214 - val_loss: 2.4511e-04 - val_mean_absolute_error: 0.0114
# Epoch 186/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.2838e-04 - mean_absolute_error: 0.0207 - val_loss: 2.3274e-04 - val_mean_absolute_error: 0.0113
# Epoch 187/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.1326e-04 - mean_absolute_error: 0.0212 - val_loss: 4.1547e-04 - val_mean_absolute_error: 0.0156
# Epoch 188/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.8512e-04 - mean_absolute_error: 0.0203 - val_loss: 2.8421e-04 - val_mean_absolute_error: 0.0133
# Epoch 189/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.1464e-04 - mean_absolute_error: 0.0219 - val_loss: 2.9198e-04 - val_mean_absolute_error: 0.0128
# Epoch 190/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.2650e-04 - mean_absolute_error: 0.0205 - val_loss: 3.4681e-04 - val_mean_absolute_error: 0.0143
# Epoch 191/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.1032e-04 - mean_absolute_error: 0.0218 - val_loss: 3.0043e-04 - val_mean_absolute_error: 0.0129
# Epoch 192/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.0203e-04 - mean_absolute_error: 0.0219 - val_loss: 5.6841e-04 - val_mean_absolute_error: 0.0194
# Epoch 193/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.0033e-04 - mean_absolute_error: 0.0212 - val_loss: 3.0288e-04 - val_mean_absolute_error: 0.0129
# Epoch 194/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.0628e-04 - mean_absolute_error: 0.0213 - val_loss: 3.6794e-04 - val_mean_absolute_error: 0.0147
# Epoch 195/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.6484e-04 - mean_absolute_error: 0.0213 - val_loss: 2.5235e-04 - val_mean_absolute_error: 0.0121
# Epoch 196/300
# 24/24 [==============================] - 0s 17ms/step - loss: 8.0525e-04 - mean_absolute_error: 0.0215 - val_loss: 2.3033e-04 - val_mean_absolute_error: 0.0112
# Epoch 197/300
# 24/24 [==============================] - 0s 19ms/step - loss: 7.1840e-04 - mean_absolute_error: 0.0204 - val_loss: 2.4776e-04 - val_mean_absolute_error: 0.0114
# Epoch 198/300
# 24/24 [==============================] - 0s 19ms/step - loss: 7.6749e-04 - mean_absolute_error: 0.0212 - val_loss: 3.2997e-04 - val_mean_absolute_error: 0.0137
# Epoch 199/300
# 24/24 [==============================] - 0s 19ms/step - loss: 7.7558e-04 - mean_absolute_error: 0.0212 - val_loss: 2.5991e-04 - val_mean_absolute_error: 0.0125
# Epoch 200/300
# 24/24 [==============================] - 0s 16ms/step - loss: 7.7806e-04 - mean_absolute_error: 0.0209 - val_loss: 3.9370e-04 - val_mean_absolute_error: 0.0162
# Epoch 201/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.2536e-04 - mean_absolute_error: 0.0218 - val_loss: 3.0444e-04 - val_mean_absolute_error: 0.0129
# Epoch 202/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.3348e-04 - mean_absolute_error: 0.0205 - val_loss: 2.4045e-04 - val_mean_absolute_error: 0.0112
# Epoch 203/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.9228e-04 - mean_absolute_error: 0.0212 - val_loss: 2.3428e-04 - val_mean_absolute_error: 0.0109
# Epoch 204/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.8878e-04 - mean_absolute_error: 0.0211 - val_loss: 2.2370e-04 - val_mean_absolute_error: 0.0111
# Epoch 205/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.4998e-04 - mean_absolute_error: 0.0205 - val_loss: 4.2793e-04 - val_mean_absolute_error: 0.0162
# Epoch 206/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.3368e-04 - mean_absolute_error: 0.0215 - val_loss: 4.2020e-04 - val_mean_absolute_error: 0.0159
# Epoch 207/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.7463e-04 - mean_absolute_error: 0.0208 - val_loss: 2.3355e-04 - val_mean_absolute_error: 0.0113
# Epoch 208/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.9008e-04 - mean_absolute_error: 0.0210 - val_loss: 2.5948e-04 - val_mean_absolute_error: 0.0117
# Epoch 209/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.6650e-04 - mean_absolute_error: 0.0207 - val_loss: 3.1322e-04 - val_mean_absolute_error: 0.0132
# Epoch 210/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.7549e-04 - mean_absolute_error: 0.0210 - val_loss: 2.3557e-04 - val_mean_absolute_error: 0.0112
# Epoch 211/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.4800e-04 - mean_absolute_error: 0.0220 - val_loss: 2.7086e-04 - val_mean_absolute_error: 0.0128
# Epoch 212/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.5666e-04 - mean_absolute_error: 0.0209 - val_loss: 2.3906e-04 - val_mean_absolute_error: 0.0111
# Epoch 213/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.5622e-04 - mean_absolute_error: 0.0208 - val_loss: 2.7504e-04 - val_mean_absolute_error: 0.0122
# Epoch 214/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.3202e-04 - mean_absolute_error: 0.0211 - val_loss: 2.5067e-04 - val_mean_absolute_error: 0.0115
# Epoch 215/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.3230e-04 - mean_absolute_error: 0.0217 - val_loss: 2.4900e-04 - val_mean_absolute_error: 0.0116
# Epoch 216/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.4586e-04 - mean_absolute_error: 0.0205 - val_loss: 2.3312e-04 - val_mean_absolute_error: 0.0111
# Epoch 217/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.0628e-04 - mean_absolute_error: 0.0198 - val_loss: 2.2147e-04 - val_mean_absolute_error: 0.0108
# Epoch 218/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.4370e-04 - mean_absolute_error: 0.0206 - val_loss: 3.2912e-04 - val_mean_absolute_error: 0.0139
# Epoch 219/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.3298e-04 - mean_absolute_error: 0.0206 - val_loss: 4.8361e-04 - val_mean_absolute_error: 0.0173
# Epoch 220/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.5214e-04 - mean_absolute_error: 0.0220 - val_loss: 5.1423e-04 - val_mean_absolute_error: 0.0179
# Epoch 221/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.3639e-04 - mean_absolute_error: 0.0221 - val_loss: 2.4541e-04 - val_mean_absolute_error: 0.0114
# Epoch 222/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.4707e-04 - mean_absolute_error: 0.0221 - val_loss: 2.3746e-04 - val_mean_absolute_error: 0.0116
# Epoch 223/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.4479e-04 - mean_absolute_error: 0.0210 - val_loss: 2.3166e-04 - val_mean_absolute_error: 0.0112
# Epoch 224/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.9163e-04 - mean_absolute_error: 0.0210 - val_loss: 4.1137e-04 - val_mean_absolute_error: 0.0160
# Epoch 225/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.4776e-04 - mean_absolute_error: 0.0205 - val_loss: 2.8544e-04 - val_mean_absolute_error: 0.0125
# Epoch 226/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.3606e-04 - mean_absolute_error: 0.0206 - val_loss: 2.4682e-04 - val_mean_absolute_error: 0.0115
# Epoch 227/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.1709e-04 - mean_absolute_error: 0.0233 - val_loss: 5.4950e-04 - val_mean_absolute_error: 0.0193
# Epoch 228/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.8059e-04 - mean_absolute_error: 0.0226 - val_loss: 4.1316e-04 - val_mean_absolute_error: 0.0158
# Epoch 229/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.5980e-04 - mean_absolute_error: 0.0208 - val_loss: 3.3105e-04 - val_mean_absolute_error: 0.0139
# Epoch 230/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.2419e-04 - mean_absolute_error: 0.0206 - val_loss: 3.2990e-04 - val_mean_absolute_error: 0.0139
# Epoch 231/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.6620e-04 - mean_absolute_error: 0.0225 - val_loss: 3.6096e-04 - val_mean_absolute_error: 0.0147
# Epoch 232/300
# 24/24 [==============================] - 0s 16ms/step - loss: 6.8410e-04 - mean_absolute_error: 0.0194 - val_loss: 2.1933e-04 - val_mean_absolute_error: 0.0106
# Epoch 233/300
# 24/24 [==============================] - 0s 19ms/step - loss: 7.7466e-04 - mean_absolute_error: 0.0212 - val_loss: 2.2751e-04 - val_mean_absolute_error: 0.0109
# Epoch 234/300
# 24/24 [==============================] - 0s 16ms/step - loss: 7.7499e-04 - mean_absolute_error: 0.0210 - val_loss: 2.5444e-04 - val_mean_absolute_error: 0.0116
# Epoch 235/300
# 24/24 [==============================] - 0s 19ms/step - loss: 7.2950e-04 - mean_absolute_error: 0.0208 - val_loss: 2.2523e-04 - val_mean_absolute_error: 0.0109
# Epoch 236/300
# 24/24 [==============================] - 0s 19ms/step - loss: 7.7853e-04 - mean_absolute_error: 0.0209 - val_loss: 2.8553e-04 - val_mean_absolute_error: 0.0125
# Epoch 237/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.6160e-04 - mean_absolute_error: 0.0208 - val_loss: 3.0963e-04 - val_mean_absolute_error: 0.0132
# Epoch 238/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.5061e-04 - mean_absolute_error: 0.0206 - val_loss: 3.0426e-04 - val_mean_absolute_error: 0.0137
# Epoch 239/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.9447e-04 - mean_absolute_error: 0.0216 - val_loss: 2.5636e-04 - val_mean_absolute_error: 0.0123
# Epoch 240/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.8842e-04 - mean_absolute_error: 0.0210 - val_loss: 3.6247e-04 - val_mean_absolute_error: 0.0149
# Epoch 241/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.2778e-04 - mean_absolute_error: 0.0207 - val_loss: 3.1333e-04 - val_mean_absolute_error: 0.0132
# Epoch 242/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.7848e-04 - mean_absolute_error: 0.0210 - val_loss: 2.4660e-04 - val_mean_absolute_error: 0.0115
# Epoch 243/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.5009e-04 - mean_absolute_error: 0.0210 - val_loss: 2.2605e-04 - val_mean_absolute_error: 0.0111
# Epoch 244/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.7684e-04 - mean_absolute_error: 0.0212 - val_loss: 2.8518e-04 - val_mean_absolute_error: 0.0126
# Epoch 245/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.1332e-04 - mean_absolute_error: 0.0205 - val_loss: 2.4065e-04 - val_mean_absolute_error: 0.0117
# Epoch 246/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.1866e-04 - mean_absolute_error: 0.0203 - val_loss: 3.6757e-04 - val_mean_absolute_error: 0.0149
# Epoch 247/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.2854e-04 - mean_absolute_error: 0.0204 - val_loss: 3.1794e-04 - val_mean_absolute_error: 0.0132
# Epoch 248/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.0507e-04 - mean_absolute_error: 0.0217 - val_loss: 2.9014e-04 - val_mean_absolute_error: 0.0134
# Epoch 249/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.1522e-04 - mean_absolute_error: 0.0203 - val_loss: 2.3102e-04 - val_mean_absolute_error: 0.0109
# Epoch 250/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.6609e-04 - mean_absolute_error: 0.0210 - val_loss: 2.8685e-04 - val_mean_absolute_error: 0.0125
# Epoch 251/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.4439e-04 - mean_absolute_error: 0.0208 - val_loss: 2.3631e-04 - val_mean_absolute_error: 0.0116
# Epoch 252/300
# 24/24 [==============================] - 0s 12ms/step - loss: 6.9022e-04 - mean_absolute_error: 0.0198 - val_loss: 2.7135e-04 - val_mean_absolute_error: 0.0121
# Epoch 253/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.6453e-04 - mean_absolute_error: 0.0210 - val_loss: 4.3796e-04 - val_mean_absolute_error: 0.0164
# Epoch 254/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.6867e-04 - mean_absolute_error: 0.0213 - val_loss: 5.8330e-04 - val_mean_absolute_error: 0.0199
# Epoch 255/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.4317e-04 - mean_absolute_error: 0.0205 - val_loss: 2.3365e-04 - val_mean_absolute_error: 0.0109
# Epoch 256/300
# 24/24 [==============================] - 0s 14ms/step - loss: 6.9945e-04 - mean_absolute_error: 0.0201 - val_loss: 2.1808e-04 - val_mean_absolute_error: 0.0108
# Epoch 257/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.6242e-04 - mean_absolute_error: 0.0209 - val_loss: 2.4116e-04 - val_mean_absolute_error: 0.0112
# Epoch 258/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.5555e-04 - mean_absolute_error: 0.0211 - val_loss: 2.6702e-04 - val_mean_absolute_error: 0.0127
# Epoch 259/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.0544e-04 - mean_absolute_error: 0.0203 - val_loss: 2.2862e-04 - val_mean_absolute_error: 0.0108
# Epoch 260/300
# 24/24 [==============================] - 0s 15ms/step - loss: 7.6360e-04 - mean_absolute_error: 0.0207 - val_loss: 3.6248e-04 - val_mean_absolute_error: 0.0147
# Epoch 261/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.0502e-04 - mean_absolute_error: 0.0199 - val_loss: 2.6412e-04 - val_mean_absolute_error: 0.0125
# Epoch 262/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.8022e-04 - mean_absolute_error: 0.0198 - val_loss: 2.4018e-04 - val_mean_absolute_error: 0.0113
# Epoch 263/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.0744e-04 - mean_absolute_error: 0.0201 - val_loss: 2.4674e-04 - val_mean_absolute_error: 0.0114
# Epoch 264/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.0913e-04 - mean_absolute_error: 0.0214 - val_loss: 2.2866e-04 - val_mean_absolute_error: 0.0112
# Epoch 265/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.7668e-04 - mean_absolute_error: 0.0214 - val_loss: 2.9286e-04 - val_mean_absolute_error: 0.0127
# Epoch 266/300
# 24/24 [==============================] - 0s 12ms/step - loss: 6.7288e-04 - mean_absolute_error: 0.0198 - val_loss: 2.2739e-04 - val_mean_absolute_error: 0.0111
# Epoch 267/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.3488e-04 - mean_absolute_error: 0.0216 - val_loss: 2.3918e-04 - val_mean_absolute_error: 0.0117
# Epoch 268/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.2090e-04 - mean_absolute_error: 0.0203 - val_loss: 2.4611e-04 - val_mean_absolute_error: 0.0113
# Epoch 269/300
# 24/24 [==============================] - 0s 18ms/step - loss: 6.8279e-04 - mean_absolute_error: 0.0200 - val_loss: 2.3298e-04 - val_mean_absolute_error: 0.0114
# Epoch 270/300
# 24/24 [==============================] - 0s 16ms/step - loss: 7.3910e-04 - mean_absolute_error: 0.0205 - val_loss: 2.4874e-04 - val_mean_absolute_error: 0.0118
# Epoch 271/300
# 24/24 [==============================] - 0s 17ms/step - loss: 7.1260e-04 - mean_absolute_error: 0.0204 - val_loss: 2.3837e-04 - val_mean_absolute_error: 0.0116
# Epoch 272/300
# 24/24 [==============================] - 0s 20ms/step - loss: 7.6226e-04 - mean_absolute_error: 0.0206 - val_loss: 2.3963e-04 - val_mean_absolute_error: 0.0112
# Epoch 273/300
# 24/24 [==============================] - 0s 18ms/step - loss: 8.5635e-04 - mean_absolute_error: 0.0219 - val_loss: 2.5590e-04 - val_mean_absolute_error: 0.0117
# Epoch 274/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.1751e-04 - mean_absolute_error: 0.0213 - val_loss: 2.8531e-04 - val_mean_absolute_error: 0.0127
# Epoch 275/300
# 24/24 [==============================] - 0s 15ms/step - loss: 7.0059e-04 - mean_absolute_error: 0.0204 - val_loss: 2.8356e-04 - val_mean_absolute_error: 0.0124
# Epoch 276/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.0559e-04 - mean_absolute_error: 0.0209 - val_loss: 2.7898e-04 - val_mean_absolute_error: 0.0123
# Epoch 277/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.0591e-04 - mean_absolute_error: 0.0198 - val_loss: 2.5585e-04 - val_mean_absolute_error: 0.0116
# Epoch 278/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.9480e-04 - mean_absolute_error: 0.0213 - val_loss: 2.2208e-04 - val_mean_absolute_error: 0.0107
# Epoch 279/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.8929e-04 - mean_absolute_error: 0.0211 - val_loss: 2.6562e-04 - val_mean_absolute_error: 0.0126
# Epoch 280/300
# 24/24 [==============================] - 0s 12ms/step - loss: 6.8492e-04 - mean_absolute_error: 0.0199 - val_loss: 4.2385e-04 - val_mean_absolute_error: 0.0162
# Epoch 281/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.5621e-04 - mean_absolute_error: 0.0205 - val_loss: 2.4595e-04 - val_mean_absolute_error: 0.0116
# Epoch 282/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.1405e-04 - mean_absolute_error: 0.0203 - val_loss: 2.8378e-04 - val_mean_absolute_error: 0.0128
# Epoch 283/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.4375e-04 - mean_absolute_error: 0.0216 - val_loss: 2.3520e-04 - val_mean_absolute_error: 0.0111
# Epoch 284/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.2669e-04 - mean_absolute_error: 0.0202 - val_loss: 2.6679e-04 - val_mean_absolute_error: 0.0120
# Epoch 285/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.2034e-04 - mean_absolute_error: 0.0203 - val_loss: 4.1118e-04 - val_mean_absolute_error: 0.0157
# Epoch 286/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.6027e-04 - mean_absolute_error: 0.0230 - val_loss: 3.0010e-04 - val_mean_absolute_error: 0.0137
# Epoch 287/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.4518e-04 - mean_absolute_error: 0.0205 - val_loss: 2.2904e-04 - val_mean_absolute_error: 0.0112
# Epoch 288/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.7916e-04 - mean_absolute_error: 0.0211 - val_loss: 5.5671e-04 - val_mean_absolute_error: 0.0181
# Epoch 289/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.4599e-04 - mean_absolute_error: 0.0214 - val_loss: 2.3618e-04 - val_mean_absolute_error: 0.0114
# Epoch 290/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.2147e-04 - mean_absolute_error: 0.0200 - val_loss: 2.3782e-04 - val_mean_absolute_error: 0.0116
# Epoch 291/300
# 24/24 [==============================] - 0s 14ms/step - loss: 6.8043e-04 - mean_absolute_error: 0.0197 - val_loss: 2.3779e-04 - val_mean_absolute_error: 0.0112
# Epoch 292/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.8893e-04 - mean_absolute_error: 0.0215 - val_loss: 3.0642e-04 - val_mean_absolute_error: 0.0133
# Epoch 293/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.0765e-04 - mean_absolute_error: 0.0222 - val_loss: 2.5708e-04 - val_mean_absolute_error: 0.0117
# Epoch 294/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.9574e-04 - mean_absolute_error: 0.0201 - val_loss: 2.4294e-04 - val_mean_absolute_error: 0.0118
# Epoch 295/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.1436e-04 - mean_absolute_error: 0.0209 - val_loss: 2.4078e-04 - val_mean_absolute_error: 0.0114
# Epoch 296/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.0256e-04 - mean_absolute_error: 0.0202 - val_loss: 3.0480e-04 - val_mean_absolute_error: 0.0131
# Epoch 297/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.0896e-04 - mean_absolute_error: 0.0202 - val_loss: 2.3174e-04 - val_mean_absolute_error: 0.0110
# Epoch 298/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.6499e-04 - mean_absolute_error: 0.0208 - val_loss: 2.4003e-04 - val_mean_absolute_error: 0.0112
# Epoch 299/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.8172e-04 - mean_absolute_error: 0.0194 - val_loss: 2.7817e-04 - val_mean_absolute_error: 0.0123
# Epoch 300/300
# 24/24 [==============================] - 0s 12ms/step - loss: 6.8924e-04 - mean_absolute_error: 0.0200 - val_loss: 3.5339e-04 - val_mean_absolute_error: 0.0153

# %%
def make_predictions(model, x_train, x_test):
    train_predict = model.predict(x_train)
    test_predict = model.predict(x_test)
    return train_predict, test_predict

# %%
train_predict, test_predict = make_predictions(model, x_train, x_test)
# Out:
# 24/24 [==============================] - 1s 6ms/step
# 5/5 [==============================] - 0s 5ms/step

# %%
def inverse_transform(scaler, y_train, train_predict, y_test, test_predict):
    train_predict = scaler.inverse_transform(train_predict)
    test_predict = scaler.inverse_transform(test_predict)
    return train_predict, test_predict

# %%
train_predict, test_predict = inverse_transform(scaler, y_train, train_predict, y_test, test_predict)

# %%
def evaluate_model(y_train, train_predict, y_test, test_predict):
    train_rmse = math.sqrt(mean_squared_error(y_train, train_predict))
    test_rmse = math.sqrt(mean_squared_error(y_test, test_predict))
    print(f"Training RMSE: {train_rmse}")
    print(f"Testing RMSE: {test_rmse}")

# %%
evaluate_model(y_train, train_predict, y_test, test_predict)
# Out:
# Training RMSE: 196.12994643194537
# Testing RMSE: 219.47583609184386

# %%
def plot_predictions(original_data, train_predict, test_predict, company_name):
    look_back = 60
    train_predict_plot = np.empty_like(original_data)
    train_predict_plot[:] = np.nan
    train_predict_plot[look_back : len(train_predict) + look_back] = train_predict.flatten()

    test_predict_plot = np.empty_like(original_data)
    test_predict_plot[:] = np.nan
    test_start = len(original_data) - len(test_predict)
    test_predict_plot[test_start:] = test_predict.flatten()

    plt.figure(figsize=(15, 6))
    plt.plot(original_data, color='black', label=f"Actual {company_name} price")
    plt.plot(train_predict_plot, color='red', label=f'Predicted {company_name} price (train_set)')
    plt.plot(test_predict_plot, color='blue', label=f"Predicted {company_name} price (test_set)")
    plt.title(f"{company_name} share price")
    plt.xlabel("Time")
    plt.ylabel(f"{company_name} share price")
    plt.legend()
    plt.show()

# %%
plot_predictions(new_df, train_predict, test_predict, company_name)

# %%
predictions = model.predict(x_test)

actual_values_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))
predicted_values_inverse = scaler.inverse_transform(predictions)

comparison_df = pd.DataFrame({'Actual Close Prices': actual_values_inverse.flatten(), 'Predicted Close Prices': predicted_values_inverse.flatten()})
print(comparison_df.head())

plt.figure(figsize=(10, 5))
plt.plot(actual_values_inverse.flatten(), marker='.', label="Actual Close Prices")
plt.plot(predicted_values_inverse.flatten(), 'r', label="Predicted Close Prices")
plt.ylabel('Close Price')
plt.xlabel('Time Step')
plt.legend()
plt.title('Comparison of Actual vs Predicted Close Prices')
plt.show()
# Out:
# 5/5 [==============================] - 0s 5ms/step
#    Actual Close Prices  Predicted Close Prices
# 0           218.110001              214.674835
# 1           217.309998              220.803879
# 2           221.559998              220.340195
# 3           220.380005              223.989319
# 4           216.899994              223.423599
