# %%
# !pip install --upgrade mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mplfinance) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mplfinance) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mplfinance) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.10b0

# %%
import numpy as np
import pandas as pd
import math
import random
import datetime as dt
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
from mplfinance.original_flavor import candlestick_ohlc
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import metrics
from sklearn.metrics import mean_squared_error
import yfinance as yf
# Out:
# /usr/local/lib/python3.10/dist-packages/yfinance/base.py:48: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _empty_series = pd.Series()

# %%
# Downloading stock data for Caterpillar Inc. (CAT) from Yahoo Finance
stock_data = yf.download('CAT', start='2020-01-01', end='2024-01-01')
specific_df = pd.DataFrame(stock_data).reset_index()
specific_df['Name'] = 'CAT'
print(specific_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2020-01-02  149.000000  150.550003  147.979996  150.529999  136.412842
# 1 2020-01-03  148.770004  149.960007  147.449997  148.440002  134.518845
# 2 2020-01-06  147.270004  148.559998  146.539993  148.339996  134.428238
# 3 2020-01-07  147.350006  147.570007  145.509995  146.380005  132.652039
# 4 2020-01-08  146.830002  148.570007  146.460007  147.679993  133.830093
#
#     Volume Name
# 0  3311900  CAT
# 1  3100600  CAT
# 2  2549600  CAT
# 3  2841900  CAT
# 4  2153200  CAT

# %%
plt.figure(figsize=(15,6))
plt.plot(specific_df['Date'], specific_df['Close'], marker='.')
plt.title('Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
matplotlib_date = mdates.date2num(specific_df['Date'])
ohlc = np.vstack((matplotlib_date, specific_df['Open'], specific_df['High'], specific_df['Low'], specific_df['Close'])).T
plt.figure(figsize=(15,6))
ax=plt.subplot()
candlestick_ohlc(ax, ohlc, width=0.6, colorup='g', colordown='r')
ax.xaxis_date()
plt.title('Candlestick Chart')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
window = 30
plt.figure(figsize=(15,6))
plt.plot(specific_df['Date'], specific_df['Close'], label='Closing Price', linewidth=2)
plt.plot(specific_df['Date'], specific_df['Close'].rolling(window=window).mean(), label=f'{window}-Day Moving Avg', linestyle='--')
plt.title(f'Closing Prices and {window}-Day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %%
company_name = 'CAT'
specific_df['Month'] = specific_df['Date'].dt.month
monthly_average = specific_df.groupby('Month')['Close'].mean()

plt.figure(figsize=(15,6))
plt.plot(monthly_average.index, monthly_average.values, marker='o')
plt.title(f'Monthly Seasonality of {company_name}')
plt.xlabel('Months')
plt.ylabel('Average Closing Price')
plt.xticks(range(1,13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %%
new_df = specific_df.reset_index()['Close']
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(np.array(new_df).reshape(-1,1))

# %%
from sklearn.model_selection import train_test_split
test_size = 0.2
train_data, test_data = train_test_split(scaled_data, test_size=test_size, shuffle=False)

# %%
def generate_sequences_and_labels(data, n_past):
    sequences = [data[i - n_past:i, 0] for i in range(n_past, len(data))]
    labels = [data[i, 0] for i in range(n_past, len(data))]
    return np.array(sequences), np.array(labels)

# %%
n_past = 60
x_train, y_train = generate_sequences_and_labels(train_data, n_past)
x_test, y_test = generate_sequences_and_labels(test_data, n_past)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=[input_shape, 1]))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    return model

# %%
def compile_lstm_model(model):
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
def train_lstm_model(model, x_train, y_train, x_test, y_test):
    model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=300, batch_size=32, verbose=1)

# %%
model = build_lstm_model(x_train.shape[1])
compile_lstm_model(model)
train_lstm_model(model, x_train, y_train, x_test, y_test)
# Out:
# Epoch 1/300
# 24/24 [==============================] - 6s 59ms/step - loss: 0.0430 - mean_absolute_error: 0.1549 - val_loss: 0.0058 - val_mean_absolute_error: 0.0602
# Epoch 2/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0096 - mean_absolute_error: 0.0792 - val_loss: 0.0248 - val_mean_absolute_error: 0.1444
# Epoch 3/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0071 - mean_absolute_error: 0.0670 - val_loss: 0.0105 - val_mean_absolute_error: 0.0894
# Epoch 4/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0054 - mean_absolute_error: 0.0571 - val_loss: 0.0054 - val_mean_absolute_error: 0.0582
# Epoch 5/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0054 - mean_absolute_error: 0.0571 - val_loss: 0.0059 - val_mean_absolute_error: 0.0625
# Epoch 6/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0050 - mean_absolute_error: 0.0552 - val_loss: 0.0056 - val_mean_absolute_error: 0.0603
# Epoch 7/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0054 - mean_absolute_error: 0.0574 - val_loss: 0.0039 - val_mean_absolute_error: 0.0469
# Epoch 8/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0052 - mean_absolute_error: 0.0562 - val_loss: 0.0044 - val_mean_absolute_error: 0.0522
# Epoch 9/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0048 - mean_absolute_error: 0.0537 - val_loss: 0.0058 - val_mean_absolute_error: 0.0629
# Epoch 10/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0044 - mean_absolute_error: 0.0509 - val_loss: 0.0037 - val_mean_absolute_error: 0.0462
# Epoch 11/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0041 - mean_absolute_error: 0.0497 - val_loss: 0.0107 - val_mean_absolute_error: 0.0917
# Epoch 12/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0042 - mean_absolute_error: 0.0505 - val_loss: 0.0055 - val_mean_absolute_error: 0.0615
# Epoch 13/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0045 - mean_absolute_error: 0.0519 - val_loss: 0.0042 - val_mean_absolute_error: 0.0514
# Epoch 14/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0040 - mean_absolute_error: 0.0496 - val_loss: 0.0125 - val_mean_absolute_error: 0.1011
# Epoch 15/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0043 - mean_absolute_error: 0.0505 - val_loss: 0.0078 - val_mean_absolute_error: 0.0767
# Epoch 16/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0043 - mean_absolute_error: 0.0512 - val_loss: 0.0041 - val_mean_absolute_error: 0.0512
# Epoch 17/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0037 - mean_absolute_error: 0.0463 - val_loss: 0.0069 - val_mean_absolute_error: 0.0717
# Epoch 18/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0036 - mean_absolute_error: 0.0462 - val_loss: 0.0075 - val_mean_absolute_error: 0.0759
# Epoch 19/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0035 - mean_absolute_error: 0.0460 - val_loss: 0.0035 - val_mean_absolute_error: 0.0467
# Epoch 20/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0036 - mean_absolute_error: 0.0459 - val_loss: 0.0027 - val_mean_absolute_error: 0.0400
# Epoch 21/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0038 - mean_absolute_error: 0.0475 - val_loss: 0.0026 - val_mean_absolute_error: 0.0397
# Epoch 22/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0035 - mean_absolute_error: 0.0452 - val_loss: 0.0070 - val_mean_absolute_error: 0.0731
# Epoch 23/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0032 - mean_absolute_error: 0.0437 - val_loss: 0.0045 - val_mean_absolute_error: 0.0564
# Epoch 24/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0032 - mean_absolute_error: 0.0444 - val_loss: 0.0044 - val_mean_absolute_error: 0.0553
# Epoch 25/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0030 - mean_absolute_error: 0.0427 - val_loss: 0.0050 - val_mean_absolute_error: 0.0602
# Epoch 26/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0036 - mean_absolute_error: 0.0458 - val_loss: 0.0022 - val_mean_absolute_error: 0.0360
# Epoch 27/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0038 - mean_absolute_error: 0.0475 - val_loss: 0.0087 - val_mean_absolute_error: 0.0836
# Epoch 28/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0036 - mean_absolute_error: 0.0461 - val_loss: 0.0020 - val_mean_absolute_error: 0.0347
# Epoch 29/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0033 - mean_absolute_error: 0.0449 - val_loss: 0.0027 - val_mean_absolute_error: 0.0415
# Epoch 30/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0033 - mean_absolute_error: 0.0441 - val_loss: 0.0047 - val_mean_absolute_error: 0.0586
# Epoch 31/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0030 - mean_absolute_error: 0.0427 - val_loss: 0.0066 - val_mean_absolute_error: 0.0715
# Epoch 32/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0031 - mean_absolute_error: 0.0421 - val_loss: 0.0073 - val_mean_absolute_error: 0.0758
# Epoch 33/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0028 - mean_absolute_error: 0.0412 - val_loss: 0.0034 - val_mean_absolute_error: 0.0483
# Epoch 34/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0030 - mean_absolute_error: 0.0431 - val_loss: 0.0024 - val_mean_absolute_error: 0.0390
# Epoch 35/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0028 - mean_absolute_error: 0.0411 - val_loss: 0.0022 - val_mean_absolute_error: 0.0373
# Epoch 36/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0027 - mean_absolute_error: 0.0407 - val_loss: 0.0106 - val_mean_absolute_error: 0.0946
# Epoch 37/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0426 - val_loss: 0.0042 - val_mean_absolute_error: 0.0557
# Epoch 38/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0027 - mean_absolute_error: 0.0408 - val_loss: 0.0053 - val_mean_absolute_error: 0.0634
# Epoch 39/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0419 - val_loss: 0.0048 - val_mean_absolute_error: 0.0604
# Epoch 40/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0026 - mean_absolute_error: 0.0389 - val_loss: 0.0029 - val_mean_absolute_error: 0.0447
# Epoch 41/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0026 - mean_absolute_error: 0.0387 - val_loss: 0.0020 - val_mean_absolute_error: 0.0349
# Epoch 42/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0027 - mean_absolute_error: 0.0393 - val_loss: 0.0065 - val_mean_absolute_error: 0.0722
# Epoch 43/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0029 - mean_absolute_error: 0.0415 - val_loss: 0.0016 - val_mean_absolute_error: 0.0303
# Epoch 44/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0027 - mean_absolute_error: 0.0404 - val_loss: 0.0040 - val_mean_absolute_error: 0.0544
# Epoch 45/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0389 - val_loss: 0.0023 - val_mean_absolute_error: 0.0386
# Epoch 46/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0025 - mean_absolute_error: 0.0382 - val_loss: 0.0029 - val_mean_absolute_error: 0.0443
# Epoch 47/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0028 - mean_absolute_error: 0.0407 - val_loss: 0.0018 - val_mean_absolute_error: 0.0328
# Epoch 48/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0026 - mean_absolute_error: 0.0392 - val_loss: 0.0014 - val_mean_absolute_error: 0.0266
# Epoch 49/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0388 - val_loss: 0.0013 - val_mean_absolute_error: 0.0263
# Epoch 50/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0027 - mean_absolute_error: 0.0404 - val_loss: 0.0022 - val_mean_absolute_error: 0.0380
# Epoch 51/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0023 - mean_absolute_error: 0.0366 - val_loss: 0.0062 - val_mean_absolute_error: 0.0709
# Epoch 52/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0026 - mean_absolute_error: 0.0392 - val_loss: 0.0026 - val_mean_absolute_error: 0.0423
# Epoch 53/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0382 - val_loss: 0.0013 - val_mean_absolute_error: 0.0269
# Epoch 54/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0381 - val_loss: 0.0025 - val_mean_absolute_error: 0.0408
# Epoch 55/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0022 - mean_absolute_error: 0.0359 - val_loss: 0.0020 - val_mean_absolute_error: 0.0359
# Epoch 56/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0026 - mean_absolute_error: 0.0393 - val_loss: 0.0015 - val_mean_absolute_error: 0.0301
# Epoch 57/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0357 - val_loss: 0.0019 - val_mean_absolute_error: 0.0345
# Epoch 58/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0022 - mean_absolute_error: 0.0357 - val_loss: 0.0023 - val_mean_absolute_error: 0.0395
# Epoch 59/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0022 - mean_absolute_error: 0.0364 - val_loss: 0.0014 - val_mean_absolute_error: 0.0280
# Epoch 60/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0021 - mean_absolute_error: 0.0362 - val_loss: 0.0020 - val_mean_absolute_error: 0.0364
# Epoch 61/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0019 - mean_absolute_error: 0.0340 - val_loss: 0.0011 - val_mean_absolute_error: 0.0242
# Epoch 62/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0022 - mean_absolute_error: 0.0362 - val_loss: 0.0035 - val_mean_absolute_error: 0.0515
# Epoch 63/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0020 - mean_absolute_error: 0.0348 - val_loss: 0.0028 - val_mean_absolute_error: 0.0451
# Epoch 64/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0354 - val_loss: 0.0017 - val_mean_absolute_error: 0.0327
# Epoch 65/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0345 - val_loss: 0.0015 - val_mean_absolute_error: 0.0293
# Epoch 66/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0347 - val_loss: 0.0021 - val_mean_absolute_error: 0.0377
# Epoch 67/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0354 - val_loss: 0.0023 - val_mean_absolute_error: 0.0390
# Epoch 68/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0347 - val_loss: 0.0053 - val_mean_absolute_error: 0.0657
# Epoch 69/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0352 - val_loss: 0.0011 - val_mean_absolute_error: 0.0237
# Epoch 70/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0330 - val_loss: 0.0019 - val_mean_absolute_error: 0.0346
# Epoch 71/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0314 - val_loss: 0.0010 - val_mean_absolute_error: 0.0231
# Epoch 72/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0341 - val_loss: 0.0051 - val_mean_absolute_error: 0.0647
# Epoch 73/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0372 - val_loss: 0.0023 - val_mean_absolute_error: 0.0401
# Epoch 74/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0019 - mean_absolute_error: 0.0341 - val_loss: 0.0013 - val_mean_absolute_error: 0.0271
# Epoch 75/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0326 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 76/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0344 - val_loss: 0.0011 - val_mean_absolute_error: 0.0242
# Epoch 77/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0341 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
# Epoch 78/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0339 - val_loss: 0.0013 - val_mean_absolute_error: 0.0280
# Epoch 79/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0325 - val_loss: 0.0022 - val_mean_absolute_error: 0.0395
# Epoch 80/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0314 - val_loss: 0.0028 - val_mean_absolute_error: 0.0458
# Epoch 81/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0326 - val_loss: 0.0011 - val_mean_absolute_error: 0.0242
# Epoch 82/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0341 - val_loss: 9.0810e-04 - val_mean_absolute_error: 0.0217
# Epoch 83/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0309 - val_loss: 0.0024 - val_mean_absolute_error: 0.0417
# Epoch 84/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0318 - val_loss: 0.0034 - val_mean_absolute_error: 0.0515
# Epoch 85/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0309 - val_loss: 0.0020 - val_mean_absolute_error: 0.0371
# Epoch 86/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0316 - val_loss: 0.0018 - val_mean_absolute_error: 0.0346
# Epoch 87/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0313 - val_loss: 9.5797e-04 - val_mean_absolute_error: 0.0229
# Epoch 88/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0322 - val_loss: 0.0025 - val_mean_absolute_error: 0.0427
# Epoch 89/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0017 - mean_absolute_error: 0.0325 - val_loss: 0.0012 - val_mean_absolute_error: 0.0266
# Epoch 90/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0303 - val_loss: 0.0017 - val_mean_absolute_error: 0.0337
# Epoch 91/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0312 - val_loss: 0.0031 - val_mean_absolute_error: 0.0487
# Epoch 92/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0282 - val_loss: 0.0040 - val_mean_absolute_error: 0.0564
# Epoch 93/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0318 - val_loss: 9.3970e-04 - val_mean_absolute_error: 0.0230
# Epoch 94/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0288 - val_loss: 0.0012 - val_mean_absolute_error: 0.0267
# Epoch 95/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0307 - val_loss: 0.0012 - val_mean_absolute_error: 0.0277
# Epoch 96/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0014 - mean_absolute_error: 0.0288 - val_loss: 9.2253e-04 - val_mean_absolute_error: 0.0229
# Epoch 97/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0015 - mean_absolute_error: 0.0293 - val_loss: 8.1354e-04 - val_mean_absolute_error: 0.0205
# Epoch 98/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0016 - mean_absolute_error: 0.0314 - val_loss: 8.6451e-04 - val_mean_absolute_error: 0.0218
# Epoch 99/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0014 - mean_absolute_error: 0.0283 - val_loss: 0.0021 - val_mean_absolute_error: 0.0382
# Epoch 100/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0281 - val_loss: 0.0020 - val_mean_absolute_error: 0.0372
# Epoch 101/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0015 - mean_absolute_error: 0.0302 - val_loss: 0.0019 - val_mean_absolute_error: 0.0361
# Epoch 102/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0304 - val_loss: 0.0038 - val_mean_absolute_error: 0.0557
# Epoch 103/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0302 - val_loss: 0.0028 - val_mean_absolute_error: 0.0465
# Epoch 104/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0305 - val_loss: 0.0032 - val_mean_absolute_error: 0.0502
# Epoch 105/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0288 - val_loss: 0.0031 - val_mean_absolute_error: 0.0494
# Epoch 106/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0280 - val_loss: 0.0016 - val_mean_absolute_error: 0.0327
# Epoch 107/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0289 - val_loss: 0.0019 - val_mean_absolute_error: 0.0370
# Epoch 108/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0278 - val_loss: 9.1309e-04 - val_mean_absolute_error: 0.0232
# Epoch 109/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0269 - val_loss: 9.0427e-04 - val_mean_absolute_error: 0.0231
# Epoch 110/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0281 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265
# Epoch 111/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0276 - val_loss: 7.1367e-04 - val_mean_absolute_error: 0.0190
# Epoch 112/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0286 - val_loss: 7.0948e-04 - val_mean_absolute_error: 0.0189
# Epoch 113/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0282 - val_loss: 0.0012 - val_mean_absolute_error: 0.0272
# Epoch 114/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0261 - val_loss: 8.5444e-04 - val_mean_absolute_error: 0.0223
# Epoch 115/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0281 - val_loss: 0.0017 - val_mean_absolute_error: 0.0340
# Epoch 116/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0275 - val_loss: 0.0012 - val_mean_absolute_error: 0.0280
# Epoch 117/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0264 - val_loss: 7.1796e-04 - val_mean_absolute_error: 0.0197
# Epoch 118/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0274 - val_loss: 0.0022 - val_mean_absolute_error: 0.0403
# Epoch 119/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0283 - val_loss: 0.0043 - val_mean_absolute_error: 0.0607
# Epoch 120/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0280 - val_loss: 7.8109e-04 - val_mean_absolute_error: 0.0208
# Epoch 121/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0286 - val_loss: 8.6088e-04 - val_mean_absolute_error: 0.0224
# Epoch 122/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0262 - val_loss: 6.4834e-04 - val_mean_absolute_error: 0.0183
# Epoch 123/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0270 - val_loss: 8.2684e-04 - val_mean_absolute_error: 0.0220
# Epoch 124/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - mean_absolute_error: 0.0262 - val_loss: 6.7539e-04 - val_mean_absolute_error: 0.0192
# Epoch 125/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0285 - val_loss: 6.4032e-04 - val_mean_absolute_error: 0.0182
# Epoch 126/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - mean_absolute_error: 0.0264 - val_loss: 8.9554e-04 - val_mean_absolute_error: 0.0232
# Epoch 127/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0272 - val_loss: 0.0013 - val_mean_absolute_error: 0.0298
# Epoch 128/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0279 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258
# Epoch 129/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - mean_absolute_error: 0.0256 - val_loss: 0.0022 - val_mean_absolute_error: 0.0408
# Epoch 130/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0273 - val_loss: 0.0023 - val_mean_absolute_error: 0.0423
# Epoch 131/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0263 - val_loss: 8.6498e-04 - val_mean_absolute_error: 0.0227
# Epoch 132/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0258 - val_loss: 0.0015 - val_mean_absolute_error: 0.0319
# Epoch 133/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0252 - val_loss: 9.4108e-04 - val_mean_absolute_error: 0.0241
# Epoch 134/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0254 - val_loss: 7.1474e-04 - val_mean_absolute_error: 0.0200
# Epoch 135/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0260 - val_loss: 8.2592e-04 - val_mean_absolute_error: 0.0220
# Epoch 136/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0012 - mean_absolute_error: 0.0259 - val_loss: 5.8742e-04 - val_mean_absolute_error: 0.0173
# Epoch 137/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0253 - val_loss: 5.8471e-04 - val_mean_absolute_error: 0.0174
# Epoch 138/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.7040e-04 - mean_absolute_error: 0.0239 - val_loss: 5.9156e-04 - val_mean_absolute_error: 0.0174
# Epoch 139/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0247 - val_loss: 0.0018 - val_mean_absolute_error: 0.0370
# Epoch 140/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0270 - val_loss: 9.2262e-04 - val_mean_absolute_error: 0.0238
# Epoch 141/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - mean_absolute_error: 0.0259 - val_loss: 6.7854e-04 - val_mean_absolute_error: 0.0193
# Epoch 142/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0010 - mean_absolute_error: 0.0249 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 143/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0010 - mean_absolute_error: 0.0245 - val_loss: 8.2008e-04 - val_mean_absolute_error: 0.0220
# Epoch 144/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0010 - mean_absolute_error: 0.0248 - val_loss: 5.8025e-04 - val_mean_absolute_error: 0.0173
# Epoch 145/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0254 - val_loss: 5.4609e-04 - val_mean_absolute_error: 0.0166
# Epoch 146/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0010 - mean_absolute_error: 0.0245 - val_loss: 6.4545e-04 - val_mean_absolute_error: 0.0189
# Epoch 147/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0010 - mean_absolute_error: 0.0246 - val_loss: 6.1338e-04 - val_mean_absolute_error: 0.0178
# Epoch 148/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0010 - mean_absolute_error: 0.0250 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 149/300
# 24/24 [==============================] - 0s 13ms/step - loss: 9.5379e-04 - mean_absolute_error: 0.0238 - val_loss: 5.5230e-04 - val_mean_absolute_error: 0.0167
# Epoch 150/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.7067e-04 - mean_absolute_error: 0.0241 - val_loss: 6.6256e-04 - val_mean_absolute_error: 0.0190
# Epoch 151/300
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0010 - mean_absolute_error: 0.0249 - val_loss: 5.2796e-04 - val_mean_absolute_error: 0.0161
# Epoch 152/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0266 - val_loss: 6.3484e-04 - val_mean_absolute_error: 0.0184
# Epoch 153/300
# 24/24 [==============================] - 1s 23ms/step - loss: 9.9832e-04 - mean_absolute_error: 0.0244 - val_loss: 8.3768e-04 - val_mean_absolute_error: 0.0224
# Epoch 154/300
# 24/24 [==============================] - 0s 15ms/step - loss: 9.3147e-04 - mean_absolute_error: 0.0234 - val_loss: 5.3041e-04 - val_mean_absolute_error: 0.0161
# Epoch 155/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0010 - mean_absolute_error: 0.0241 - val_loss: 5.2971e-04 - val_mean_absolute_error: 0.0161
# Epoch 156/300
# 24/24 [==============================] - 0s 18ms/step - loss: 9.8423e-04 - mean_absolute_error: 0.0238 - val_loss: 5.7825e-04 - val_mean_absolute_error: 0.0175
# Epoch 157/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.5197e-04 - mean_absolute_error: 0.0242 - val_loss: 5.1084e-04 - val_mean_absolute_error: 0.0157
# Epoch 158/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.8219e-04 - mean_absolute_error: 0.0242 - val_loss: 5.5759e-04 - val_mean_absolute_error: 0.0168
# Epoch 159/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.1420e-04 - mean_absolute_error: 0.0235 - val_loss: 8.2886e-04 - val_mean_absolute_error: 0.0224
# Epoch 160/300
# 24/24 [==============================] - 0s 15ms/step - loss: 8.6489e-04 - mean_absolute_error: 0.0221 - val_loss: 0.0013 - val_mean_absolute_error: 0.0296
# Epoch 161/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.7306e-04 - mean_absolute_error: 0.0230 - val_loss: 7.7046e-04 - val_mean_absolute_error: 0.0212
# Epoch 162/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.2803e-04 - mean_absolute_error: 0.0221 - val_loss: 0.0012 - val_mean_absolute_error: 0.0278
# Epoch 163/300
# 24/24 [==============================] - 0s 13ms/step - loss: 9.8810e-04 - mean_absolute_error: 0.0246 - val_loss: 0.0017 - val_mean_absolute_error: 0.0352
# Epoch 164/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.6188e-04 - mean_absolute_error: 0.0241 - val_loss: 0.0011 - val_mean_absolute_error: 0.0276
# Epoch 165/300
# 24/24 [==============================] - 0s 13ms/step - loss: 9.1149e-04 - mean_absolute_error: 0.0234 - val_loss: 8.0268e-04 - val_mean_absolute_error: 0.0218
# Epoch 166/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.6677e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0011 - val_mean_absolute_error: 0.0264
# Epoch 167/300
# 24/24 [==============================] - 0s 18ms/step - loss: 8.3800e-04 - mean_absolute_error: 0.0221 - val_loss: 0.0010 - val_mean_absolute_error: 0.0256
# Epoch 168/300
# 24/24 [==============================] - 0s 17ms/step - loss: 9.5332e-04 - mean_absolute_error: 0.0239 - val_loss: 4.8909e-04 - val_mean_absolute_error: 0.0153
# Epoch 169/300
# 24/24 [==============================] - 0s 19ms/step - loss: 8.8376e-04 - mean_absolute_error: 0.0230 - val_loss: 7.0241e-04 - val_mean_absolute_error: 0.0199
# Epoch 170/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0258 - val_loss: 5.5354e-04 - val_mean_absolute_error: 0.0168
# Epoch 171/300
# 24/24 [==============================] - 0s 16ms/step - loss: 8.4314e-04 - mean_absolute_error: 0.0224 - val_loss: 0.0012 - val_mean_absolute_error: 0.0279
# Epoch 172/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.6842e-04 - mean_absolute_error: 0.0225 - val_loss: 0.0010 - val_mean_absolute_error: 0.0257
# Epoch 173/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.3184e-04 - mean_absolute_error: 0.0219 - val_loss: 7.4204e-04 - val_mean_absolute_error: 0.0208
# Epoch 174/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.4621e-04 - mean_absolute_error: 0.0224 - val_loss: 5.0979e-04 - val_mean_absolute_error: 0.0157
# Epoch 175/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.9210e-04 - mean_absolute_error: 0.0216 - val_loss: 9.6772e-04 - val_mean_absolute_error: 0.0248
# Epoch 176/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.7392e-04 - mean_absolute_error: 0.0216 - val_loss: 0.0013 - val_mean_absolute_error: 0.0305
# Epoch 177/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.6394e-04 - mean_absolute_error: 0.0224 - val_loss: 7.7170e-04 - val_mean_absolute_error: 0.0213
# Epoch 178/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.9981e-04 - mean_absolute_error: 0.0224 - val_loss: 7.5880e-04 - val_mean_absolute_error: 0.0210
# Epoch 179/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.8737e-04 - mean_absolute_error: 0.0222 - val_loss: 4.7856e-04 - val_mean_absolute_error: 0.0151
# Epoch 180/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.8311e-04 - mean_absolute_error: 0.0231 - val_loss: 5.6025e-04 - val_mean_absolute_error: 0.0170
# Epoch 181/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.5758e-04 - mean_absolute_error: 0.0226 - val_loss: 4.9305e-04 - val_mean_absolute_error: 0.0153
# Epoch 182/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.4075e-04 - mean_absolute_error: 0.0223 - val_loss: 6.6104e-04 - val_mean_absolute_error: 0.0196
# Epoch 183/300
# 24/24 [==============================] - 0s 13ms/step - loss: 9.1021e-04 - mean_absolute_error: 0.0233 - val_loss: 6.2948e-04 - val_mean_absolute_error: 0.0188
# Epoch 184/300
# 24/24 [==============================] - 0s 15ms/step - loss: 8.6428e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0013 - val_mean_absolute_error: 0.0315
# Epoch 185/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.7850e-04 - mean_absolute_error: 0.0225 - val_loss: 5.2141e-04 - val_mean_absolute_error: 0.0162
# Epoch 186/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.2426e-04 - mean_absolute_error: 0.0222 - val_loss: 5.0062e-04 - val_mean_absolute_error: 0.0157
# Epoch 187/300
# 24/24 [==============================] - 0s 15ms/step - loss: 8.5248e-04 - mean_absolute_error: 0.0224 - val_loss: 4.6837e-04 - val_mean_absolute_error: 0.0149
# Epoch 188/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.7406e-04 - mean_absolute_error: 0.0230 - val_loss: 0.0017 - val_mean_absolute_error: 0.0357
# Epoch 189/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0010 - mean_absolute_error: 0.0250 - val_loss: 0.0013 - val_mean_absolute_error: 0.0306
# Epoch 190/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.7207e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0014 - val_mean_absolute_error: 0.0308
# Epoch 191/300
# 24/24 [==============================] - 0s 15ms/step - loss: 7.7401e-04 - mean_absolute_error: 0.0216 - val_loss: 0.0012 - val_mean_absolute_error: 0.0289
# Epoch 192/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.9253e-04 - mean_absolute_error: 0.0216 - val_loss: 5.4167e-04 - val_mean_absolute_error: 0.0167
# Epoch 193/300
# 24/24 [==============================] - 0s 15ms/step - loss: 6.9617e-04 - mean_absolute_error: 0.0207 - val_loss: 4.6798e-04 - val_mean_absolute_error: 0.0150
# Epoch 194/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.9690e-04 - mean_absolute_error: 0.0218 - val_loss: 7.7311e-04 - val_mean_absolute_error: 0.0211
# Epoch 195/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.6995e-04 - mean_absolute_error: 0.0218 - val_loss: 7.9296e-04 - val_mean_absolute_error: 0.0216
# Epoch 196/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.4161e-04 - mean_absolute_error: 0.0225 - val_loss: 0.0021 - val_mean_absolute_error: 0.0411
# Epoch 197/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.6300e-04 - mean_absolute_error: 0.0224 - val_loss: 9.1682e-04 - val_mean_absolute_error: 0.0237
# Epoch 198/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.0449e-04 - mean_absolute_error: 0.0219 - val_loss: 7.6508e-04 - val_mean_absolute_error: 0.0211
# Epoch 199/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.7170e-04 - mean_absolute_error: 0.0214 - val_loss: 4.9303e-04 - val_mean_absolute_error: 0.0156
# Epoch 200/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.6534e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0012 - val_mean_absolute_error: 0.0285
# Epoch 201/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.3366e-04 - mean_absolute_error: 0.0208 - val_loss: 4.7937e-04 - val_mean_absolute_error: 0.0154
# Epoch 202/300
# 24/24 [==============================] - 0s 18ms/step - loss: 9.1269e-04 - mean_absolute_error: 0.0235 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 203/300
# 24/24 [==============================] - 0s 17ms/step - loss: 8.2575e-04 - mean_absolute_error: 0.0223 - val_loss: 0.0010 - val_mean_absolute_error: 0.0253
# Epoch 204/300
# 24/24 [==============================] - 0s 17ms/step - loss: 7.8077e-04 - mean_absolute_error: 0.0215 - val_loss: 9.8650e-04 - val_mean_absolute_error: 0.0249
# Epoch 205/300
# 24/24 [==============================] - 0s 18ms/step - loss: 7.3314e-04 - mean_absolute_error: 0.0211 - val_loss: 6.5442e-04 - val_mean_absolute_error: 0.0192
# Epoch 206/300
# 24/24 [==============================] - 0s 15ms/step - loss: 7.0042e-04 - mean_absolute_error: 0.0205 - val_loss: 4.9819e-04 - val_mean_absolute_error: 0.0161
# Epoch 207/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.6297e-04 - mean_absolute_error: 0.0224 - val_loss: 4.9140e-04 - val_mean_absolute_error: 0.0158
# Epoch 208/300
# 24/24 [==============================] - 0s 13ms/step - loss: 9.0164e-04 - mean_absolute_error: 0.0232 - val_loss: 6.4699e-04 - val_mean_absolute_error: 0.0191
# Epoch 209/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.1306e-04 - mean_absolute_error: 0.0217 - val_loss: 5.1033e-04 - val_mean_absolute_error: 0.0163
# Epoch 210/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.4209e-04 - mean_absolute_error: 0.0208 - val_loss: 4.9438e-04 - val_mean_absolute_error: 0.0158
# Epoch 211/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.1742e-04 - mean_absolute_error: 0.0217 - val_loss: 5.3549e-04 - val_mean_absolute_error: 0.0169
# Epoch 212/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.8929e-04 - mean_absolute_error: 0.0213 - val_loss: 4.6832e-04 - val_mean_absolute_error: 0.0152
# Epoch 213/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.1118e-04 - mean_absolute_error: 0.0225 - val_loss: 9.4202e-04 - val_mean_absolute_error: 0.0240
# Epoch 214/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.3190e-04 - mean_absolute_error: 0.0224 - val_loss: 6.1604e-04 - val_mean_absolute_error: 0.0184
# Epoch 215/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.8520e-04 - mean_absolute_error: 0.0217 - val_loss: 0.0010 - val_mean_absolute_error: 0.0257
# Epoch 216/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.6720e-04 - mean_absolute_error: 0.0212 - val_loss: 5.1667e-04 - val_mean_absolute_error: 0.0165
# Epoch 217/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.6166e-04 - mean_absolute_error: 0.0200 - val_loss: 4.9536e-04 - val_mean_absolute_error: 0.0160
# Epoch 218/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.7674e-04 - mean_absolute_error: 0.0210 - val_loss: 5.3097e-04 - val_mean_absolute_error: 0.0168
# Epoch 219/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.2687e-04 - mean_absolute_error: 0.0209 - val_loss: 5.3525e-04 - val_mean_absolute_error: 0.0166
# Epoch 220/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.7685e-04 - mean_absolute_error: 0.0216 - val_loss: 9.4546e-04 - val_mean_absolute_error: 0.0241
# Epoch 221/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.5677e-04 - mean_absolute_error: 0.0209 - val_loss: 4.7215e-04 - val_mean_absolute_error: 0.0151
# Epoch 222/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.6026e-04 - mean_absolute_error: 0.0212 - val_loss: 5.0631e-04 - val_mean_absolute_error: 0.0161
# Epoch 223/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.0566e-04 - mean_absolute_error: 0.0207 - val_loss: 7.1854e-04 - val_mean_absolute_error: 0.0203
# Epoch 224/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.7677e-04 - mean_absolute_error: 0.0212 - val_loss: 4.9415e-04 - val_mean_absolute_error: 0.0160
# Epoch 225/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.6264e-04 - mean_absolute_error: 0.0212 - val_loss: 6.4961e-04 - val_mean_absolute_error: 0.0191
# Epoch 226/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.0192e-04 - mean_absolute_error: 0.0198 - val_loss: 5.4612e-04 - val_mean_absolute_error: 0.0169
# Epoch 227/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.3148e-04 - mean_absolute_error: 0.0204 - val_loss: 7.0380e-04 - val_mean_absolute_error: 0.0201
# Epoch 228/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.7739e-04 - mean_absolute_error: 0.0215 - val_loss: 8.6073e-04 - val_mean_absolute_error: 0.0228
# Epoch 229/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.5997e-04 - mean_absolute_error: 0.0213 - val_loss: 6.4738e-04 - val_mean_absolute_error: 0.0191
# Epoch 230/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.0454e-04 - mean_absolute_error: 0.0207 - val_loss: 4.7920e-04 - val_mean_absolute_error: 0.0155
# Epoch 231/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.1937e-04 - mean_absolute_error: 0.0219 - val_loss: 4.6942e-04 - val_mean_absolute_error: 0.0153
# Epoch 232/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.0695e-04 - mean_absolute_error: 0.0217 - val_loss: 4.6804e-04 - val_mean_absolute_error: 0.0152
# Epoch 233/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.5828e-04 - mean_absolute_error: 0.0206 - val_loss: 9.1784e-04 - val_mean_absolute_error: 0.0237
# Epoch 234/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.9578e-04 - mean_absolute_error: 0.0230 - val_loss: 5.5144e-04 - val_mean_absolute_error: 0.0173
# Epoch 235/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.1051e-04 - mean_absolute_error: 0.0208 - val_loss: 5.1632e-04 - val_mean_absolute_error: 0.0165
# Epoch 236/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.7411e-04 - mean_absolute_error: 0.0222 - val_loss: 9.8418e-04 - val_mean_absolute_error: 0.0247
# Epoch 237/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.0828e-04 - mean_absolute_error: 0.0206 - val_loss: 8.5899e-04 - val_mean_absolute_error: 0.0228
# Epoch 238/300
# 24/24 [==============================] - 0s 18ms/step - loss: 7.3472e-04 - mean_absolute_error: 0.0209 - val_loss: 8.4722e-04 - val_mean_absolute_error: 0.0226
# Epoch 239/300
# 24/24 [==============================] - 0s 19ms/step - loss: 6.2536e-04 - mean_absolute_error: 0.0191 - val_loss: 4.7584e-04 - val_mean_absolute_error: 0.0154
# Epoch 240/300
# 24/24 [==============================] - 0s 17ms/step - loss: 7.2886e-04 - mean_absolute_error: 0.0203 - val_loss: 0.0017 - val_mean_absolute_error: 0.0362
# Epoch 241/300
# 24/24 [==============================] - 0s 19ms/step - loss: 8.1745e-04 - mean_absolute_error: 0.0217 - val_loss: 0.0030 - val_mean_absolute_error: 0.0510
# Epoch 242/300
# 24/24 [==============================] - 0s 17ms/step - loss: 8.3589e-04 - mean_absolute_error: 0.0224 - val_loss: 5.0715e-04 - val_mean_absolute_error: 0.0163
# Epoch 243/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.2482e-04 - mean_absolute_error: 0.0202 - val_loss: 7.5921e-04 - val_mean_absolute_error: 0.0210
# Epoch 244/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.9941e-04 - mean_absolute_error: 0.0219 - val_loss: 4.9800e-04 - val_mean_absolute_error: 0.0160
# Epoch 245/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.7676e-04 - mean_absolute_error: 0.0198 - val_loss: 4.7190e-04 - val_mean_absolute_error: 0.0154
# Epoch 246/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.8192e-04 - mean_absolute_error: 0.0215 - val_loss: 4.9470e-04 - val_mean_absolute_error: 0.0159
# Epoch 247/300
# 24/24 [==============================] - 0s 15ms/step - loss: 6.6902e-04 - mean_absolute_error: 0.0196 - val_loss: 6.5755e-04 - val_mean_absolute_error: 0.0192
# Epoch 248/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.7417e-04 - mean_absolute_error: 0.0197 - val_loss: 8.0977e-04 - val_mean_absolute_error: 0.0219
# Epoch 249/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.8403e-04 - mean_absolute_error: 0.0215 - val_loss: 0.0021 - val_mean_absolute_error: 0.0412
# Epoch 250/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.8282e-04 - mean_absolute_error: 0.0219 - val_loss: 0.0014 - val_mean_absolute_error: 0.0316
# Epoch 251/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.7573e-04 - mean_absolute_error: 0.0216 - val_loss: 5.8268e-04 - val_mean_absolute_error: 0.0179
# Epoch 252/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.4746e-04 - mean_absolute_error: 0.0213 - val_loss: 6.8012e-04 - val_mean_absolute_error: 0.0197
# Epoch 253/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.4973e-04 - mean_absolute_error: 0.0209 - val_loss: 8.2431e-04 - val_mean_absolute_error: 0.0222
# Epoch 254/300
# 24/24 [==============================] - 0s 15ms/step - loss: 7.0158e-04 - mean_absolute_error: 0.0204 - val_loss: 7.8757e-04 - val_mean_absolute_error: 0.0214
# Epoch 255/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.2533e-04 - mean_absolute_error: 0.0202 - val_loss: 4.7099e-04 - val_mean_absolute_error: 0.0154
# Epoch 256/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.7664e-04 - mean_absolute_error: 0.0214 - val_loss: 8.9212e-04 - val_mean_absolute_error: 0.0231
# Epoch 257/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.3328e-04 - mean_absolute_error: 0.0222 - val_loss: 4.6177e-04 - val_mean_absolute_error: 0.0151
# Epoch 258/300
# 24/24 [==============================] - 0s 12ms/step - loss: 5.9383e-04 - mean_absolute_error: 0.0190 - val_loss: 7.0717e-04 - val_mean_absolute_error: 0.0201
# Epoch 259/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.1028e-04 - mean_absolute_error: 0.0205 - val_loss: 5.1186e-04 - val_mean_absolute_error: 0.0163
# Epoch 260/300
# 24/24 [==============================] - 0s 15ms/step - loss: 6.4302e-04 - mean_absolute_error: 0.0193 - val_loss: 4.6726e-04 - val_mean_absolute_error: 0.0152
# Epoch 261/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.1268e-04 - mean_absolute_error: 0.0203 - val_loss: 6.5041e-04 - val_mean_absolute_error: 0.0191
# Epoch 262/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.4735e-04 - mean_absolute_error: 0.0209 - val_loss: 7.2709e-04 - val_mean_absolute_error: 0.0211
# Epoch 263/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.9754e-04 - mean_absolute_error: 0.0202 - val_loss: 6.3016e-04 - val_mean_absolute_error: 0.0188
# Epoch 264/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.2087e-04 - mean_absolute_error: 0.0204 - val_loss: 4.6605e-04 - val_mean_absolute_error: 0.0152
# Epoch 265/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.6891e-04 - mean_absolute_error: 0.0226 - val_loss: 4.8603e-04 - val_mean_absolute_error: 0.0158
# Epoch 266/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.7143e-04 - mean_absolute_error: 0.0215 - val_loss: 0.0011 - val_mean_absolute_error: 0.0273
# Epoch 267/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.7495e-04 - mean_absolute_error: 0.0215 - val_loss: 4.9754e-04 - val_mean_absolute_error: 0.0159
# Epoch 268/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.0621e-04 - mean_absolute_error: 0.0207 - val_loss: 5.0712e-04 - val_mean_absolute_error: 0.0161
# Epoch 269/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.5566e-04 - mean_absolute_error: 0.0195 - val_loss: 7.7324e-04 - val_mean_absolute_error: 0.0212
# Epoch 270/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.8254e-04 - mean_absolute_error: 0.0201 - val_loss: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 271/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.8432e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0011 - val_mean_absolute_error: 0.0266
# Epoch 272/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.8362e-04 - mean_absolute_error: 0.0219 - val_loss: 9.5362e-04 - val_mean_absolute_error: 0.0242
# Epoch 273/300
# 24/24 [==============================] - 0s 15ms/step - loss: 6.9318e-04 - mean_absolute_error: 0.0204 - val_loss: 4.7032e-04 - val_mean_absolute_error: 0.0154
# Epoch 274/300
# 24/24 [==============================] - 0s 17ms/step - loss: 7.8785e-04 - mean_absolute_error: 0.0216 - val_loss: 0.0010 - val_mean_absolute_error: 0.0257
# Epoch 275/300
# 24/24 [==============================] - 0s 17ms/step - loss: 7.9657e-04 - mean_absolute_error: 0.0216 - val_loss: 5.0690e-04 - val_mean_absolute_error: 0.0162
# Epoch 276/300
# 24/24 [==============================] - 0s 18ms/step - loss: 7.2333e-04 - mean_absolute_error: 0.0207 - val_loss: 0.0013 - val_mean_absolute_error: 0.0301
# Epoch 277/300
# 24/24 [==============================] - 0s 18ms/step - loss: 6.9438e-04 - mean_absolute_error: 0.0202 - val_loss: 6.4987e-04 - val_mean_absolute_error: 0.0192
# Epoch 278/300
# 24/24 [==============================] - 0s 16ms/step - loss: 7.7848e-04 - mean_absolute_error: 0.0216 - val_loss: 4.5678e-04 - val_mean_absolute_error: 0.0151
# Epoch 279/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.1214e-04 - mean_absolute_error: 0.0204 - val_loss: 4.6970e-04 - val_mean_absolute_error: 0.0153
# Epoch 280/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.1068e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0010 - val_mean_absolute_error: 0.0252
# Epoch 281/300
# 24/24 [==============================] - 0s 15ms/step - loss: 6.6430e-04 - mean_absolute_error: 0.0196 - val_loss: 8.7977e-04 - val_mean_absolute_error: 0.0231
# Epoch 282/300
# 24/24 [==============================] - 0s 15ms/step - loss: 6.6135e-04 - mean_absolute_error: 0.0195 - val_loss: 4.7119e-04 - val_mean_absolute_error: 0.0154
# Epoch 283/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.2211e-04 - mean_absolute_error: 0.0208 - val_loss: 8.9061e-04 - val_mean_absolute_error: 0.0232
# Epoch 284/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.2091e-04 - mean_absolute_error: 0.0191 - val_loss: 5.0069e-04 - val_mean_absolute_error: 0.0161
# Epoch 285/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.1889e-04 - mean_absolute_error: 0.0199 - val_loss: 4.6513e-04 - val_mean_absolute_error: 0.0153
# Epoch 286/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.6242e-04 - mean_absolute_error: 0.0196 - val_loss: 5.5281e-04 - val_mean_absolute_error: 0.0173
# Epoch 287/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.9339e-04 - mean_absolute_error: 0.0203 - val_loss: 5.9423e-04 - val_mean_absolute_error: 0.0181
# Epoch 288/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.2483e-04 - mean_absolute_error: 0.0195 - val_loss: 8.4080e-04 - val_mean_absolute_error: 0.0224
# Epoch 289/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.3706e-04 - mean_absolute_error: 0.0208 - val_loss: 8.6426e-04 - val_mean_absolute_error: 0.0227
# Epoch 290/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.1943e-04 - mean_absolute_error: 0.0204 - val_loss: 5.6154e-04 - val_mean_absolute_error: 0.0176
# Epoch 291/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.4579e-04 - mean_absolute_error: 0.0219 - val_loss: 5.1115e-04 - val_mean_absolute_error: 0.0164
# Epoch 292/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.1721e-04 - mean_absolute_error: 0.0202 - val_loss: 4.6206e-04 - val_mean_absolute_error: 0.0151
# Epoch 293/300
# 24/24 [==============================] - 0s 13ms/step - loss: 5.7433e-04 - mean_absolute_error: 0.0185 - val_loss: 6.2043e-04 - val_mean_absolute_error: 0.0186
# Epoch 294/300
# 24/24 [==============================] - 0s 12ms/step - loss: 6.9415e-04 - mean_absolute_error: 0.0203 - val_loss: 5.1734e-04 - val_mean_absolute_error: 0.0164
# Epoch 295/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.8107e-04 - mean_absolute_error: 0.0200 - val_loss: 6.9046e-04 - val_mean_absolute_error: 0.0198
# Epoch 296/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.1747e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0017 - val_mean_absolute_error: 0.0364
# Epoch 297/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.9986e-04 - mean_absolute_error: 0.0203 - val_loss: 6.3602e-04 - val_mean_absolute_error: 0.0189
# Epoch 298/300
# 24/24 [==============================] - 0s 13ms/step - loss: 6.9411e-04 - mean_absolute_error: 0.0200 - val_loss: 0.0014 - val_mean_absolute_error: 0.0313
# Epoch 299/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.0778e-04 - mean_absolute_error: 0.0203 - val_loss: 0.0010 - val_mean_absolute_error: 0.0255
# Epoch 300/300
# 24/24 [==============================] - 0s 15ms/step - loss: 6.9115e-04 - mean_absolute_error: 0.0199 - val_loss: 8.5727e-04 - val_mean_absolute_error: 0.0236

# %%
def make_predictions(model, x_train, x_test):
    train_predict = model.predict(x_train)
    test_predict = model.predict(x_test)
    return train_predict, test_predict

# %%
train_predict, test_predict = make_predictions(model, x_train, x_test)
# Out:
# 24/24 [==============================] - 1s 6ms/step
# 5/5 [==============================] - 0s 6ms/step

# %%
def inverse_transform(scaler, y_train, train_predict, y_test, test_predict):
    train_predict = scaler.inverse_transform(train_predict)
    test_predict = scaler.inverse_transform(test_predict)
    return train_predict, test_predict

# %%
train_predict, test_predict = inverse_transform(scaler, y_train, train_predict, y_test, test_predict)

# %%
def evaluate_model(y_train, train_predict, y_test, test_predict):
    train_rmse = math.sqrt(mean_squared_error(y_train, train_predict))
    test_rmse = math.sqrt(mean_squared_error(y_test, test_predict))
    print(f"Training RMSE: {train_rmse}")
    print(f"Testing RMSE: {test_rmse}")

# %%
evaluate_model(y_train, train_predict, y_test, test_predict)
# Out:
# Training RMSE: 198.09103434267985
# Testing RMSE: 266.2744576387463

# %%
def plot_predictions(original_data, train_predict, test_predict, company_name):
    look_back = 60
    train_predict_plot = np.empty_like(original_data)
    train_predict_plot[:] = np.nan
    train_predict_plot[look_back : len(train_predict) + look_back] = train_predict.flatten()

    test_predict_plot = np.empty_like(original_data)
    test_predict_plot[:] = np.nan
    test_start = len(original_data) - len(test_predict)
    test_predict_plot[test_start:] = test_predict.flatten()

    plt.figure(figsize=(15, 6))
    plt.plot(original_data, color='black', label=f"Actual {company_name} price")
    plt.plot(train_predict_plot, color='red', label=f'Predicted {company_name} price (train_set)')
    plt.plot(test_predict_plot, color='blue', label=f"Predicted {company_name} price (test_set)")
    plt.title(f"{company_name} share price")
    plt.xlabel("Time")
    plt.ylabel(f"{company_name} share price")
    plt.legend()
    plt.show()

# %%
plot_predictions(new_df, train_predict, test_predict, company_name)

# %%
predictions = model.predict(x_test)

actual_values_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))
predicted_values_inverse = scaler.inverse_transform(predictions)

comparison_df = pd.DataFrame({'Actual Close Prices': actual_values_inverse.flatten(), 'Predicted Close Prices': predicted_values_inverse.flatten()})
print(comparison_df.head())

plt.figure(figsize=(10, 5))
plt.plot(actual_values_inverse.flatten(), marker='.', label="Actual Close Prices")
plt.plot(predicted_values_inverse.flatten(), 'r', label="Predicted Close Prices")
plt.ylabel('Close Price')
plt.xlabel('Time Step')
plt.legend()
plt.title('Comparison of Actual vs Predicted Close Prices')
plt.show()
# Out:
# 5/5 [==============================] - 0s 7ms/step
#    Actual Close Prices  Predicted Close Prices
# 0           234.449997              238.375015
# 1           235.029999              236.934525
# 2           237.899994              237.351440
# 3           245.440002              240.914673
# 4           243.320007              249.218842
