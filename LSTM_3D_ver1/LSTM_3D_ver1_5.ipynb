# %%
# !pip install --upgrade mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mplfinance) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mplfinance) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mplfinance) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.10b0

# %%
import numpy as np
import pandas as pd
import math
import random
import datetime as dt
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
from mplfinance.original_flavor import candlestick_ohlc
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import metrics
from sklearn.metrics import mean_squared_error
import yfinance as yf
# Out:
# /usr/local/lib/python3.10/dist-packages/yfinance/base.py:48: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _empty_series = pd.Series()

# %%
# Downloading stock data for Cisco Systems Inc (CSCO) from Yahoo Finance
stock_data = yf.download('CSCO', start='2020-01-01', end='2024-01-01')
specific_df = pd.DataFrame(stock_data).reset_index()
specific_df['Name'] = 'CSCO'
print(specific_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Adj Close    Volume  \
# 0 2020-01-02  48.060001  48.419998  47.880001  48.419998  42.764027  16708100
# 1 2020-01-03  47.910000  48.139999  47.480000  47.630001  42.066311  15577400
# 2 2020-01-06  47.139999  47.820000  47.009998  47.799999  42.216454  22183600
# 3 2020-01-07  47.720001  47.720001  47.099998  47.490002  41.942673  16501900
# 4 2020-01-08  46.970001  47.790001  46.810001  47.520000  41.969162  25175900
#
#    Name
# 0  CSCO
# 1  CSCO
# 2  CSCO
# 3  CSCO
# 4  CSCO

# %%
plt.figure(figsize=(15,6))
plt.plot(specific_df['Date'], specific_df['Close'], marker='.')
plt.title('Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
matplotlib_date = mdates.date2num(specific_df['Date'])
ohlc = np.vstack((matplotlib_date, specific_df['Open'], specific_df['High'], specific_df['Low'], specific_df['Close'])).T
plt.figure(figsize=(15,6))
ax=plt.subplot()
candlestick_ohlc(ax, ohlc, width=0.6, colorup='g', colordown='r')
ax.xaxis_date()
plt.title('Candlestick Chart')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
window = 30
plt.figure(figsize=(15,6))
plt.plot(specific_df['Date'], specific_df['Close'], label='Closing Price', linewidth=2)
plt.plot(specific_df['Date'], specific_df['Close'].rolling(window=window).mean(), label=f'{window}-Day Moving Avg', linestyle='--')
plt.title(f'Closing Prices and {window}-Day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %%
company_name = 'CSCO'
specific_df['Month'] = specific_df['Date'].dt.month
monthly_average = specific_df.groupby('Month')['Close'].mean()

plt.figure(figsize=(15,6))
plt.plot(monthly_average.index, monthly_average.values, marker='o')
plt.title(f'Monthly Seasonality of {company_name}')
plt.xlabel('Months')
plt.ylabel('Average Closing Price')
plt.xticks(range(1,13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %%
new_df = specific_df.reset_index()['Close']
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(np.array(new_df).reshape(-1,1))

# %%
from sklearn.model_selection import train_test_split
test_size = 0.2
train_data, test_data = train_test_split(scaled_data, test_size=test_size, shuffle=False)

# %%
def generate_sequences_and_labels(data, n_past):
    sequences = [data[i - n_past:i, 0] for i in range(n_past, len(data))]
    labels = [data[i, 0] for i in range(n_past, len(data))]
    return np.array(sequences), np.array(labels)

# %%
n_past = 60
x_train, y_train = generate_sequences_and_labels(train_data, n_past)
x_test, y_test = generate_sequences_and_labels(test_data, n_past)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=[input_shape, 1]))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    return model

# %%
def compile_lstm_model(model):
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
def train_lstm_model(model, x_train, y_train, x_test, y_test):
    model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=300, batch_size=32, verbose=1)

# %%
model = build_lstm_model(x_train.shape[1])
compile_lstm_model(model)
train_lstm_model(model, x_train, y_train, x_test, y_test)
# Out:
# Epoch 1/300
# 24/24 [==============================] - 9s 61ms/step - loss: 0.0547 - mean_absolute_error: 0.1713 - val_loss: 0.0048 - val_mean_absolute_error: 0.0533
# Epoch 2/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0095 - mean_absolute_error: 0.0759 - val_loss: 0.0033 - val_mean_absolute_error: 0.0415
# Epoch 3/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0079 - mean_absolute_error: 0.0685 - val_loss: 0.0037 - val_mean_absolute_error: 0.0444
# Epoch 4/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0072 - mean_absolute_error: 0.0663 - val_loss: 0.0031 - val_mean_absolute_error: 0.0457
# Epoch 5/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0061 - mean_absolute_error: 0.0617 - val_loss: 0.0045 - val_mean_absolute_error: 0.0499
# Epoch 6/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0077 - mean_absolute_error: 0.0691 - val_loss: 0.0052 - val_mean_absolute_error: 0.0549
# Epoch 7/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0061 - mean_absolute_error: 0.0607 - val_loss: 0.0030 - val_mean_absolute_error: 0.0392
# Epoch 8/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0070 - mean_absolute_error: 0.0648 - val_loss: 0.0024 - val_mean_absolute_error: 0.0379
# Epoch 9/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0064 - mean_absolute_error: 0.0630 - val_loss: 0.0038 - val_mean_absolute_error: 0.0535
# Epoch 10/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0058 - mean_absolute_error: 0.0599 - val_loss: 0.0038 - val_mean_absolute_error: 0.0540
# Epoch 11/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0060 - mean_absolute_error: 0.0599 - val_loss: 0.0026 - val_mean_absolute_error: 0.0413
# Epoch 12/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0050 - mean_absolute_error: 0.0551 - val_loss: 0.0022 - val_mean_absolute_error: 0.0360
# Epoch 13/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0056 - mean_absolute_error: 0.0571 - val_loss: 0.0060 - val_mean_absolute_error: 0.0706
# Epoch 14/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0064 - mean_absolute_error: 0.0635 - val_loss: 0.0029 - val_mean_absolute_error: 0.0456
# Epoch 15/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0047 - mean_absolute_error: 0.0541 - val_loss: 0.0022 - val_mean_absolute_error: 0.0375
# Epoch 16/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0050 - mean_absolute_error: 0.0531 - val_loss: 0.0025 - val_mean_absolute_error: 0.0408
# Epoch 17/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0046 - mean_absolute_error: 0.0526 - val_loss: 0.0037 - val_mean_absolute_error: 0.0546
# Epoch 18/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0048 - mean_absolute_error: 0.0531 - val_loss: 0.0019 - val_mean_absolute_error: 0.0326
# Epoch 19/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0045 - mean_absolute_error: 0.0525 - val_loss: 0.0025 - val_mean_absolute_error: 0.0414
# Epoch 20/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0047 - mean_absolute_error: 0.0530 - val_loss: 0.0020 - val_mean_absolute_error: 0.0312
# Epoch 21/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0044 - mean_absolute_error: 0.0511 - val_loss: 0.0017 - val_mean_absolute_error: 0.0307
# Epoch 22/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0042 - mean_absolute_error: 0.0504 - val_loss: 0.0025 - val_mean_absolute_error: 0.0417
# Epoch 23/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0041 - mean_absolute_error: 0.0492 - val_loss: 0.0017 - val_mean_absolute_error: 0.0311
# Epoch 24/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0044 - mean_absolute_error: 0.0508 - val_loss: 0.0017 - val_mean_absolute_error: 0.0317
# Epoch 25/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0042 - mean_absolute_error: 0.0504 - val_loss: 0.0024 - val_mean_absolute_error: 0.0347
# Epoch 26/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0045 - mean_absolute_error: 0.0517 - val_loss: 0.0021 - val_mean_absolute_error: 0.0376
# Epoch 27/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0043 - mean_absolute_error: 0.0510 - val_loss: 0.0039 - val_mean_absolute_error: 0.0563
# Epoch 28/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0048 - mean_absolute_error: 0.0541 - val_loss: 0.0036 - val_mean_absolute_error: 0.0532
# Epoch 29/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0046 - mean_absolute_error: 0.0531 - val_loss: 0.0018 - val_mean_absolute_error: 0.0329
# Epoch 30/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0039 - mean_absolute_error: 0.0477 - val_loss: 0.0018 - val_mean_absolute_error: 0.0338
# Epoch 31/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0037 - mean_absolute_error: 0.0471 - val_loss: 0.0032 - val_mean_absolute_error: 0.0491
# Epoch 32/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0040 - mean_absolute_error: 0.0495 - val_loss: 0.0016 - val_mean_absolute_error: 0.0294
# Epoch 33/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0036 - mean_absolute_error: 0.0461 - val_loss: 0.0017 - val_mean_absolute_error: 0.0286
# Epoch 34/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0035 - mean_absolute_error: 0.0460 - val_loss: 0.0018 - val_mean_absolute_error: 0.0330
# Epoch 35/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0035 - mean_absolute_error: 0.0452 - val_loss: 0.0020 - val_mean_absolute_error: 0.0313
# Epoch 36/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0039 - mean_absolute_error: 0.0478 - val_loss: 0.0017 - val_mean_absolute_error: 0.0327
# Epoch 37/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0035 - mean_absolute_error: 0.0450 - val_loss: 0.0015 - val_mean_absolute_error: 0.0285
# Epoch 38/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0041 - mean_absolute_error: 0.0488 - val_loss: 0.0019 - val_mean_absolute_error: 0.0309
# Epoch 39/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0038 - mean_absolute_error: 0.0476 - val_loss: 0.0015 - val_mean_absolute_error: 0.0269
# Epoch 40/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0038 - mean_absolute_error: 0.0469 - val_loss: 0.0018 - val_mean_absolute_error: 0.0341
# Epoch 41/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0033 - mean_absolute_error: 0.0442 - val_loss: 0.0015 - val_mean_absolute_error: 0.0273
# Epoch 42/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0036 - mean_absolute_error: 0.0464 - val_loss: 0.0015 - val_mean_absolute_error: 0.0294
# Epoch 43/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0032 - mean_absolute_error: 0.0442 - val_loss: 0.0014 - val_mean_absolute_error: 0.0265
# Epoch 44/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0035 - mean_absolute_error: 0.0450 - val_loss: 0.0016 - val_mean_absolute_error: 0.0304
# Epoch 45/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0035 - mean_absolute_error: 0.0459 - val_loss: 0.0027 - val_mean_absolute_error: 0.0450
# Epoch 46/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0033 - mean_absolute_error: 0.0443 - val_loss: 0.0014 - val_mean_absolute_error: 0.0282
# Epoch 47/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0034 - mean_absolute_error: 0.0447 - val_loss: 0.0014 - val_mean_absolute_error: 0.0284
# Epoch 48/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0038 - mean_absolute_error: 0.0488 - val_loss: 0.0020 - val_mean_absolute_error: 0.0373
# Epoch 49/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0035 - mean_absolute_error: 0.0451 - val_loss: 0.0016 - val_mean_absolute_error: 0.0306
# Epoch 50/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0032 - mean_absolute_error: 0.0435 - val_loss: 0.0013 - val_mean_absolute_error: 0.0255
# Epoch 51/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0031 - mean_absolute_error: 0.0420 - val_loss: 0.0013 - val_mean_absolute_error: 0.0260
# Epoch 52/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0034 - mean_absolute_error: 0.0445 - val_loss: 0.0026 - val_mean_absolute_error: 0.0442
# Epoch 53/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0035 - mean_absolute_error: 0.0453 - val_loss: 0.0018 - val_mean_absolute_error: 0.0349
# Epoch 54/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0032 - mean_absolute_error: 0.0438 - val_loss: 0.0013 - val_mean_absolute_error: 0.0250
# Epoch 55/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0031 - mean_absolute_error: 0.0420 - val_loss: 0.0021 - val_mean_absolute_error: 0.0388
# Epoch 56/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0031 - mean_absolute_error: 0.0422 - val_loss: 0.0013 - val_mean_absolute_error: 0.0262
# Epoch 57/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0033 - mean_absolute_error: 0.0435 - val_loss: 0.0015 - val_mean_absolute_error: 0.0270
# Epoch 58/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0035 - mean_absolute_error: 0.0447 - val_loss: 0.0013 - val_mean_absolute_error: 0.0254
# Epoch 59/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0033 - mean_absolute_error: 0.0447 - val_loss: 0.0012 - val_mean_absolute_error: 0.0243
# Epoch 60/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0029 - mean_absolute_error: 0.0412 - val_loss: 0.0015 - val_mean_absolute_error: 0.0312
# Epoch 61/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0034 - mean_absolute_error: 0.0437 - val_loss: 0.0027 - val_mean_absolute_error: 0.0463
# Epoch 62/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0030 - mean_absolute_error: 0.0419 - val_loss: 0.0012 - val_mean_absolute_error: 0.0257
# Epoch 63/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0030 - mean_absolute_error: 0.0418 - val_loss: 0.0012 - val_mean_absolute_error: 0.0261
# Epoch 64/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0030 - mean_absolute_error: 0.0422 - val_loss: 0.0015 - val_mean_absolute_error: 0.0275
# Epoch 65/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0422 - val_loss: 0.0012 - val_mean_absolute_error: 0.0244
# Epoch 66/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0031 - mean_absolute_error: 0.0420 - val_loss: 0.0012 - val_mean_absolute_error: 0.0242
# Epoch 67/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0027 - mean_absolute_error: 0.0396 - val_loss: 0.0012 - val_mean_absolute_error: 0.0249
# Epoch 68/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0026 - mean_absolute_error: 0.0391 - val_loss: 0.0015 - val_mean_absolute_error: 0.0312
# Epoch 69/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0028 - mean_absolute_error: 0.0402 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 70/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0375 - val_loss: 0.0011 - val_mean_absolute_error: 0.0245
# Epoch 71/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0027 - mean_absolute_error: 0.0394 - val_loss: 0.0027 - val_mean_absolute_error: 0.0458
# Epoch 72/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0027 - mean_absolute_error: 0.0402 - val_loss: 0.0011 - val_mean_absolute_error: 0.0235
# Epoch 73/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0028 - mean_absolute_error: 0.0399 - val_loss: 0.0013 - val_mean_absolute_error: 0.0284
# Epoch 74/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0027 - mean_absolute_error: 0.0400 - val_loss: 0.0014 - val_mean_absolute_error: 0.0300
# Epoch 75/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0026 - mean_absolute_error: 0.0389 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 76/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0028 - mean_absolute_error: 0.0400 - val_loss: 0.0011 - val_mean_absolute_error: 0.0241
# Epoch 77/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0027 - mean_absolute_error: 0.0393 - val_loss: 0.0010 - val_mean_absolute_error: 0.0230
# Epoch 78/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0378 - val_loss: 0.0011 - val_mean_absolute_error: 0.0228
# Epoch 79/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0024 - mean_absolute_error: 0.0382 - val_loss: 0.0012 - val_mean_absolute_error: 0.0237
# Epoch 80/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0025 - mean_absolute_error: 0.0378 - val_loss: 0.0010 - val_mean_absolute_error: 0.0231
# Epoch 81/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0024 - mean_absolute_error: 0.0375 - val_loss: 0.0010 - val_mean_absolute_error: 0.0223
# Epoch 82/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0385 - val_loss: 0.0013 - val_mean_absolute_error: 0.0254
# Epoch 83/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0378 - val_loss: 0.0010 - val_mean_absolute_error: 0.0224
# Epoch 84/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0372 - val_loss: 9.8660e-04 - val_mean_absolute_error: 0.0229
# Epoch 85/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0025 - mean_absolute_error: 0.0386 - val_loss: 0.0010 - val_mean_absolute_error: 0.0242
# Epoch 86/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0370 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 87/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0023 - mean_absolute_error: 0.0367 - val_loss: 0.0011 - val_mean_absolute_error: 0.0260
# Epoch 88/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0024 - mean_absolute_error: 0.0369 - val_loss: 8.9953e-04 - val_mean_absolute_error: 0.0210
# Epoch 89/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0024 - mean_absolute_error: 0.0372 - val_loss: 8.9898e-04 - val_mean_absolute_error: 0.0210
# Epoch 90/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0022 - mean_absolute_error: 0.0366 - val_loss: 0.0015 - val_mean_absolute_error: 0.0278
# Epoch 91/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0021 - mean_absolute_error: 0.0350 - val_loss: 0.0012 - val_mean_absolute_error: 0.0248
# Epoch 92/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0025 - mean_absolute_error: 0.0374 - val_loss: 9.1853e-04 - val_mean_absolute_error: 0.0220
# Epoch 93/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0023 - mean_absolute_error: 0.0364 - val_loss: 0.0016 - val_mean_absolute_error: 0.0332
# Epoch 94/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0023 - mean_absolute_error: 0.0368 - val_loss: 0.0015 - val_mean_absolute_error: 0.0329
# Epoch 95/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0024 - mean_absolute_error: 0.0376 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 96/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0348 - val_loss: 8.4297e-04 - val_mean_absolute_error: 0.0205
# Epoch 97/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0023 - mean_absolute_error: 0.0354 - val_loss: 8.2153e-04 - val_mean_absolute_error: 0.0198
# Epoch 98/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0349 - val_loss: 8.2482e-04 - val_mean_absolute_error: 0.0204
# Epoch 99/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0341 - val_loss: 8.3581e-04 - val_mean_absolute_error: 0.0200
# Epoch 100/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0343 - val_loss: 0.0010 - val_mean_absolute_error: 0.0224
# Epoch 101/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0346 - val_loss: 9.3346e-04 - val_mean_absolute_error: 0.0213
# Epoch 102/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0022 - mean_absolute_error: 0.0353 - val_loss: 9.7564e-04 - val_mean_absolute_error: 0.0220
# Epoch 103/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0344 - val_loss: 8.8863e-04 - val_mean_absolute_error: 0.0207
# Epoch 104/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0340 - val_loss: 7.9688e-04 - val_mean_absolute_error: 0.0198
# Epoch 105/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0334 - val_loss: 0.0012 - val_mean_absolute_error: 0.0246
# Epoch 106/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0341 - val_loss: 7.8219e-04 - val_mean_absolute_error: 0.0191
# Epoch 107/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0022 - mean_absolute_error: 0.0354 - val_loss: 0.0019 - val_mean_absolute_error: 0.0376
# Epoch 108/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0331 - val_loss: 8.5992e-04 - val_mean_absolute_error: 0.0213
# Epoch 109/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0331 - val_loss: 0.0012 - val_mean_absolute_error: 0.0243
# Epoch 110/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0022 - mean_absolute_error: 0.0346 - val_loss: 9.1312e-04 - val_mean_absolute_error: 0.0210
# Epoch 111/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0335 - val_loss: 0.0010 - val_mean_absolute_error: 0.0224
# Epoch 112/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0328 - val_loss: 0.0011 - val_mean_absolute_error: 0.0231
# Epoch 113/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0332 - val_loss: 7.5598e-04 - val_mean_absolute_error: 0.0190
# Epoch 114/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0326 - val_loss: 8.6777e-04 - val_mean_absolute_error: 0.0203
# Epoch 115/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0022 - mean_absolute_error: 0.0348 - val_loss: 9.9276e-04 - val_mean_absolute_error: 0.0220
# Epoch 116/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0328 - val_loss: 8.3698e-04 - val_mean_absolute_error: 0.0199
# Epoch 117/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0331 - val_loss: 8.6632e-04 - val_mean_absolute_error: 0.0203
# Epoch 118/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0316 - val_loss: 7.3774e-04 - val_mean_absolute_error: 0.0187
# Epoch 119/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0019 - mean_absolute_error: 0.0321 - val_loss: 8.1479e-04 - val_mean_absolute_error: 0.0206
# Epoch 120/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0016 - mean_absolute_error: 0.0298 - val_loss: 7.1647e-04 - val_mean_absolute_error: 0.0184
# Epoch 121/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0019 - mean_absolute_error: 0.0312 - val_loss: 9.6248e-04 - val_mean_absolute_error: 0.0239
# Epoch 122/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0320 - val_loss: 8.3530e-04 - val_mean_absolute_error: 0.0198
# Epoch 123/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0308 - val_loss: 8.7072e-04 - val_mean_absolute_error: 0.0202
# Epoch 124/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0326 - val_loss: 7.1762e-04 - val_mean_absolute_error: 0.0187
# Epoch 125/300
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0016 - mean_absolute_error: 0.0302 - val_loss: 7.4349e-04 - val_mean_absolute_error: 0.0186
# Epoch 126/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0302 - val_loss: 7.1903e-04 - val_mean_absolute_error: 0.0186
# Epoch 127/300
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0016 - mean_absolute_error: 0.0297 - val_loss: 7.9637e-04 - val_mean_absolute_error: 0.0206
# Epoch 128/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0318 - val_loss: 0.0012 - val_mean_absolute_error: 0.0249
# Epoch 129/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0317 - val_loss: 6.9795e-04 - val_mean_absolute_error: 0.0182
# Epoch 130/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0015 - mean_absolute_error: 0.0292 - val_loss: 6.8079e-04 - val_mean_absolute_error: 0.0179
# Epoch 131/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0301 - val_loss: 7.4777e-04 - val_mean_absolute_error: 0.0183
# Epoch 132/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - val_loss: 8.3039e-04 - val_mean_absolute_error: 0.0195
# Epoch 133/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0300 - val_loss: 6.8691e-04 - val_mean_absolute_error: 0.0182
# Epoch 134/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0299 - val_loss: 7.9939e-04 - val_mean_absolute_error: 0.0210
# Epoch 135/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0314 - val_loss: 6.5632e-04 - val_mean_absolute_error: 0.0174
# Epoch 136/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0291 - val_loss: 7.0772e-04 - val_mean_absolute_error: 0.0189
# Epoch 137/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0294 - val_loss: 6.7034e-04 - val_mean_absolute_error: 0.0179
# Epoch 138/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0017 - mean_absolute_error: 0.0309 - val_loss: 8.0090e-04 - val_mean_absolute_error: 0.0212
# Epoch 139/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0282 - val_loss: 8.6859e-04 - val_mean_absolute_error: 0.0227
# Epoch 140/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0297 - val_loss: 6.4092e-04 - val_mean_absolute_error: 0.0172
# Epoch 141/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0016 - mean_absolute_error: 0.0287 - val_loss: 6.9855e-04 - val_mean_absolute_error: 0.0188
# Epoch 142/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0281 - val_loss: 6.7379e-04 - val_mean_absolute_error: 0.0174
# Epoch 143/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0290 - val_loss: 6.9696e-04 - val_mean_absolute_error: 0.0178
# Epoch 144/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0280 - val_loss: 6.3541e-04 - val_mean_absolute_error: 0.0170
# Epoch 145/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0276 - val_loss: 6.3317e-04 - val_mean_absolute_error: 0.0172
# Epoch 146/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0285 - val_loss: 8.2086e-04 - val_mean_absolute_error: 0.0218
# Epoch 147/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0302 - val_loss: 7.7585e-04 - val_mean_absolute_error: 0.0209
# Epoch 148/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0268 - val_loss: 7.1529e-04 - val_mean_absolute_error: 0.0193
# Epoch 149/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0288 - val_loss: 7.0740e-04 - val_mean_absolute_error: 0.0192
# Epoch 150/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0014 - mean_absolute_error: 0.0279 - val_loss: 6.0459e-04 - val_mean_absolute_error: 0.0166
# Epoch 151/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0015 - mean_absolute_error: 0.0287 - val_loss: 5.9312e-04 - val_mean_absolute_error: 0.0164
# Epoch 152/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0276 - val_loss: 7.4951e-04 - val_mean_absolute_error: 0.0183
# Epoch 153/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0015 - mean_absolute_error: 0.0286 - val_loss: 6.1803e-04 - val_mean_absolute_error: 0.0164
# Epoch 154/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0015 - mean_absolute_error: 0.0287 - val_loss: 5.8725e-04 - val_mean_absolute_error: 0.0161
# Epoch 155/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0279 - val_loss: 5.8689e-04 - val_mean_absolute_error: 0.0162
# Epoch 156/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0290 - val_loss: 6.1450e-04 - val_mean_absolute_error: 0.0172
# Epoch 157/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0268 - val_loss: 7.3627e-04 - val_mean_absolute_error: 0.0201
# Epoch 158/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0277 - val_loss: 7.8309e-04 - val_mean_absolute_error: 0.0213
# Epoch 159/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0280 - val_loss: 7.0606e-04 - val_mean_absolute_error: 0.0195
# Epoch 160/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0274 - val_loss: 6.2194e-04 - val_mean_absolute_error: 0.0173
# Epoch 161/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0015 - mean_absolute_error: 0.0295 - val_loss: 6.0493e-04 - val_mean_absolute_error: 0.0169
# Epoch 162/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0282 - val_loss: 5.6447e-04 - val_mean_absolute_error: 0.0158
# Epoch 163/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0271 - val_loss: 5.6453e-04 - val_mean_absolute_error: 0.0159
# Epoch 164/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0286 - val_loss: 7.1398e-04 - val_mean_absolute_error: 0.0200
# Epoch 165/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0276 - val_loss: 0.0013 - val_mean_absolute_error: 0.0311
# Epoch 166/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0282 - val_loss: 6.0189e-04 - val_mean_absolute_error: 0.0170
# Epoch 167/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0268 - val_loss: 6.2354e-04 - val_mean_absolute_error: 0.0177
# Epoch 168/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0269 - val_loss: 5.3667e-04 - val_mean_absolute_error: 0.0149
# Epoch 169/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0266 - val_loss: 5.4596e-04 - val_mean_absolute_error: 0.0154
# Epoch 170/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0276 - val_loss: 5.3993e-04 - val_mean_absolute_error: 0.0153
# Epoch 171/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0269 - val_loss: 5.3033e-04 - val_mean_absolute_error: 0.0151
# Epoch 172/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0255 - val_loss: 8.0565e-04 - val_mean_absolute_error: 0.0194
# Epoch 173/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0267 - val_loss: 5.3820e-04 - val_mean_absolute_error: 0.0153
# Epoch 174/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0014 - mean_absolute_error: 0.0278 - val_loss: 5.6046e-04 - val_mean_absolute_error: 0.0155
# Epoch 175/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0257 - val_loss: 5.4221e-04 - val_mean_absolute_error: 0.0156
# Epoch 176/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0259 - val_loss: 6.2663e-04 - val_mean_absolute_error: 0.0179
# Epoch 177/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0280 - val_loss: 5.6659e-04 - val_mean_absolute_error: 0.0162
# Epoch 178/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0260 - val_loss: 5.4798e-04 - val_mean_absolute_error: 0.0155
# Epoch 179/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0256 - val_loss: 6.5247e-04 - val_mean_absolute_error: 0.0186
# Epoch 180/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0260 - val_loss: 5.4731e-04 - val_mean_absolute_error: 0.0158
# Epoch 181/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0274 - val_loss: 7.0255e-04 - val_mean_absolute_error: 0.0175
# Epoch 182/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0268 - val_loss: 5.2728e-04 - val_mean_absolute_error: 0.0153
# Epoch 183/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0253 - val_loss: 5.1474e-04 - val_mean_absolute_error: 0.0146
# Epoch 184/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0248 - val_loss: 5.6657e-04 - val_mean_absolute_error: 0.0164
# Epoch 185/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0274 - val_loss: 0.0010 - val_mean_absolute_error: 0.0273
# Epoch 186/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0275 - val_loss: 7.0861e-04 - val_mean_absolute_error: 0.0204
# Epoch 187/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0013 - mean_absolute_error: 0.0267 - val_loss: 7.2630e-04 - val_mean_absolute_error: 0.0207
# Epoch 188/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0266 - val_loss: 5.2203e-04 - val_mean_absolute_error: 0.0152
# Epoch 189/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0013 - mean_absolute_error: 0.0265 - val_loss: 5.5550e-04 - val_mean_absolute_error: 0.0154
# Epoch 190/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0261 - val_loss: 5.7809e-04 - val_mean_absolute_error: 0.0156
# Epoch 191/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0271 - val_loss: 5.6272e-04 - val_mean_absolute_error: 0.0154
# Epoch 192/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0247 - val_loss: 5.3292e-04 - val_mean_absolute_error: 0.0153
# Epoch 193/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0255 - val_loss: 5.1951e-04 - val_mean_absolute_error: 0.0152
# Epoch 194/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0252 - val_loss: 5.0744e-04 - val_mean_absolute_error: 0.0148
# Epoch 195/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0246 - val_loss: 5.3494e-04 - val_mean_absolute_error: 0.0156
# Epoch 196/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0279 - val_loss: 5.4468e-04 - val_mean_absolute_error: 0.0159
# Epoch 197/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0269 - val_loss: 7.8564e-04 - val_mean_absolute_error: 0.0222
# Epoch 198/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0250 - val_loss: 8.0908e-04 - val_mean_absolute_error: 0.0228
# Epoch 199/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0253 - val_loss: 7.3687e-04 - val_mean_absolute_error: 0.0211
# Epoch 200/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0275 - val_loss: 9.8534e-04 - val_mean_absolute_error: 0.0262
# Epoch 201/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0283 - val_loss: 6.9715e-04 - val_mean_absolute_error: 0.0200
# Epoch 202/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0297 - val_loss: 8.0390e-04 - val_mean_absolute_error: 0.0227
# Epoch 203/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0245 - val_loss: 5.2930e-04 - val_mean_absolute_error: 0.0155
# Epoch 204/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0254 - val_loss: 6.0115e-04 - val_mean_absolute_error: 0.0175
# Epoch 205/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0268 - val_loss: 5.0137e-04 - val_mean_absolute_error: 0.0146
# Epoch 206/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0262 - val_loss: 8.6417e-04 - val_mean_absolute_error: 0.0206
# Epoch 207/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0263 - val_loss: 5.7435e-04 - val_mean_absolute_error: 0.0168
# Epoch 208/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0250 - val_loss: 5.7444e-04 - val_mean_absolute_error: 0.0157
# Epoch 209/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0256 - val_loss: 7.2017e-04 - val_mean_absolute_error: 0.0180
# Epoch 210/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0253 - val_loss: 5.1726e-04 - val_mean_absolute_error: 0.0151
# Epoch 211/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0258 - val_loss: 5.5729e-04 - val_mean_absolute_error: 0.0164
# Epoch 212/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0250 - val_loss: 5.9492e-04 - val_mean_absolute_error: 0.0159
# Epoch 213/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0257 - val_loss: 5.0684e-04 - val_mean_absolute_error: 0.0145
# Epoch 214/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0258 - val_loss: 5.4450e-04 - val_mean_absolute_error: 0.0159
# Epoch 215/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0255 - val_loss: 6.9138e-04 - val_mean_absolute_error: 0.0200
# Epoch 216/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0269 - val_loss: 7.7600e-04 - val_mean_absolute_error: 0.0221
# Epoch 217/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0254 - val_loss: 5.5425e-04 - val_mean_absolute_error: 0.0162
# Epoch 218/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0265 - val_loss: 5.1660e-04 - val_mean_absolute_error: 0.0150
# Epoch 219/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0265 - val_loss: 5.7706e-04 - val_mean_absolute_error: 0.0169
# Epoch 220/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0265 - val_loss: 5.0829e-04 - val_mean_absolute_error: 0.0148
# Epoch 221/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0264 - val_loss: 6.4147e-04 - val_mean_absolute_error: 0.0166
# Epoch 222/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0012 - mean_absolute_error: 0.0257 - val_loss: 5.3063e-04 - val_mean_absolute_error: 0.0152
# Epoch 223/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0258 - val_loss: 5.2860e-04 - val_mean_absolute_error: 0.0155
# Epoch 224/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0247 - val_loss: 5.7063e-04 - val_mean_absolute_error: 0.0167
# Epoch 225/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0011 - mean_absolute_error: 0.0244 - val_loss: 5.1034e-04 - val_mean_absolute_error: 0.0150
# Epoch 226/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0012 - mean_absolute_error: 0.0253 - val_loss: 5.3302e-04 - val_mean_absolute_error: 0.0156
# Epoch 227/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0252 - val_loss: 6.3595e-04 - val_mean_absolute_error: 0.0165
# Epoch 228/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0252 - val_loss: 5.4850e-04 - val_mean_absolute_error: 0.0152
# Epoch 229/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0248 - val_loss: 7.2443e-04 - val_mean_absolute_error: 0.0180
# Epoch 230/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0255 - val_loss: 5.6120e-04 - val_mean_absolute_error: 0.0154
# Epoch 231/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - mean_absolute_error: 0.0251 - val_loss: 5.1867e-04 - val_mean_absolute_error: 0.0148
# Epoch 232/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0243 - val_loss: 5.4523e-04 - val_mean_absolute_error: 0.0153
# Epoch 233/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0241 - val_loss: 5.8204e-04 - val_mean_absolute_error: 0.0170
# Epoch 234/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0012 - mean_absolute_error: 0.0261 - val_loss: 6.2023e-04 - val_mean_absolute_error: 0.0162
# Epoch 235/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0251 - val_loss: 5.8511e-04 - val_mean_absolute_error: 0.0157
# Epoch 236/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0253 - val_loss: 7.6755e-04 - val_mean_absolute_error: 0.0189
# Epoch 237/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0254 - val_loss: 5.0535e-04 - val_mean_absolute_error: 0.0149
# Epoch 238/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0244 - val_loss: 5.4253e-04 - val_mean_absolute_error: 0.0160
# Epoch 239/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0257 - val_loss: 6.4426e-04 - val_mean_absolute_error: 0.0188
# Epoch 240/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0011 - mean_absolute_error: 0.0234 - val_loss: 5.1356e-04 - val_mean_absolute_error: 0.0150
# Epoch 241/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0261 - val_loss: 5.7524e-04 - val_mean_absolute_error: 0.0169
# Epoch 242/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0010 - mean_absolute_error: 0.0240 - val_loss: 6.4251e-04 - val_mean_absolute_error: 0.0187
# Epoch 243/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0243 - val_loss: 5.1373e-04 - val_mean_absolute_error: 0.0150
# Epoch 244/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0256 - val_loss: 5.0474e-04 - val_mean_absolute_error: 0.0145
# Epoch 245/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0254 - val_loss: 6.8085e-04 - val_mean_absolute_error: 0.0198
# Epoch 246/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0013 - mean_absolute_error: 0.0272 - val_loss: 0.0011 - val_mean_absolute_error: 0.0291
# Epoch 247/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0276 - val_loss: 5.4775e-04 - val_mean_absolute_error: 0.0160
# Epoch 248/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0241 - val_loss: 5.4671e-04 - val_mean_absolute_error: 0.0160
# Epoch 249/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0245 - val_loss: 5.3885e-04 - val_mean_absolute_error: 0.0150
# Epoch 250/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0251 - val_loss: 5.3804e-04 - val_mean_absolute_error: 0.0157
# Epoch 251/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0013 - mean_absolute_error: 0.0271 - val_loss: 6.4429e-04 - val_mean_absolute_error: 0.0187
# Epoch 252/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0254 - val_loss: 9.9302e-04 - val_mean_absolute_error: 0.0263
# Epoch 253/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0259 - val_loss: 5.1767e-04 - val_mean_absolute_error: 0.0149
# Epoch 254/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0247 - val_loss: 5.4123e-04 - val_mean_absolute_error: 0.0160
# Epoch 255/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0261 - val_loss: 5.0532e-04 - val_mean_absolute_error: 0.0147
# Epoch 256/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0242 - val_loss: 5.9625e-04 - val_mean_absolute_error: 0.0175
# Epoch 257/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0253 - val_loss: 5.1821e-04 - val_mean_absolute_error: 0.0152
# Epoch 258/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0011 - mean_absolute_error: 0.0250 - val_loss: 5.4204e-04 - val_mean_absolute_error: 0.0155
# Epoch 259/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0010 - mean_absolute_error: 0.0240 - val_loss: 5.9095e-04 - val_mean_absolute_error: 0.0173
# Epoch 260/300
# 24/24 [==============================] - 0s 19ms/step - loss: 9.9202e-04 - mean_absolute_error: 0.0234 - val_loss: 7.6046e-04 - val_mean_absolute_error: 0.0185
# Epoch 261/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0011 - mean_absolute_error: 0.0245 - val_loss: 5.5183e-04 - val_mean_absolute_error: 0.0163
# Epoch 262/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0249 - val_loss: 5.5380e-04 - val_mean_absolute_error: 0.0163
# Epoch 263/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0245 - val_loss: 6.1917e-04 - val_mean_absolute_error: 0.0182
# Epoch 264/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0248 - val_loss: 5.0333e-04 - val_mean_absolute_error: 0.0149
# Epoch 265/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0251 - val_loss: 5.6682e-04 - val_mean_absolute_error: 0.0155
# Epoch 266/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0010 - mean_absolute_error: 0.0240 - val_loss: 6.3122e-04 - val_mean_absolute_error: 0.0164
# Epoch 267/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0010 - mean_absolute_error: 0.0236 - val_loss: 5.3150e-04 - val_mean_absolute_error: 0.0151
# Epoch 268/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0241 - val_loss: 5.0669e-04 - val_mean_absolute_error: 0.0148
# Epoch 269/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0258 - val_loss: 5.2130e-04 - val_mean_absolute_error: 0.0153
# Epoch 270/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0010 - mean_absolute_error: 0.0238 - val_loss: 5.0868e-04 - val_mean_absolute_error: 0.0150
# Epoch 271/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0252 - val_loss: 5.4528e-04 - val_mean_absolute_error: 0.0161
# Epoch 272/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0246 - val_loss: 5.1663e-04 - val_mean_absolute_error: 0.0152
# Epoch 273/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0010 - mean_absolute_error: 0.0245 - val_loss: 8.1458e-04 - val_mean_absolute_error: 0.0229
# Epoch 274/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0248 - val_loss: 5.9449e-04 - val_mean_absolute_error: 0.0159
# Epoch 275/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0012 - mean_absolute_error: 0.0264 - val_loss: 5.2386e-04 - val_mean_absolute_error: 0.0154
# Epoch 276/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0254 - val_loss: 5.5523e-04 - val_mean_absolute_error: 0.0163
# Epoch 277/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0250 - val_loss: 4.9815e-04 - val_mean_absolute_error: 0.0145
# Epoch 278/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0248 - val_loss: 5.3947e-04 - val_mean_absolute_error: 0.0156
# Epoch 279/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0011 - mean_absolute_error: 0.0247 - val_loss: 5.1513e-04 - val_mean_absolute_error: 0.0151
# Epoch 280/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0011 - mean_absolute_error: 0.0245 - val_loss: 7.4326e-04 - val_mean_absolute_error: 0.0213
# Epoch 281/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0010 - mean_absolute_error: 0.0240 - val_loss: 5.3499e-04 - val_mean_absolute_error: 0.0150
# Epoch 282/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0247 - val_loss: 5.6999e-04 - val_mean_absolute_error: 0.0167
# Epoch 283/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0246 - val_loss: 5.3397e-04 - val_mean_absolute_error: 0.0157
# Epoch 284/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0242 - val_loss: 7.9761e-04 - val_mean_absolute_error: 0.0224
# Epoch 285/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0250 - val_loss: 5.1124e-04 - val_mean_absolute_error: 0.0145
# Epoch 286/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0246 - val_loss: 5.5836e-04 - val_mean_absolute_error: 0.0166
# Epoch 287/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0264 - val_loss: 0.0014 - val_mean_absolute_error: 0.0331
# Epoch 288/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0257 - val_loss: 5.4827e-04 - val_mean_absolute_error: 0.0155
# Epoch 289/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0241 - val_loss: 5.2433e-04 - val_mean_absolute_error: 0.0155
# Epoch 290/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0251 - val_loss: 5.7511e-04 - val_mean_absolute_error: 0.0156
# Epoch 291/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0248 - val_loss: 8.4029e-04 - val_mean_absolute_error: 0.0199
# Epoch 292/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0248 - val_loss: 5.3220e-04 - val_mean_absolute_error: 0.0149
# Epoch 293/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0011 - mean_absolute_error: 0.0245 - val_loss: 5.1502e-04 - val_mean_absolute_error: 0.0151
# Epoch 294/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0010 - mean_absolute_error: 0.0238 - val_loss: 5.0952e-04 - val_mean_absolute_error: 0.0151
# Epoch 295/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0011 - mean_absolute_error: 0.0244 - val_loss: 5.4736e-04 - val_mean_absolute_error: 0.0161
# Epoch 296/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0010 - mean_absolute_error: 0.0237 - val_loss: 5.5178e-04 - val_mean_absolute_error: 0.0154
# Epoch 297/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0244 - val_loss: 5.3662e-04 - val_mean_absolute_error: 0.0160
# Epoch 298/300
# 24/24 [==============================] - 0s 13ms/step - loss: 9.8924e-04 - mean_absolute_error: 0.0233 - val_loss: 5.0611e-04 - val_mean_absolute_error: 0.0149
# Epoch 299/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0010 - mean_absolute_error: 0.0232 - val_loss: 5.4579e-04 - val_mean_absolute_error: 0.0160
# Epoch 300/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0252 - val_loss: 6.0062e-04 - val_mean_absolute_error: 0.0176

# %%
def make_predictions(model, x_train, x_test):
    train_predict = model.predict(x_train)
    test_predict = model.predict(x_test)
    return train_predict, test_predict

# %%
train_predict, test_predict = make_predictions(model, x_train, x_test)
# Out:
# 24/24 [==============================] - 1s 6ms/step
# 5/5 [==============================] - 0s 6ms/step

# %%
def inverse_transform(scaler, y_train, train_predict, y_test, test_predict):
    train_predict = scaler.inverse_transform(train_predict)
    test_predict = scaler.inverse_transform(test_predict)
    return train_predict, test_predict

# %%
train_predict, test_predict = inverse_transform(scaler, y_train, train_predict, y_test, test_predict)

# %%
def evaluate_model(y_train, train_predict, y_test, test_predict):
    train_rmse = math.sqrt(mean_squared_error(y_train, train_predict))
    test_rmse = math.sqrt(mean_squared_error(y_test, test_predict))
    print(f"Training RMSE: {train_rmse}")
    print(f"Testing RMSE: {test_rmse}")

# %%
evaluate_model(y_train, train_predict, y_test, test_predict)
# Out:
# Training RMSE: 48.29096006339669
# Testing RMSE: 51.45750904893632

# %%
def plot_predictions(original_data, train_predict, test_predict, company_name):
    look_back = 60
    train_predict_plot = np.empty_like(original_data)
    train_predict_plot[:] = np.nan
    train_predict_plot[look_back : len(train_predict) + look_back] = train_predict.flatten()

    test_predict_plot = np.empty_like(original_data)
    test_predict_plot[:] = np.nan
    test_start = len(original_data) - len(test_predict)
    test_predict_plot[test_start:] = test_predict.flatten()

    plt.figure(figsize=(15, 6))
    plt.plot(original_data, color='black', label=f"Actual {company_name} price")
    plt.plot(train_predict_plot, color='red', label=f'Predicted {company_name} price (train_set)')
    plt.plot(test_predict_plot, color='blue', label=f"Predicted {company_name} price (test_set)")
    plt.title(f"{company_name} share price")
    plt.xlabel("Time")
    plt.ylabel(f"{company_name} share price")
    plt.legend()
    plt.show()

# %%
plot_predictions(new_df, train_predict, test_predict, company_name)

# %%
predictions = model.predict(x_test)

actual_values_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))
predicted_values_inverse = scaler.inverse_transform(predictions)

comparison_df = pd.DataFrame({'Actual Close Prices': actual_values_inverse.flatten(), 'Predicted Close Prices': predicted_values_inverse.flatten()})
print(comparison_df.head())

plt.figure(figsize=(10, 5))
plt.plot(actual_values_inverse.flatten(), marker='.', label="Actual Close Prices")
plt.plot(predicted_values_inverse.flatten(), 'r', label="Predicted Close Prices")
plt.ylabel('Close Price')
plt.xlabel('Time Step')
plt.legend()
plt.title('Comparison of Actual vs Predicted Close Prices')
plt.show()
# Out:
# 5/5 [==============================] - 0s 7ms/step
#    Actual Close Prices  Predicted Close Prices
# 0            49.680000               49.657043
# 1            49.660000               49.555763
# 2            50.480000               49.516777
# 3            50.799999               50.178791
# 4            50.959999               50.446690
