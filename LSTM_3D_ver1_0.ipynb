# %%
# !pip install --upgrade mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mplfinance) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mplfinance) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mplfinance) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.10b0

# %%
import numpy as np
import pandas as pd
import math
import random
import datetime as dt
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
from mplfinance.original_flavor import candlestick_ohlc
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import metrics
from sklearn.metrics import mean_squared_error
import yfinance as yf

# %%
# Downloading stock data for Apple (AAPL) from Yahoo Finance
stock_data = yf.download('AAPL', start='2020-01-01', end='2024-01-01')
specific_df = pd.DataFrame(stock_data).reset_index()
specific_df['Name'] = 'AAPL'
print(specific_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2020-01-02  74.059998  75.150002  73.797501  75.087502  73.152649
# 1 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.441460
# 2 2020-01-06  73.447502  74.989998  73.187500  74.949997  73.018700
# 3 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.675285
# 4 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.844345
#
#       Volume  Name
# 0  135480400  AAPL
# 1  146322800  AAPL
# 2  118387200  AAPL
# 3  108872000  AAPL
# 4  132079200  AAPL

# %%
plt.figure(figsize=(15,6))
plt.plot(specific_df['Date'], specific_df['Close'], marker='.')
plt.title('Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
matplotlib_date = mdates.date2num(specific_df['Date'])
ohlc = np.vstack((matplotlib_date, specific_df['Open'], specific_df['High'], specific_df['Low'], specific_df['Close'])).T
plt.figure(figsize=(15,6))
ax=plt.subplot()
candlestick_ohlc(ax, ohlc, width=0.6, colorup='g', colordown='r')
ax.xaxis_date()
plt.title('Candlestick Chart')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
window = 30
plt.figure(figsize=(15,6))
plt.plot(specific_df['Date'], specific_df['Close'], label='Closing Price', linewidth=2)
plt.plot(specific_df['Date'], specific_df['Close'].rolling(window=window).mean(), label=f'{window}-Day Moving Avg', linestyle='--')
plt.title(f'Closing Prices and {window}-Day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %%
company_name = 'AAPL'
specific_df['Month'] = specific_df['Date'].dt.month
monthly_average = specific_df.groupby('Month')['Close'].mean()

plt.figure(figsize=(15,6))
plt.plot(monthly_average.index, monthly_average.values, marker='o')
plt.title(f'Monthly Seasonality of {company_name}')
plt.xlabel('Months')
plt.ylabel('Average Closing Price')
plt.xticks(range(1,13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %%
new_df = specific_df.reset_index()['Close']
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(np.array(new_df).reshape(-1,1))

# %%
from sklearn.model_selection import train_test_split
test_size = 0.2
train_data, test_data = train_test_split(scaled_data, test_size=test_size, shuffle=False)

# %%
def generate_sequences_and_labels(data, n_past):
    sequences = [data[i - n_past:i, 0] for i in range(n_past, len(data))]
    labels = [data[i, 0] for i in range(n_past, len(data))]
    return np.array(sequences), np.array(labels)

# %%
n_past = 60
x_train, y_train = generate_sequences_and_labels(train_data, n_past)
x_test, y_test = generate_sequences_and_labels(test_data, n_past)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=[input_shape, 1]))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    return model

# %%
def compile_lstm_model(model):
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
def train_lstm_model(model, x_train, y_train, x_test, y_test):
    model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=300, batch_size=32, verbose=1)

# %%
model = build_lstm_model(x_train.shape[1])
compile_lstm_model(model)
train_lstm_model(model, x_train, y_train, x_test, y_test)
# Out:
# Epoch 1/300
# 24/24 [==============================] - 10s 62ms/step - loss: 0.0725 - mean_absolute_error: 0.2000 - val_loss: 0.0122 - val_mean_absolute_error: 0.0995
# Epoch 2/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0122 - mean_absolute_error: 0.0881 - val_loss: 0.0096 - val_mean_absolute_error: 0.0862
# Epoch 3/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0077 - mean_absolute_error: 0.0698 - val_loss: 0.0114 - val_mean_absolute_error: 0.0963
# Epoch 4/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0070 - mean_absolute_error: 0.0652 - val_loss: 0.0044 - val_mean_absolute_error: 0.0578
# Epoch 5/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0057 - mean_absolute_error: 0.0587 - val_loss: 0.0023 - val_mean_absolute_error: 0.0425
# Epoch 6/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0053 - mean_absolute_error: 0.0579 - val_loss: 0.0031 - val_mean_absolute_error: 0.0495
# Epoch 7/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0059 - mean_absolute_error: 0.0604 - val_loss: 0.0021 - val_mean_absolute_error: 0.0398
# Epoch 8/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0048 - mean_absolute_error: 0.0551 - val_loss: 0.0056 - val_mean_absolute_error: 0.0653
# Epoch 9/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0053 - mean_absolute_error: 0.0564 - val_loss: 0.0022 - val_mean_absolute_error: 0.0416
# Epoch 10/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0045 - mean_absolute_error: 0.0527 - val_loss: 0.0019 - val_mean_absolute_error: 0.0380
# Epoch 11/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0052 - mean_absolute_error: 0.0560 - val_loss: 0.0051 - val_mean_absolute_error: 0.0622
# Epoch 12/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0047 - mean_absolute_error: 0.0534 - val_loss: 0.0033 - val_mean_absolute_error: 0.0506
# Epoch 13/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0048 - mean_absolute_error: 0.0522 - val_loss: 0.0030 - val_mean_absolute_error: 0.0481
# Epoch 14/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0048 - mean_absolute_error: 0.0522 - val_loss: 0.0019 - val_mean_absolute_error: 0.0379
# Epoch 15/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0045 - mean_absolute_error: 0.0510 - val_loss: 0.0039 - val_mean_absolute_error: 0.0543
# Epoch 16/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0049 - mean_absolute_error: 0.0534 - val_loss: 0.0017 - val_mean_absolute_error: 0.0353
# Epoch 17/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0043 - mean_absolute_error: 0.0512 - val_loss: 0.0072 - val_mean_absolute_error: 0.0761
# Epoch 18/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0048 - mean_absolute_error: 0.0530 - val_loss: 0.0017 - val_mean_absolute_error: 0.0319
# Epoch 19/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0046 - mean_absolute_error: 0.0533 - val_loss: 0.0101 - val_mean_absolute_error: 0.0924
# Epoch 20/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0041 - mean_absolute_error: 0.0495 - val_loss: 0.0015 - val_mean_absolute_error: 0.0323
# Epoch 21/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0043 - mean_absolute_error: 0.0504 - val_loss: 0.0069 - val_mean_absolute_error: 0.0746
# Epoch 22/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0044 - mean_absolute_error: 0.0504 - val_loss: 0.0015 - val_mean_absolute_error: 0.0323
# Epoch 23/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0044 - mean_absolute_error: 0.0516 - val_loss: 0.0063 - val_mean_absolute_error: 0.0712
# Epoch 24/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0037 - mean_absolute_error: 0.0469 - val_loss: 0.0048 - val_mean_absolute_error: 0.0608
# Epoch 25/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0035 - mean_absolute_error: 0.0461 - val_loss: 0.0026 - val_mean_absolute_error: 0.0443
# Epoch 26/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0039 - mean_absolute_error: 0.0477 - val_loss: 0.0140 - val_mean_absolute_error: 0.1124
# Epoch 27/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0050 - mean_absolute_error: 0.0555 - val_loss: 0.0034 - val_mean_absolute_error: 0.0508
# Epoch 28/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0038 - mean_absolute_error: 0.0475 - val_loss: 0.0018 - val_mean_absolute_error: 0.0368
# Epoch 29/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0037 - mean_absolute_error: 0.0468 - val_loss: 0.0041 - val_mean_absolute_error: 0.0563
# Epoch 30/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0043 - mean_absolute_error: 0.0503 - val_loss: 0.0042 - val_mean_absolute_error: 0.0572
# Epoch 31/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0034 - mean_absolute_error: 0.0446 - val_loss: 0.0030 - val_mean_absolute_error: 0.0478
# Epoch 32/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0037 - mean_absolute_error: 0.0466 - val_loss: 0.0052 - val_mean_absolute_error: 0.0644
# Epoch 33/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0037 - mean_absolute_error: 0.0469 - val_loss: 0.0028 - val_mean_absolute_error: 0.0462
# Epoch 34/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0035 - mean_absolute_error: 0.0459 - val_loss: 0.0038 - val_mean_absolute_error: 0.0542
# Epoch 35/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0035 - mean_absolute_error: 0.0452 - val_loss: 0.0056 - val_mean_absolute_error: 0.0677
# Epoch 36/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0034 - mean_absolute_error: 0.0443 - val_loss: 0.0025 - val_mean_absolute_error: 0.0438
# Epoch 37/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0035 - mean_absolute_error: 0.0450 - val_loss: 0.0036 - val_mean_absolute_error: 0.0528
# Epoch 38/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0034 - mean_absolute_error: 0.0450 - val_loss: 0.0022 - val_mean_absolute_error: 0.0407
# Epoch 39/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0034 - mean_absolute_error: 0.0442 - val_loss: 0.0049 - val_mean_absolute_error: 0.0632
# Epoch 40/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0032 - mean_absolute_error: 0.0439 - val_loss: 0.0027 - val_mean_absolute_error: 0.0453
# Epoch 41/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0031 - mean_absolute_error: 0.0440 - val_loss: 0.0065 - val_mean_absolute_error: 0.0737
# Epoch 42/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0036 - mean_absolute_error: 0.0452 - val_loss: 0.0018 - val_mean_absolute_error: 0.0371
# Epoch 43/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0033 - mean_absolute_error: 0.0442 - val_loss: 0.0059 - val_mean_absolute_error: 0.0701
# Epoch 44/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0032 - mean_absolute_error: 0.0440 - val_loss: 0.0024 - val_mean_absolute_error: 0.0433
# Epoch 45/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0037 - mean_absolute_error: 0.0480 - val_loss: 0.0012 - val_mean_absolute_error: 0.0288
# Epoch 46/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0036 - mean_absolute_error: 0.0461 - val_loss: 0.0024 - val_mean_absolute_error: 0.0434
# Epoch 47/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0031 - mean_absolute_error: 0.0433 - val_loss: 0.0032 - val_mean_absolute_error: 0.0501
# Epoch 48/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0026 - mean_absolute_error: 0.0392 - val_loss: 0.0012 - val_mean_absolute_error: 0.0278
# Epoch 49/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0031 - mean_absolute_error: 0.0436 - val_loss: 0.0042 - val_mean_absolute_error: 0.0589
# Epoch 50/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0029 - mean_absolute_error: 0.0412 - val_loss: 0.0024 - val_mean_absolute_error: 0.0439
# Epoch 51/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0029 - mean_absolute_error: 0.0412 - val_loss: 0.0034 - val_mean_absolute_error: 0.0521
# Epoch 52/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0424 - val_loss: 0.0030 - val_mean_absolute_error: 0.0491
# Epoch 53/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0028 - mean_absolute_error: 0.0409 - val_loss: 0.0011 - val_mean_absolute_error: 0.0269
# Epoch 54/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0031 - mean_absolute_error: 0.0431 - val_loss: 0.0023 - val_mean_absolute_error: 0.0430
# Epoch 55/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0413 - val_loss: 0.0015 - val_mean_absolute_error: 0.0339
# Epoch 56/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0028 - mean_absolute_error: 0.0400 - val_loss: 0.0033 - val_mean_absolute_error: 0.0515
# Epoch 57/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0378 - val_loss: 9.3531e-04 - val_mean_absolute_error: 0.0238
# Epoch 58/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0382 - val_loss: 0.0012 - val_mean_absolute_error: 0.0299
# Epoch 59/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0381 - val_loss: 0.0031 - val_mean_absolute_error: 0.0504
# Epoch 60/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0030 - mean_absolute_error: 0.0434 - val_loss: 9.2169e-04 - val_mean_absolute_error: 0.0241
# Epoch 61/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0026 - mean_absolute_error: 0.0403 - val_loss: 0.0034 - val_mean_absolute_error: 0.0527
# Epoch 62/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0381 - val_loss: 0.0046 - val_mean_absolute_error: 0.0625
# Epoch 63/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0030 - mean_absolute_error: 0.0422 - val_loss: 8.7120e-04 - val_mean_absolute_error: 0.0222
# Epoch 64/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0385 - val_loss: 0.0028 - val_mean_absolute_error: 0.0473
# Epoch 65/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0028 - mean_absolute_error: 0.0403 - val_loss: 8.2765e-04 - val_mean_absolute_error: 0.0218
# Epoch 66/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0033 - mean_absolute_error: 0.0438 - val_loss: 0.0041 - val_mean_absolute_error: 0.0591
# Epoch 67/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0030 - mean_absolute_error: 0.0426 - val_loss: 0.0035 - val_mean_absolute_error: 0.0538
# Epoch 68/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0026 - mean_absolute_error: 0.0388 - val_loss: 8.6850e-04 - val_mean_absolute_error: 0.0238
# Epoch 69/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0376 - val_loss: 0.0013 - val_mean_absolute_error: 0.0314
# Epoch 70/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0026 - mean_absolute_error: 0.0383 - val_loss: 0.0048 - val_mean_absolute_error: 0.0644
# Epoch 71/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0028 - mean_absolute_error: 0.0406 - val_loss: 7.7939e-04 - val_mean_absolute_error: 0.0212
# Epoch 72/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0023 - mean_absolute_error: 0.0376 - val_loss: 0.0012 - val_mean_absolute_error: 0.0299
# Epoch 73/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0024 - mean_absolute_error: 0.0385 - val_loss: 7.6437e-04 - val_mean_absolute_error: 0.0209
# Epoch 74/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0383 - val_loss: 0.0039 - val_mean_absolute_error: 0.0574
# Epoch 75/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0027 - mean_absolute_error: 0.0404 - val_loss: 0.0021 - val_mean_absolute_error: 0.0407
# Epoch 76/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0356 - val_loss: 0.0015 - val_mean_absolute_error: 0.0346
# Epoch 77/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0022 - mean_absolute_error: 0.0358 - val_loss: 7.2783e-04 - val_mean_absolute_error: 0.0205
# Epoch 78/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0025 - mean_absolute_error: 0.0380 - val_loss: 0.0023 - val_mean_absolute_error: 0.0435
# Epoch 79/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0350 - val_loss: 7.5599e-04 - val_mean_absolute_error: 0.0220
# Epoch 80/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0024 - mean_absolute_error: 0.0376 - val_loss: 0.0013 - val_mean_absolute_error: 0.0320
# Epoch 81/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0352 - val_loss: 0.0014 - val_mean_absolute_error: 0.0329
# Epoch 82/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0023 - mean_absolute_error: 0.0369 - val_loss: 0.0025 - val_mean_absolute_error: 0.0449
# Epoch 83/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0348 - val_loss: 0.0016 - val_mean_absolute_error: 0.0351
# Epoch 84/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0345 - val_loss: 6.6942e-04 - val_mean_absolute_error: 0.0195
# Epoch 85/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0024 - mean_absolute_error: 0.0376 - val_loss: 6.8881e-04 - val_mean_absolute_error: 0.0206
# Epoch 86/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0344 - val_loss: 0.0021 - val_mean_absolute_error: 0.0408
# Epoch 87/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0352 - val_loss: 0.0016 - val_mean_absolute_error: 0.0350
# Epoch 88/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0343 - val_loss: 0.0014 - val_mean_absolute_error: 0.0330
# Epoch 89/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0330 - val_loss: 0.0013 - val_mean_absolute_error: 0.0318
# Epoch 90/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0021 - mean_absolute_error: 0.0353 - val_loss: 9.1189e-04 - val_mean_absolute_error: 0.0257
# Epoch 91/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0330 - val_loss: 0.0017 - val_mean_absolute_error: 0.0370
# Epoch 92/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0336 - val_loss: 0.0025 - val_mean_absolute_error: 0.0456
# Epoch 93/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0354 - val_loss: 7.1205e-04 - val_mean_absolute_error: 0.0218
# Epoch 94/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0346 - val_loss: 0.0028 - val_mean_absolute_error: 0.0482
# Epoch 95/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0348 - val_loss: 0.0014 - val_mean_absolute_error: 0.0323
# Epoch 96/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0019 - mean_absolute_error: 0.0335 - val_loss: 0.0011 - val_mean_absolute_error: 0.0288
# Epoch 97/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0019 - mean_absolute_error: 0.0337 - val_loss: 0.0011 - val_mean_absolute_error: 0.0280
# Epoch 98/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0314 - val_loss: 9.9954e-04 - val_mean_absolute_error: 0.0271
# Epoch 99/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0020 - mean_absolute_error: 0.0347 - val_loss: 0.0033 - val_mean_absolute_error: 0.0532
# Epoch 100/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0023 - mean_absolute_error: 0.0369 - val_loss: 0.0011 - val_mean_absolute_error: 0.0288
# Epoch 101/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0345 - val_loss: 0.0028 - val_mean_absolute_error: 0.0487
# Epoch 102/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0353 - val_loss: 0.0024 - val_mean_absolute_error: 0.0447
# Epoch 103/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0330 - val_loss: 0.0014 - val_mean_absolute_error: 0.0325
# Epoch 104/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0334 - val_loss: 7.4696e-04 - val_mean_absolute_error: 0.0228
# Epoch 105/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0331 - val_loss: 0.0013 - val_mean_absolute_error: 0.0309
# Epoch 106/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0017 - mean_absolute_error: 0.0323 - val_loss: 0.0017 - val_mean_absolute_error: 0.0374
# Epoch 107/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0322 - val_loss: 0.0012 - val_mean_absolute_error: 0.0305
# Epoch 108/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0323 - val_loss: 0.0012 - val_mean_absolute_error: 0.0299
# Epoch 109/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0315 - val_loss: 6.6068e-04 - val_mean_absolute_error: 0.0211
# Epoch 110/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0328 - val_loss: 0.0016 - val_mean_absolute_error: 0.0363
# Epoch 111/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0325 - val_loss: 6.6179e-04 - val_mean_absolute_error: 0.0211
# Epoch 112/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0328 - val_loss: 8.1429e-04 - val_mean_absolute_error: 0.0242
# Epoch 113/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0312 - val_loss: 0.0010 - val_mean_absolute_error: 0.0282
# Epoch 114/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0335 - val_loss: 5.0819e-04 - val_mean_absolute_error: 0.0171
# Epoch 115/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0305 - val_loss: 0.0021 - val_mean_absolute_error: 0.0421
# Epoch 116/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0301 - val_loss: 6.2461e-04 - val_mean_absolute_error: 0.0206
# Epoch 117/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0017 - mean_absolute_error: 0.0322 - val_loss: 0.0022 - val_mean_absolute_error: 0.0433
# Epoch 118/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0318 - val_loss: 0.0019 - val_mean_absolute_error: 0.0395
# Epoch 119/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0301 - val_loss: 8.1923e-04 - val_mean_absolute_error: 0.0243
# Epoch 120/300
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0017 - mean_absolute_error: 0.0315 - val_loss: 9.4875e-04 - val_mean_absolute_error: 0.0267
# Epoch 121/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0312 - val_loss: 0.0012 - val_mean_absolute_error: 0.0300
# Epoch 122/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0016 - mean_absolute_error: 0.0309 - val_loss: 0.0015 - val_mean_absolute_error: 0.0348
# Epoch 123/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0291 - val_loss: 7.3026e-04 - val_mean_absolute_error: 0.0228
# Epoch 124/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0015 - mean_absolute_error: 0.0291 - val_loss: 0.0016 - val_mean_absolute_error: 0.0358
# Epoch 125/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0015 - mean_absolute_error: 0.0298 - val_loss: 7.5488e-04 - val_mean_absolute_error: 0.0234
# Epoch 126/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0014 - mean_absolute_error: 0.0288 - val_loss: 0.0011 - val_mean_absolute_error: 0.0291
# Epoch 127/300
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0015 - mean_absolute_error: 0.0300 - val_loss: 0.0010 - val_mean_absolute_error: 0.0283
# Epoch 128/300
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0014 - mean_absolute_error: 0.0294 - val_loss: 7.9698e-04 - val_mean_absolute_error: 0.0211
# Epoch 129/300
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0015 - mean_absolute_error: 0.0297 - val_loss: 0.0012 - val_mean_absolute_error: 0.0307
# Epoch 130/300
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0016 - mean_absolute_error: 0.0306 - val_loss: 4.7554e-04 - val_mean_absolute_error: 0.0159
# Epoch 131/300
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0017 - mean_absolute_error: 0.0315 - val_loss: 5.2841e-04 - val_mean_absolute_error: 0.0189
# Epoch 132/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0016 - mean_absolute_error: 0.0314 - val_loss: 4.3683e-04 - val_mean_absolute_error: 0.0161
# Epoch 133/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0016 - mean_absolute_error: 0.0308 - val_loss: 4.2157e-04 - val_mean_absolute_error: 0.0153
# Epoch 134/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0015 - mean_absolute_error: 0.0309 - val_loss: 8.1893e-04 - val_mean_absolute_error: 0.0246
# Epoch 135/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0015 - mean_absolute_error: 0.0303 - val_loss: 0.0019 - val_mean_absolute_error: 0.0403
# Epoch 136/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0013 - mean_absolute_error: 0.0278 - val_loss: 8.2404e-04 - val_mean_absolute_error: 0.0249
# Epoch 137/300
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0014 - mean_absolute_error: 0.0286 - val_loss: 0.0012 - val_mean_absolute_error: 0.0309
# Epoch 138/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0276 - val_loss: 6.7938e-04 - val_mean_absolute_error: 0.0222
# Epoch 139/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0014 - mean_absolute_error: 0.0295 - val_loss: 4.2968e-04 - val_mean_absolute_error: 0.0164
# Epoch 140/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0270 - val_loss: 0.0010 - val_mean_absolute_error: 0.0287
# Epoch 141/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0267 - val_loss: 3.9358e-04 - val_mean_absolute_error: 0.0146
# Epoch 142/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0288 - val_loss: 4.6925e-04 - val_mean_absolute_error: 0.0174
# Epoch 143/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0290 - val_loss: 0.0010 - val_mean_absolute_error: 0.0288
# Epoch 144/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0291 - val_loss: 4.4945e-04 - val_mean_absolute_error: 0.0171
# Epoch 145/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0302 - val_loss: 4.2394e-04 - val_mean_absolute_error: 0.0164
# Epoch 146/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0276 - val_loss: 9.4415e-04 - val_mean_absolute_error: 0.0271
# Epoch 147/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0283 - val_loss: 9.9785e-04 - val_mean_absolute_error: 0.0280
# Epoch 148/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0281 - val_loss: 5.6602e-04 - val_mean_absolute_error: 0.0199
# Epoch 149/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0266 - val_loss: 7.4319e-04 - val_mean_absolute_error: 0.0235
# Epoch 150/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0266 - val_loss: 9.1996e-04 - val_mean_absolute_error: 0.0267
# Epoch 151/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0267 - val_loss: 0.0014 - val_mean_absolute_error: 0.0341
# Epoch 152/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0280 - val_loss: 0.0011 - val_mean_absolute_error: 0.0300
# Epoch 153/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0286 - val_loss: 3.7575e-04 - val_mean_absolute_error: 0.0151
# Epoch 154/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0278 - val_loss: 5.3466e-04 - val_mean_absolute_error: 0.0192
# Epoch 155/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0270 - val_loss: 3.6061e-04 - val_mean_absolute_error: 0.0146
# Epoch 156/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0270 - val_loss: 9.8904e-04 - val_mean_absolute_error: 0.0280
# Epoch 157/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0278 - val_loss: 0.0010 - val_mean_absolute_error: 0.0283
# Epoch 158/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0278 - val_loss: 6.0207e-04 - val_mean_absolute_error: 0.0209
# Epoch 159/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0272 - val_loss: 0.0011 - val_mean_absolute_error: 0.0305
# Epoch 160/300
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0013 - mean_absolute_error: 0.0281 - val_loss: 8.1970e-04 - val_mean_absolute_error: 0.0251
# Epoch 161/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0012 - mean_absolute_error: 0.0266 - val_loss: 6.6103e-04 - val_mean_absolute_error: 0.0221
# Epoch 162/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0012 - mean_absolute_error: 0.0270 - val_loss: 0.0011 - val_mean_absolute_error: 0.0300
# Epoch 163/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0012 - mean_absolute_error: 0.0260 - val_loss: 0.0011 - val_mean_absolute_error: 0.0298
# Epoch 164/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0011 - mean_absolute_error: 0.0251 - val_loss: 0.0026 - val_mean_absolute_error: 0.0476
# Epoch 165/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0282 - val_loss: 0.0035 - val_mean_absolute_error: 0.0565
# Epoch 166/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0295 - val_loss: 0.0038 - val_mean_absolute_error: 0.0591
# Epoch 167/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0294 - val_loss: 0.0013 - val_mean_absolute_error: 0.0336
# Epoch 168/300
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0014 - mean_absolute_error: 0.0288 - val_loss: 5.6760e-04 - val_mean_absolute_error: 0.0202
# Epoch 169/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0257 - val_loss: 7.5967e-04 - val_mean_absolute_error: 0.0241
# Epoch 170/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0256 - val_loss: 3.1307e-04 - val_mean_absolute_error: 0.0131
# Epoch 171/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0260 - val_loss: 0.0012 - val_mean_absolute_error: 0.0314
# Epoch 172/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0010 - mean_absolute_error: 0.0251 - val_loss: 6.2948e-04 - val_mean_absolute_error: 0.0217
# Epoch 173/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0261 - val_loss: 5.8957e-04 - val_mean_absolute_error: 0.0189
# Epoch 174/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0256 - val_loss: 5.4851e-04 - val_mean_absolute_error: 0.0199
# Epoch 175/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0251 - val_loss: 5.8257e-04 - val_mean_absolute_error: 0.0207
# Epoch 176/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0258 - val_loss: 2.9400e-04 - val_mean_absolute_error: 0.0128
# Epoch 177/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0253 - val_loss: 9.2745e-04 - val_mean_absolute_error: 0.0273
# Epoch 178/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0252 - val_loss: 3.4393e-04 - val_mean_absolute_error: 0.0148
# Epoch 179/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0263 - val_loss: 4.5349e-04 - val_mean_absolute_error: 0.0176
# Epoch 180/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0010 - mean_absolute_error: 0.0250 - val_loss: 8.1650e-04 - val_mean_absolute_error: 0.0254
# Epoch 181/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0012 - mean_absolute_error: 0.0264 - val_loss: 0.0015 - val_mean_absolute_error: 0.0352
# Epoch 182/300
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0011 - mean_absolute_error: 0.0252 - val_loss: 2.9273e-04 - val_mean_absolute_error: 0.0130
# Epoch 183/300
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0273 - val_loss: 3.4617e-04 - val_mean_absolute_error: 0.0136
# Epoch 184/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0258 - val_loss: 8.3970e-04 - val_mean_absolute_error: 0.0259
# Epoch 185/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0257 - val_loss: 2.8348e-04 - val_mean_absolute_error: 0.0127
# Epoch 186/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0253 - val_loss: 0.0011 - val_mean_absolute_error: 0.0304
# Epoch 187/300
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0249 - val_loss: 2.7785e-04 - val_mean_absolute_error: 0.0125
# Epoch 188/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0250 - val_loss: 3.0813e-04 - val_mean_absolute_error: 0.0137
# Epoch 189/300
# 24/24 [==============================] - 0s 13ms/step - loss: 9.9826e-04 - mean_absolute_error: 0.0241 - val_loss: 0.0012 - val_mean_absolute_error: 0.0323
# Epoch 190/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.0987e-04 - mean_absolute_error: 0.0235 - val_loss: 7.4033e-04 - val_mean_absolute_error: 0.0243
# Epoch 191/300
# 24/24 [==============================] - 0s 13ms/step - loss: 9.9182e-04 - mean_absolute_error: 0.0243 - val_loss: 2.7643e-04 - val_mean_absolute_error: 0.0125
# Epoch 192/300
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - mean_absolute_error: 0.0253 - val_loss: 3.0808e-04 - val_mean_absolute_error: 0.0137
# Epoch 193/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.8913e-04 - mean_absolute_error: 0.0232 - val_loss: 5.2995e-04 - val_mean_absolute_error: 0.0199
# Epoch 194/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.8355e-04 - mean_absolute_error: 0.0238 - val_loss: 0.0020 - val_mean_absolute_error: 0.0419
# Epoch 195/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0011 - mean_absolute_error: 0.0261 - val_loss: 0.0020 - val_mean_absolute_error: 0.0423
# Epoch 196/300
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0010 - mean_absolute_error: 0.0256 - val_loss: 0.0014 - val_mean_absolute_error: 0.0347
# Epoch 197/300
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0011 - mean_absolute_error: 0.0261 - val_loss: 2.9149e-04 - val_mean_absolute_error: 0.0127
# Epoch 198/300
# 24/24 [==============================] - 0s 18ms/step - loss: 9.5852e-04 - mean_absolute_error: 0.0235 - val_loss: 2.6449e-04 - val_mean_absolute_error: 0.0123
# Epoch 199/300
# 24/24 [==============================] - 0s 17ms/step - loss: 9.9922e-04 - mean_absolute_error: 0.0242 - val_loss: 2.6083e-04 - val_mean_absolute_error: 0.0122
# Epoch 200/300
# 24/24 [==============================] - 0s 13ms/step - loss: 9.3512e-04 - mean_absolute_error: 0.0241 - val_loss: 3.8292e-04 - val_mean_absolute_error: 0.0162
# Epoch 201/300
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0010 - mean_absolute_error: 0.0243 - val_loss: 5.2343e-04 - val_mean_absolute_error: 0.0199
# Epoch 202/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.0530e-04 - mean_absolute_error: 0.0230 - val_loss: 3.5279e-04 - val_mean_absolute_error: 0.0153
# Epoch 203/300
# 24/24 [==============================] - 0s 14ms/step - loss: 9.3246e-04 - mean_absolute_error: 0.0233 - val_loss: 4.2099e-04 - val_mean_absolute_error: 0.0173
# Epoch 204/300
# 24/24 [==============================] - 1s 23ms/step - loss: 8.5521e-04 - mean_absolute_error: 0.0222 - val_loss: 2.7364e-04 - val_mean_absolute_error: 0.0128
# Epoch 205/300
# 24/24 [==============================] - 1s 26ms/step - loss: 8.7170e-04 - mean_absolute_error: 0.0229 - val_loss: 2.5448e-04 - val_mean_absolute_error: 0.0120
# Epoch 206/300
# 24/24 [==============================] - 1s 24ms/step - loss: 9.8314e-04 - mean_absolute_error: 0.0245 - val_loss: 4.1922e-04 - val_mean_absolute_error: 0.0171
# Epoch 207/300
# 24/24 [==============================] - 0s 14ms/step - loss: 9.0554e-04 - mean_absolute_error: 0.0233 - val_loss: 4.9818e-04 - val_mean_absolute_error: 0.0193
# Epoch 208/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.8818e-04 - mean_absolute_error: 0.0227 - val_loss: 4.3892e-04 - val_mean_absolute_error: 0.0178
# Epoch 209/300
# 24/24 [==============================] - 0s 13ms/step - loss: 9.6885e-04 - mean_absolute_error: 0.0241 - val_loss: 9.7943e-04 - val_mean_absolute_error: 0.0285
# Epoch 210/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.9893e-04 - mean_absolute_error: 0.0234 - val_loss: 5.7074e-04 - val_mean_absolute_error: 0.0211
# Epoch 211/300
# 24/24 [==============================] - 0s 13ms/step - loss: 9.8073e-04 - mean_absolute_error: 0.0242 - val_loss: 2.5404e-04 - val_mean_absolute_error: 0.0122
# Epoch 212/300
# 24/24 [==============================] - 0s 15ms/step - loss: 8.9369e-04 - mean_absolute_error: 0.0233 - val_loss: 6.2586e-04 - val_mean_absolute_error: 0.0222
# Epoch 213/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.5284e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0010 - val_mean_absolute_error: 0.0290
# Epoch 214/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.3637e-04 - mean_absolute_error: 0.0223 - val_loss: 8.2477e-04 - val_mean_absolute_error: 0.0259
# Epoch 215/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.0351e-04 - mean_absolute_error: 0.0220 - val_loss: 2.4986e-04 - val_mean_absolute_error: 0.0117
# Epoch 216/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.9425e-04 - mean_absolute_error: 0.0228 - val_loss: 2.9878e-04 - val_mean_absolute_error: 0.0138
# Epoch 217/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.6321e-04 - mean_absolute_error: 0.0231 - val_loss: 2.7772e-04 - val_mean_absolute_error: 0.0129
# Epoch 218/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.3869e-04 - mean_absolute_error: 0.0221 - val_loss: 3.1455e-04 - val_mean_absolute_error: 0.0133
# Epoch 219/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.7920e-04 - mean_absolute_error: 0.0229 - val_loss: 2.6934e-04 - val_mean_absolute_error: 0.0127
# Epoch 220/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.8547e-04 - mean_absolute_error: 0.0232 - val_loss: 4.5138e-04 - val_mean_absolute_error: 0.0183
# Epoch 221/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.2603e-04 - mean_absolute_error: 0.0218 - val_loss: 5.6855e-04 - val_mean_absolute_error: 0.0210
# Epoch 222/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.1923e-04 - mean_absolute_error: 0.0221 - val_loss: 3.3792e-04 - val_mean_absolute_error: 0.0151
# Epoch 223/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.4098e-04 - mean_absolute_error: 0.0223 - val_loss: 0.0016 - val_mean_absolute_error: 0.0377
# Epoch 224/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.2556e-04 - mean_absolute_error: 0.0221 - val_loss: 3.4734e-04 - val_mean_absolute_error: 0.0155
# Epoch 225/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.7024e-04 - mean_absolute_error: 0.0227 - val_loss: 3.0408e-04 - val_mean_absolute_error: 0.0140
# Epoch 226/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.3860e-04 - mean_absolute_error: 0.0218 - val_loss: 3.5146e-04 - val_mean_absolute_error: 0.0156
# Epoch 227/300
# 24/24 [==============================] - 0s 13ms/step - loss: 9.1041e-04 - mean_absolute_error: 0.0232 - val_loss: 8.7141e-04 - val_mean_absolute_error: 0.0267
# Epoch 228/300
# 24/24 [==============================] - 0s 16ms/step - loss: 9.0170e-04 - mean_absolute_error: 0.0230 - val_loss: 2.6607e-04 - val_mean_absolute_error: 0.0121
# Epoch 229/300
# 24/24 [==============================] - 0s 20ms/step - loss: 8.2937e-04 - mean_absolute_error: 0.0223 - val_loss: 2.6183e-04 - val_mean_absolute_error: 0.0121
# Epoch 230/300
# 24/24 [==============================] - 0s 17ms/step - loss: 7.9159e-04 - mean_absolute_error: 0.0215 - val_loss: 2.4714e-04 - val_mean_absolute_error: 0.0117
# Epoch 231/300
# 24/24 [==============================] - 0s 20ms/step - loss: 9.0695e-04 - mean_absolute_error: 0.0232 - val_loss: 2.3777e-04 - val_mean_absolute_error: 0.0117
# Epoch 232/300
# 24/24 [==============================] - 0s 18ms/step - loss: 9.2398e-04 - mean_absolute_error: 0.0238 - val_loss: 2.9615e-04 - val_mean_absolute_error: 0.0137
# Epoch 233/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.9770e-04 - mean_absolute_error: 0.0223 - val_loss: 2.4274e-04 - val_mean_absolute_error: 0.0116
# Epoch 234/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.2945e-04 - mean_absolute_error: 0.0221 - val_loss: 6.1568e-04 - val_mean_absolute_error: 0.0219
# Epoch 235/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.9786e-04 - mean_absolute_error: 0.0215 - val_loss: 3.1696e-04 - val_mean_absolute_error: 0.0135
# Epoch 236/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.6497e-04 - mean_absolute_error: 0.0209 - val_loss: 2.2912e-04 - val_mean_absolute_error: 0.0116
# Epoch 237/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.9270e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0015 - val_mean_absolute_error: 0.0360
# Epoch 238/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.1980e-04 - mean_absolute_error: 0.0222 - val_loss: 3.8643e-04 - val_mean_absolute_error: 0.0165
# Epoch 239/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.5020e-04 - mean_absolute_error: 0.0224 - val_loss: 4.8500e-04 - val_mean_absolute_error: 0.0190
# Epoch 240/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.9299e-04 - mean_absolute_error: 0.0218 - val_loss: 3.4842e-04 - val_mean_absolute_error: 0.0154
# Epoch 241/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.0710e-04 - mean_absolute_error: 0.0216 - val_loss: 3.7170e-04 - val_mean_absolute_error: 0.0160
# Epoch 242/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.0917e-04 - mean_absolute_error: 0.0219 - val_loss: 2.4469e-04 - val_mean_absolute_error: 0.0116
# Epoch 243/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.5534e-04 - mean_absolute_error: 0.0214 - val_loss: 6.9966e-04 - val_mean_absolute_error: 0.0236
# Epoch 244/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.8395e-04 - mean_absolute_error: 0.0216 - val_loss: 0.0012 - val_mean_absolute_error: 0.0323
# Epoch 245/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.8900e-04 - mean_absolute_error: 0.0218 - val_loss: 9.0175e-04 - val_mean_absolute_error: 0.0273
# Epoch 246/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.8254e-04 - mean_absolute_error: 0.0214 - val_loss: 5.3850e-04 - val_mean_absolute_error: 0.0202
# Epoch 247/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.8579e-04 - mean_absolute_error: 0.0212 - val_loss: 2.5635e-04 - val_mean_absolute_error: 0.0125
# Epoch 248/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.7799e-04 - mean_absolute_error: 0.0216 - val_loss: 0.0010 - val_mean_absolute_error: 0.0295
# Epoch 249/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.1696e-04 - mean_absolute_error: 0.0224 - val_loss: 2.6330e-04 - val_mean_absolute_error: 0.0126
# Epoch 250/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.5284e-04 - mean_absolute_error: 0.0214 - val_loss: 2.7445e-04 - val_mean_absolute_error: 0.0130
# Epoch 251/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.0937e-04 - mean_absolute_error: 0.0212 - val_loss: 3.6236e-04 - val_mean_absolute_error: 0.0157
# Epoch 252/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.0204e-04 - mean_absolute_error: 0.0202 - val_loss: 3.2755e-04 - val_mean_absolute_error: 0.0147
# Epoch 253/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.1964e-04 - mean_absolute_error: 0.0203 - val_loss: 2.9549e-04 - val_mean_absolute_error: 0.0131
# Epoch 254/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.5515e-04 - mean_absolute_error: 0.0225 - val_loss: 2.6388e-04 - val_mean_absolute_error: 0.0126
# Epoch 255/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.2508e-04 - mean_absolute_error: 0.0218 - val_loss: 4.3311e-04 - val_mean_absolute_error: 0.0175
# Epoch 256/300
# 24/24 [==============================] - 0s 15ms/step - loss: 7.5584e-04 - mean_absolute_error: 0.0215 - val_loss: 3.8123e-04 - val_mean_absolute_error: 0.0162
# Epoch 257/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.7048e-04 - mean_absolute_error: 0.0214 - val_loss: 2.2865e-04 - val_mean_absolute_error: 0.0113
# Epoch 258/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.8619e-04 - mean_absolute_error: 0.0217 - val_loss: 8.0050e-04 - val_mean_absolute_error: 0.0255
# Epoch 259/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.6213e-04 - mean_absolute_error: 0.0226 - val_loss: 6.0808e-04 - val_mean_absolute_error: 0.0217
# Epoch 260/300
# 24/24 [==============================] - 0s 14ms/step - loss: 7.4108e-04 - mean_absolute_error: 0.0211 - val_loss: 4.9262e-04 - val_mean_absolute_error: 0.0190
# Epoch 261/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.3493e-04 - mean_absolute_error: 0.0220 - val_loss: 2.7131e-04 - val_mean_absolute_error: 0.0129
# Epoch 262/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.0011e-04 - mean_absolute_error: 0.0217 - val_loss: 3.9506e-04 - val_mean_absolute_error: 0.0157
# Epoch 263/300
# 24/24 [==============================] - 0s 15ms/step - loss: 9.2807e-04 - mean_absolute_error: 0.0238 - val_loss: 2.3032e-04 - val_mean_absolute_error: 0.0114
# Epoch 264/300
# 24/24 [==============================] - 0s 17ms/step - loss: 8.9134e-04 - mean_absolute_error: 0.0229 - val_loss: 5.1494e-04 - val_mean_absolute_error: 0.0195
# Epoch 265/300
# 24/24 [==============================] - 0s 17ms/step - loss: 8.6193e-04 - mean_absolute_error: 0.0228 - val_loss: 2.4612e-04 - val_mean_absolute_error: 0.0117
# Epoch 266/300
# 24/24 [==============================] - 0s 17ms/step - loss: 7.9086e-04 - mean_absolute_error: 0.0219 - val_loss: 2.4511e-04 - val_mean_absolute_error: 0.0116
# Epoch 267/300
# 24/24 [==============================] - 0s 18ms/step - loss: 7.5645e-04 - mean_absolute_error: 0.0211 - val_loss: 4.2927e-04 - val_mean_absolute_error: 0.0167
# Epoch 268/300
# 24/24 [==============================] - 1s 30ms/step - loss: 7.9483e-04 - mean_absolute_error: 0.0217 - val_loss: 4.0713e-04 - val_mean_absolute_error: 0.0168
# Epoch 269/300
# 24/24 [==============================] - 1s 22ms/step - loss: 7.5812e-04 - mean_absolute_error: 0.0210 - val_loss: 4.1882e-04 - val_mean_absolute_error: 0.0170
# Epoch 270/300
# 24/24 [==============================] - 0s 16ms/step - loss: 7.2070e-04 - mean_absolute_error: 0.0208 - val_loss: 2.4576e-04 - val_mean_absolute_error: 0.0121
# Epoch 271/300
# 24/24 [==============================] - 0s 19ms/step - loss: 8.2381e-04 - mean_absolute_error: 0.0220 - val_loss: 2.3813e-04 - val_mean_absolute_error: 0.0119
# Epoch 272/300
# 24/24 [==============================] - 1s 23ms/step - loss: 8.1289e-04 - mean_absolute_error: 0.0218 - val_loss: 6.7639e-04 - val_mean_absolute_error: 0.0231
# Epoch 273/300
# 24/24 [==============================] - 0s 18ms/step - loss: 8.6566e-04 - mean_absolute_error: 0.0224 - val_loss: 2.4762e-04 - val_mean_absolute_error: 0.0118
# Epoch 274/300
# 24/24 [==============================] - 0s 20ms/step - loss: 7.3388e-04 - mean_absolute_error: 0.0211 - val_loss: 2.8501e-04 - val_mean_absolute_error: 0.0133
# Epoch 275/300
# 24/24 [==============================] - 1s 22ms/step - loss: 7.6900e-04 - mean_absolute_error: 0.0214 - val_loss: 5.2415e-04 - val_mean_absolute_error: 0.0198
# Epoch 276/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.6157e-04 - mean_absolute_error: 0.0211 - val_loss: 3.0760e-04 - val_mean_absolute_error: 0.0140
# Epoch 277/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.6570e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0013 - val_mean_absolute_error: 0.0329
# Epoch 278/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.9594e-04 - mean_absolute_error: 0.0219 - val_loss: 6.1229e-04 - val_mean_absolute_error: 0.0216
# Epoch 279/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.6148e-04 - mean_absolute_error: 0.0210 - val_loss: 2.5315e-04 - val_mean_absolute_error: 0.0123
# Epoch 280/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.6521e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0029 - val_mean_absolute_error: 0.0520
# Epoch 281/300
# 24/24 [==============================] - 0s 14ms/step - loss: 9.0271e-04 - mean_absolute_error: 0.0236 - val_loss: 5.7101e-04 - val_mean_absolute_error: 0.0208
# Epoch 282/300
# 24/24 [==============================] - 0s 12ms/step - loss: 9.3783e-04 - mean_absolute_error: 0.0240 - val_loss: 3.5192e-04 - val_mean_absolute_error: 0.0153
# Epoch 283/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.5331e-04 - mean_absolute_error: 0.0224 - val_loss: 3.4881e-04 - val_mean_absolute_error: 0.0152
# Epoch 284/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.0147e-04 - mean_absolute_error: 0.0209 - val_loss: 6.1019e-04 - val_mean_absolute_error: 0.0216
# Epoch 285/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.1089e-04 - mean_absolute_error: 0.0215 - val_loss: 3.4120e-04 - val_mean_absolute_error: 0.0145
# Epoch 286/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.8937e-04 - mean_absolute_error: 0.0215 - val_loss: 8.0554e-04 - val_mean_absolute_error: 0.0255
# Epoch 287/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.2506e-04 - mean_absolute_error: 0.0218 - val_loss: 3.2586e-04 - val_mean_absolute_error: 0.0146
# Epoch 288/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.0213e-04 - mean_absolute_error: 0.0216 - val_loss: 8.6600e-04 - val_mean_absolute_error: 0.0267
# Epoch 289/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.8031e-04 - mean_absolute_error: 0.0215 - val_loss: 3.1068e-04 - val_mean_absolute_error: 0.0136
# Epoch 290/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.6483e-04 - mean_absolute_error: 0.0213 - val_loss: 2.3747e-04 - val_mean_absolute_error: 0.0117
# Epoch 291/300
# 24/24 [==============================] - 0s 12ms/step - loss: 8.1159e-04 - mean_absolute_error: 0.0217 - val_loss: 8.0742e-04 - val_mean_absolute_error: 0.0256
# Epoch 292/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.1977e-04 - mean_absolute_error: 0.0222 - val_loss: 0.0011 - val_mean_absolute_error: 0.0298
# Epoch 293/300
# 24/24 [==============================] - 0s 13ms/step - loss: 8.1300e-04 - mean_absolute_error: 0.0221 - val_loss: 3.8610e-04 - val_mean_absolute_error: 0.0161
# Epoch 294/300
# 24/24 [==============================] - 0s 13ms/step - loss: 7.2338e-04 - mean_absolute_error: 0.0207 - val_loss: 4.4658e-04 - val_mean_absolute_error: 0.0178
# Epoch 295/300
# 24/24 [==============================] - 0s 12ms/step - loss: 7.7707e-04 - mean_absolute_error: 0.0210 - val_loss: 3.8030e-04 - val_mean_absolute_error: 0.0154
# Epoch 296/300
# 24/24 [==============================] - 0s 14ms/step - loss: 8.7747e-04 - mean_absolute_error: 0.0216 - val_loss: 0.0019 - val_mean_absolute_error: 0.0407
# Epoch 297/300
# 24/24 [==============================] - 0s 18ms/step - loss: 8.4401e-04 - mean_absolute_error: 0.0219 - val_loss: 2.3257e-04 - val_mean_absolute_error: 0.0114
# Epoch 298/300
# 24/24 [==============================] - 0s 17ms/step - loss: 7.1130e-04 - mean_absolute_error: 0.0202 - val_loss: 5.2874e-04 - val_mean_absolute_error: 0.0198
# Epoch 299/300
# 24/24 [==============================] - 0s 18ms/step - loss: 7.0871e-04 - mean_absolute_error: 0.0207 - val_loss: 2.6132e-04 - val_mean_absolute_error: 0.0126
# Epoch 300/300
# 24/24 [==============================] - 0s 20ms/step - loss: 7.5214e-04 - mean_absolute_error: 0.0213 - val_loss: 4.7002e-04 - val_mean_absolute_error: 0.0184

# %%
def make_predictions(model, x_train, x_test):
    train_predict = model.predict(x_train)
    test_predict = model.predict(x_test)
    return train_predict, test_predict

# %%
train_predict, test_predict = make_predictions(model, x_train, x_test)
# Out:
# 24/24 [==============================] - 1s 7ms/step
# 5/5 [==============================] - 0s 7ms/step
# 24/24 [==============================] - 1s 6ms/step
# 5/5 [==============================] - 0s 5ms/step

# %%
def inverse_transform(scaler, y_train, train_predict, y_test, test_predict):
    train_predict = scaler.inverse_transform(train_predict)
    test_predict = scaler.inverse_transform(test_predict)
    return train_predict, test_predict

# %%
train_predict, test_predict = inverse_transform(scaler, y_train, train_predict, y_test, test_predict)

# %%
def evaluate_model(y_train, train_predict, y_test, test_predict):
    train_rmse = math.sqrt(mean_squared_error(y_train, train_predict))
    test_rmse = math.sqrt(mean_squared_error(y_test, test_predict))
    print(f"Training RMSE: {train_rmse}")
    print(f"Testing RMSE: {test_rmse}")

# %%
evaluate_model(y_train, train_predict, y_test, test_predict)
# Out:
# Training RMSE: 137.74429002234803
# Testing RMSE: 181.2562554856764
# Training RMSE: 137.2039114437392
# Testing RMSE: 181.5306267167335

# %%
def plot_predictions(original_data, train_predict, test_predict, company_name):
    look_back = 60
    train_predict_plot = np.empty_like(original_data)
    train_predict_plot[:] = np.nan
    train_predict_plot[look_back : len(train_predict) + look_back] = train_predict.flatten()

    test_predict_plot = np.empty_like(original_data)
    test_predict_plot[:] = np.nan
    test_start = len(original_data) - len(test_predict)
    test_predict_plot[test_start:] = test_predict.flatten()

    plt.figure(figsize=(15, 6))
    plt.plot(original_data, color='black', label=f"Actual {company_name} price")
    plt.plot(train_predict_plot, color='red', label=f'Predicted {company_name} price (train_set)')
    plt.plot(test_predict_plot, color='blue', label=f"Predicted {company_name} price (test_set)")
    plt.title(f"{company_name} share price")
    plt.xlabel("Time")
    plt.ylabel(f"{company_name} share price")
    plt.legend()
    plt.show()

# %%
plot_predictions(new_df, train_predict, test_predict, company_name)

# %%
predictions = model.predict(x_test)

actual_values_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))
predicted_values_inverse = scaler.inverse_transform(predictions)

comparison_df = pd.DataFrame({'Actual Close Prices': actual_values_inverse.flatten(), 'Predicted Close Prices': predicted_values_inverse.flatten()})
print(comparison_df.head())

plt.figure(figsize=(10, 5))
plt.plot(actual_values_inverse.flatten(), marker='.', label="Actual Close Prices")
plt.plot(predicted_values_inverse.flatten(), 'r', label="Predicted Close Prices")
plt.ylabel('Close Price')
plt.xlabel('Time Step')
plt.legend()
plt.title('Comparison of Actual vs Predicted Close Prices')
plt.show()
# Out:
# 5/5 [==============================] - 0s 6ms/step
#    Actual Close Prices  Predicted Close Prices
# 0           180.570007              176.106979
# 1           180.960007              179.045914
# 2           183.789993              178.838684
# 3           183.309998              181.907028
# 4           183.949997              180.958832
