# %%
# !pip install --upgrade mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mplfinance) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mplfinance) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mplfinance) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.10b0

# %%
import numpy as np
import pandas as pd
import math
import random
import datetime as dt
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
from mplfinance.original_flavor import candlestick_ohlc
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import metrics
from sklearn.metrics import mean_squared_error
import yfinance as yf

# %%
# Downloading stock data for Apple (AAPL) from Yahoo Finance
stock_data = yf.download('AAPL', start='2020-01-01', end='2024-01-01')
specific_df = pd.DataFrame(stock_data).reset_index()
specific_df['Name'] = 'AAPL'
print(specific_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2020-01-02  74.059998  75.150002  73.797501  75.087502  73.152649
# 1 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.441460
# 2 2020-01-06  73.447502  74.989998  73.187500  74.949997  73.018684
# 3 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.675285
# 4 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.844360
#
#       Volume  Name
# 0  135480400  AAPL
# 1  146322800  AAPL
# 2  118387200  AAPL
# 3  108872000  AAPL
# 4  132079200  AAPL

# %%
matplotlib_date = mdates.date2num(specific_df['Date'])
ohlc = np.vstack((matplotlib_date, specific_df['Open'], specific_df['High'], specific_df['Low'], specific_df['Close'])).T
plt.figure(figsize=(15,6))
ax=plt.subplot()
candlestick_ohlc(ax, ohlc, width=0.6, colorup='g', colordown='r')
ax.xaxis_date()
plt.title('Candlestick Chart')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
specific_df.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2020-01-02  74.059998  75.150002  73.797501  75.087502  73.152649
# 1 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.441460
# 2 2020-01-06  73.447502  74.989998  73.187500  74.949997  73.018684
# 3 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.675285
# 4 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.844360
#
#       Volume  Name
# 0  135480400  AAPL
# 1  146322800  AAPL
# 2  118387200  AAPL
# 3  108872000  AAPL
# 4  132079200  AAPL

# %%
new_df = specific_df.reset_index()['Close']
scaler=MinMaxScaler()
scaled_data = scaler.fit_transform(np.array(new_df).reshape(-1,1))

# %%
from sklearn.model_selection import train_test_split
test_size = 0.2
train_data, test_data = train_test_split(scaled_data, test_size=test_size, shuffle=False)

# %%
def generate_sequences_and_labels(data, n_past):
    sequences = [data[i - n_past:i, 0] for i in range(n_past, len(data))]
    labels = [data[i, 0] for i in range(n_past, len(data))]
    return np.array(sequences), np.array(labels)

# %%
n_past = 60
x_train, y_train = generate_sequences_and_labels(train_data, n_past)
x_test, y_test = generate_sequences_and_labels(test_data, n_past)

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1],1)

# %%
def build_lstm_model(input_shape):
  model = Sequential()
  model.add(LSTM(units=50, return_sequences=True, input_shape=[x_train.shape[1], 1]))
  model.add(Dense(10))
  model.add(LSTM(units=25))
  # model.add(Dense(5))
  model.add(Dropout(0.2))
  model.add(Dense(1))
  return model

# %%
def compile_lstm_model(model):
  model.compile(loss='mean_squared_error', optimizer='adam', metrics='mean_absolute_error')

# %%
def train_lstm_model(model, x_train, y_train, x_test, y_test):
  model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=200, batch_size=32, verbose=1)

# %%
model = build_lstm_model(x_train.shape[1])
compile_lstm_model(model)
train_lstm_model(model, x_train, y_train, x_test, y_test)
# Out:
# Epoch 1/200
# 24/24 [==============================] - 5s 49ms/step - loss: 0.0973 - mean_absolute_error: 0.2428 - val_loss: 0.0652 - val_mean_absolute_error: 0.2505
# Epoch 2/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0181 - mean_absolute_error: 0.1066 - val_loss: 0.0255 - val_mean_absolute_error: 0.1530
# Epoch 3/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0120 - mean_absolute_error: 0.0860 - val_loss: 0.0093 - val_mean_absolute_error: 0.0864
# Epoch 4/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0084 - mean_absolute_error: 0.0711 - val_loss: 0.0094 - val_mean_absolute_error: 0.0875
# Epoch 5/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0087 - mean_absolute_error: 0.0713 - val_loss: 0.0032 - val_mean_absolute_error: 0.0495
# Epoch 6/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0083 - mean_absolute_error: 0.0706 - val_loss: 0.0120 - val_mean_absolute_error: 0.1014
# Epoch 7/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0072 - mean_absolute_error: 0.0655 - val_loss: 0.0044 - val_mean_absolute_error: 0.0577
# Epoch 8/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0065 - mean_absolute_error: 0.0632 - val_loss: 0.0027 - val_mean_absolute_error: 0.0459
# Epoch 9/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0076 - mean_absolute_error: 0.0669 - val_loss: 0.0042 - val_mean_absolute_error: 0.0566
# Epoch 10/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0065 - mean_absolute_error: 0.0623 - val_loss: 0.0037 - val_mean_absolute_error: 0.0528
# Epoch 11/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0070 - mean_absolute_error: 0.0626 - val_loss: 0.0036 - val_mean_absolute_error: 0.0523
# Epoch 12/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0064 - mean_absolute_error: 0.0618 - val_loss: 0.0046 - val_mean_absolute_error: 0.0596
# Epoch 13/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0054 - mean_absolute_error: 0.0560 - val_loss: 0.0050 - val_mean_absolute_error: 0.0624
# Epoch 14/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0056 - mean_absolute_error: 0.0559 - val_loss: 0.0021 - val_mean_absolute_error: 0.0394
# Epoch 15/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0055 - mean_absolute_error: 0.0580 - val_loss: 0.0027 - val_mean_absolute_error: 0.0453
# Epoch 16/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0057 - mean_absolute_error: 0.0580 - val_loss: 0.0015 - val_mean_absolute_error: 0.0321
# Epoch 17/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0055 - mean_absolute_error: 0.0558 - val_loss: 0.0105 - val_mean_absolute_error: 0.0952
# Epoch 18/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0060 - mean_absolute_error: 0.0596 - val_loss: 0.0028 - val_mean_absolute_error: 0.0461
# Epoch 19/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0049 - mean_absolute_error: 0.0535 - val_loss: 0.0035 - val_mean_absolute_error: 0.0513
# Epoch 20/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0061 - mean_absolute_error: 0.0602 - val_loss: 0.0057 - val_mean_absolute_error: 0.0673
# Epoch 21/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0050 - mean_absolute_error: 0.0542 - val_loss: 0.0059 - val_mean_absolute_error: 0.0689
# Epoch 22/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0048 - mean_absolute_error: 0.0528 - val_loss: 0.0032 - val_mean_absolute_error: 0.0488
# Epoch 23/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0046 - mean_absolute_error: 0.0525 - val_loss: 0.0028 - val_mean_absolute_error: 0.0462
# Epoch 24/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0046 - mean_absolute_error: 0.0524 - val_loss: 0.0015 - val_mean_absolute_error: 0.0318
# Epoch 25/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0051 - mean_absolute_error: 0.0542 - val_loss: 0.0014 - val_mean_absolute_error: 0.0304
# Epoch 26/200
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0045 - mean_absolute_error: 0.0513 - val_loss: 0.0013 - val_mean_absolute_error: 0.0297
# Epoch 27/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0045 - mean_absolute_error: 0.0514 - val_loss: 0.0016 - val_mean_absolute_error: 0.0337
# Epoch 28/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0044 - mean_absolute_error: 0.0512 - val_loss: 0.0032 - val_mean_absolute_error: 0.0490
# Epoch 29/200
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0044 - mean_absolute_error: 0.0521 - val_loss: 0.0018 - val_mean_absolute_error: 0.0359
# Epoch 30/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0042 - mean_absolute_error: 0.0492 - val_loss: 0.0030 - val_mean_absolute_error: 0.0479
# Epoch 31/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0048 - mean_absolute_error: 0.0528 - val_loss: 0.0012 - val_mean_absolute_error: 0.0281
# Epoch 32/200
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0047 - mean_absolute_error: 0.0532 - val_loss: 0.0014 - val_mean_absolute_error: 0.0307
# Epoch 33/200
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0042 - mean_absolute_error: 0.0507 - val_loss: 0.0015 - val_mean_absolute_error: 0.0330
# Epoch 34/200
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0046 - mean_absolute_error: 0.0519 - val_loss: 0.0013 - val_mean_absolute_error: 0.0304
# Epoch 35/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0045 - mean_absolute_error: 0.0517 - val_loss: 0.0058 - val_mean_absolute_error: 0.0693
# Epoch 36/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0040 - mean_absolute_error: 0.0480 - val_loss: 0.0021 - val_mean_absolute_error: 0.0393
# Epoch 37/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0043 - mean_absolute_error: 0.0505 - val_loss: 0.0029 - val_mean_absolute_error: 0.0478
# Epoch 38/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0044 - mean_absolute_error: 0.0500 - val_loss: 0.0016 - val_mean_absolute_error: 0.0346
# Epoch 39/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0044 - mean_absolute_error: 0.0505 - val_loss: 0.0015 - val_mean_absolute_error: 0.0335
# Epoch 40/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0036 - mean_absolute_error: 0.0460 - val_loss: 0.0011 - val_mean_absolute_error: 0.0260
# Epoch 41/200
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0040 - mean_absolute_error: 0.0481 - val_loss: 0.0024 - val_mean_absolute_error: 0.0432
# Epoch 42/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0036 - mean_absolute_error: 0.0459 - val_loss: 0.0025 - val_mean_absolute_error: 0.0442
# Epoch 43/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0037 - mean_absolute_error: 0.0457 - val_loss: 0.0026 - val_mean_absolute_error: 0.0451
# Epoch 44/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0036 - mean_absolute_error: 0.0452 - val_loss: 0.0029 - val_mean_absolute_error: 0.0482
# Epoch 45/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0035 - mean_absolute_error: 0.0457 - val_loss: 0.0056 - val_mean_absolute_error: 0.0688
# Epoch 46/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0042 - mean_absolute_error: 0.0505 - val_loss: 0.0024 - val_mean_absolute_error: 0.0431
# Epoch 47/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0036 - mean_absolute_error: 0.0464 - val_loss: 0.0043 - val_mean_absolute_error: 0.0594
# Epoch 48/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0040 - mean_absolute_error: 0.0484 - val_loss: 0.0062 - val_mean_absolute_error: 0.0729
# Epoch 49/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0036 - mean_absolute_error: 0.0464 - val_loss: 0.0022 - val_mean_absolute_error: 0.0412
# Epoch 50/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0031 - mean_absolute_error: 0.0430 - val_loss: 0.0028 - val_mean_absolute_error: 0.0474
# Epoch 51/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0035 - mean_absolute_error: 0.0457 - val_loss: 0.0018 - val_mean_absolute_error: 0.0368
# Epoch 52/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0035 - mean_absolute_error: 0.0449 - val_loss: 0.0026 - val_mean_absolute_error: 0.0455
# Epoch 53/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0033 - mean_absolute_error: 0.0432 - val_loss: 0.0058 - val_mean_absolute_error: 0.0705
# Epoch 54/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0034 - mean_absolute_error: 0.0444 - val_loss: 0.0013 - val_mean_absolute_error: 0.0314
# Epoch 55/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0029 - mean_absolute_error: 0.0415 - val_loss: 9.8437e-04 - val_mean_absolute_error: 0.0255
# Epoch 56/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0034 - mean_absolute_error: 0.0442 - val_loss: 0.0040 - val_mean_absolute_error: 0.0577
# Epoch 57/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0038 - mean_absolute_error: 0.0467 - val_loss: 0.0039 - val_mean_absolute_error: 0.0567
# Epoch 58/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0031 - mean_absolute_error: 0.0431 - val_loss: 0.0013 - val_mean_absolute_error: 0.0317
# Epoch 59/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0031 - mean_absolute_error: 0.0423 - val_loss: 0.0018 - val_mean_absolute_error: 0.0381
# Epoch 60/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0417 - val_loss: 0.0032 - val_mean_absolute_error: 0.0511
# Epoch 61/200
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0035 - mean_absolute_error: 0.0448 - val_loss: 8.1102e-04 - val_mean_absolute_error: 0.0217
# Epoch 62/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0035 - mean_absolute_error: 0.0442 - val_loss: 8.0442e-04 - val_mean_absolute_error: 0.0217
# Epoch 63/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0033 - mean_absolute_error: 0.0431 - val_loss: 0.0029 - val_mean_absolute_error: 0.0487
# Epoch 64/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0032 - mean_absolute_error: 0.0438 - val_loss: 0.0010 - val_mean_absolute_error: 0.0236
# Epoch 65/200
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0032 - mean_absolute_error: 0.0430 - val_loss: 0.0016 - val_mean_absolute_error: 0.0347
# Epoch 66/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0028 - mean_absolute_error: 0.0401 - val_loss: 0.0017 - val_mean_absolute_error: 0.0365
# Epoch 67/200
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0026 - mean_absolute_error: 0.0389 - val_loss: 0.0015 - val_mean_absolute_error: 0.0339
# Epoch 68/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0029 - mean_absolute_error: 0.0415 - val_loss: 0.0012 - val_mean_absolute_error: 0.0290
# Epoch 69/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0029 - mean_absolute_error: 0.0405 - val_loss: 0.0014 - val_mean_absolute_error: 0.0321
# Epoch 70/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0028 - mean_absolute_error: 0.0403 - val_loss: 0.0011 - val_mean_absolute_error: 0.0284
# Epoch 71/200
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0030 - mean_absolute_error: 0.0416 - val_loss: 0.0011 - val_mean_absolute_error: 0.0277
# Epoch 72/200
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0024 - mean_absolute_error: 0.0382 - val_loss: 0.0021 - val_mean_absolute_error: 0.0416
# Epoch 73/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0383 - val_loss: 0.0027 - val_mean_absolute_error: 0.0474
# Epoch 74/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0027 - mean_absolute_error: 0.0404 - val_loss: 0.0011 - val_mean_absolute_error: 0.0287
# Epoch 75/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0028 - mean_absolute_error: 0.0403 - val_loss: 7.1477e-04 - val_mean_absolute_error: 0.0196
# Epoch 76/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0024 - mean_absolute_error: 0.0368 - val_loss: 0.0010 - val_mean_absolute_error: 0.0274
# Epoch 77/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0354 - val_loss: 0.0028 - val_mean_absolute_error: 0.0485
# Epoch 78/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0376 - val_loss: 0.0018 - val_mean_absolute_error: 0.0384
# Epoch 79/200
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0025 - mean_absolute_error: 0.0385 - val_loss: 0.0015 - val_mean_absolute_error: 0.0337
# Epoch 80/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0370 - val_loss: 7.0323e-04 - val_mean_absolute_error: 0.0213
# Epoch 81/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0384 - val_loss: 0.0018 - val_mean_absolute_error: 0.0384
# Epoch 82/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0022 - mean_absolute_error: 0.0364 - val_loss: 6.7385e-04 - val_mean_absolute_error: 0.0207
# Epoch 83/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0022 - mean_absolute_error: 0.0362 - val_loss: 0.0011 - val_mean_absolute_error: 0.0288
# Epoch 84/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0024 - mean_absolute_error: 0.0367 - val_loss: 6.9412e-04 - val_mean_absolute_error: 0.0212
# Epoch 85/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0365 - val_loss: 6.6536e-04 - val_mean_absolute_error: 0.0189
# Epoch 86/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0023 - mean_absolute_error: 0.0364 - val_loss: 7.6409e-04 - val_mean_absolute_error: 0.0231
# Epoch 87/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0365 - val_loss: 7.8876e-04 - val_mean_absolute_error: 0.0235
# Epoch 88/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0023 - mean_absolute_error: 0.0359 - val_loss: 9.0493e-04 - val_mean_absolute_error: 0.0258
# Epoch 89/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0349 - val_loss: 9.4450e-04 - val_mean_absolute_error: 0.0264
# Epoch 90/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0353 - val_loss: 0.0017 - val_mean_absolute_error: 0.0369
# Epoch 91/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0024 - mean_absolute_error: 0.0367 - val_loss: 0.0014 - val_mean_absolute_error: 0.0330
# Epoch 92/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0023 - mean_absolute_error: 0.0358 - val_loss: 0.0010 - val_mean_absolute_error: 0.0275
# Epoch 93/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0021 - mean_absolute_error: 0.0343 - val_loss: 0.0016 - val_mean_absolute_error: 0.0356
# Epoch 94/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0022 - mean_absolute_error: 0.0353 - val_loss: 5.6545e-04 - val_mean_absolute_error: 0.0186
# Epoch 95/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0343 - val_loss: 0.0013 - val_mean_absolute_error: 0.0314
# Epoch 96/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0344 - val_loss: 0.0023 - val_mean_absolute_error: 0.0442
# Epoch 97/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0324 - val_loss: 0.0013 - val_mean_absolute_error: 0.0313
# Epoch 98/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0327 - val_loss: 5.1377e-04 - val_mean_absolute_error: 0.0168
# Epoch 99/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0347 - val_loss: 0.0017 - val_mean_absolute_error: 0.0371
# Epoch 100/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0334 - val_loss: 0.0016 - val_mean_absolute_error: 0.0365
# Epoch 101/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0018 - mean_absolute_error: 0.0327 - val_loss: 0.0018 - val_mean_absolute_error: 0.0385
# Epoch 102/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0337 - val_loss: 0.0014 - val_mean_absolute_error: 0.0338
# Epoch 103/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0339 - val_loss: 8.6433e-04 - val_mean_absolute_error: 0.0251
# Epoch 104/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0326 - val_loss: 6.0834e-04 - val_mean_absolute_error: 0.0203
# Epoch 105/200
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0321 - val_loss: 7.9937e-04 - val_mean_absolute_error: 0.0239
# Epoch 106/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0016 - mean_absolute_error: 0.0305 - val_loss: 5.8054e-04 - val_mean_absolute_error: 0.0197
# Epoch 107/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0016 - mean_absolute_error: 0.0316 - val_loss: 0.0018 - val_mean_absolute_error: 0.0392
# Epoch 108/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0019 - mean_absolute_error: 0.0332 - val_loss: 0.0013 - val_mean_absolute_error: 0.0322
# Epoch 109/200
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0312 - val_loss: 0.0022 - val_mean_absolute_error: 0.0432
# Epoch 110/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0016 - mean_absolute_error: 0.0305 - val_loss: 0.0013 - val_mean_absolute_error: 0.0329
# Epoch 111/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0314 - val_loss: 0.0019 - val_mean_absolute_error: 0.0400
# Epoch 112/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0337 - val_loss: 0.0025 - val_mean_absolute_error: 0.0469
# Epoch 113/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0337 - val_loss: 0.0017 - val_mean_absolute_error: 0.0372
# Epoch 114/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0298 - val_loss: 4.2582e-04 - val_mean_absolute_error: 0.0153
# Epoch 115/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0310 - val_loss: 4.3927e-04 - val_mean_absolute_error: 0.0153
# Epoch 116/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0312 - val_loss: 4.1754e-04 - val_mean_absolute_error: 0.0154
# Epoch 117/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0328 - val_loss: 0.0027 - val_mean_absolute_error: 0.0485
# Epoch 118/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0304 - val_loss: 7.6622e-04 - val_mean_absolute_error: 0.0236
# Epoch 119/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0276 - val_loss: 4.1924e-04 - val_mean_absolute_error: 0.0158
# Epoch 120/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0288 - val_loss: 5.4747e-04 - val_mean_absolute_error: 0.0193
# Epoch 121/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0016 - mean_absolute_error: 0.0306 - val_loss: 5.4207e-04 - val_mean_absolute_error: 0.0191
# Epoch 122/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0294 - val_loss: 4.1006e-04 - val_mean_absolute_error: 0.0157
# Epoch 123/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0016 - mean_absolute_error: 0.0301 - val_loss: 0.0017 - val_mean_absolute_error: 0.0380
# Epoch 124/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0301 - val_loss: 8.2968e-04 - val_mean_absolute_error: 0.0249
# Epoch 125/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0287 - val_loss: 0.0016 - val_mean_absolute_error: 0.0363
# Epoch 126/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0286 - val_loss: 6.5150e-04 - val_mean_absolute_error: 0.0215
# Epoch 127/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0288 - val_loss: 0.0014 - val_mean_absolute_error: 0.0341
# Epoch 128/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0280 - val_loss: 5.2658e-04 - val_mean_absolute_error: 0.0190
# Epoch 129/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0016 - mean_absolute_error: 0.0308 - val_loss: 4.7368e-04 - val_mean_absolute_error: 0.0157
# Epoch 130/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0015 - mean_absolute_error: 0.0303 - val_loss: 0.0017 - val_mean_absolute_error: 0.0379
# Epoch 131/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0284 - val_loss: 0.0017 - val_mean_absolute_error: 0.0376
# Epoch 132/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0279 - val_loss: 0.0011 - val_mean_absolute_error: 0.0294
# Epoch 133/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0275 - val_loss: 0.0012 - val_mean_absolute_error: 0.0307
# Epoch 134/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0277 - val_loss: 0.0016 - val_mean_absolute_error: 0.0375
# Epoch 135/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0281 - val_loss: 0.0018 - val_mean_absolute_error: 0.0396
# Epoch 136/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0275 - val_loss: 9.1516e-04 - val_mean_absolute_error: 0.0268
# Epoch 137/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0283 - val_loss: 9.4272e-04 - val_mean_absolute_error: 0.0274
# Epoch 138/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0268 - val_loss: 8.2000e-04 - val_mean_absolute_error: 0.0251
# Epoch 139/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0259 - val_loss: 4.9055e-04 - val_mean_absolute_error: 0.0183
# Epoch 140/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0273 - val_loss: 4.7785e-04 - val_mean_absolute_error: 0.0179
# Epoch 141/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0266 - val_loss: 6.7398e-04 - val_mean_absolute_error: 0.0223
# Epoch 142/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0261 - val_loss: 0.0010 - val_mean_absolute_error: 0.0289
# Epoch 143/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0266 - val_loss: 0.0013 - val_mean_absolute_error: 0.0327
# Epoch 144/200
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0011 - mean_absolute_error: 0.0255 - val_loss: 3.1582e-04 - val_mean_absolute_error: 0.0130
# Epoch 145/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0273 - val_loss: 0.0014 - val_mean_absolute_error: 0.0340
# Epoch 146/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0012 - mean_absolute_error: 0.0266 - val_loss: 5.8401e-04 - val_mean_absolute_error: 0.0206
# Epoch 147/200
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0012 - mean_absolute_error: 0.0263 - val_loss: 0.0011 - val_mean_absolute_error: 0.0305
# Epoch 148/200
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0013 - mean_absolute_error: 0.0273 - val_loss: 0.0016 - val_mean_absolute_error: 0.0378
# Epoch 149/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0266 - val_loss: 0.0014 - val_mean_absolute_error: 0.0351
# Epoch 150/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0269 - val_loss: 5.3408e-04 - val_mean_absolute_error: 0.0196
# Epoch 151/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0256 - val_loss: 0.0010 - val_mean_absolute_error: 0.0287
# Epoch 152/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0261 - val_loss: 0.0015 - val_mean_absolute_error: 0.0363
# Epoch 153/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0257 - val_loss: 6.0647e-04 - val_mean_absolute_error: 0.0212
# Epoch 154/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0010 - mean_absolute_error: 0.0247 - val_loss: 6.3278e-04 - val_mean_absolute_error: 0.0218
# Epoch 155/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0263 - val_loss: 0.0012 - val_mean_absolute_error: 0.0324
# Epoch 156/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0265 - val_loss: 0.0010 - val_mean_absolute_error: 0.0291
# Epoch 157/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0247 - val_loss: 0.0012 - val_mean_absolute_error: 0.0313
# Epoch 158/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0247 - val_loss: 3.7266e-04 - val_mean_absolute_error: 0.0156
# Epoch 159/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0010 - mean_absolute_error: 0.0242 - val_loss: 8.4986e-04 - val_mean_absolute_error: 0.0261
# Epoch 160/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - mean_absolute_error: 0.0252 - val_loss: 0.0016 - val_mean_absolute_error: 0.0379
# Epoch 161/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0266 - val_loss: 8.5415e-04 - val_mean_absolute_error: 0.0262
# Epoch 162/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0010 - mean_absolute_error: 0.0241 - val_loss: 6.6024e-04 - val_mean_absolute_error: 0.0226
# Epoch 163/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0247 - val_loss: 4.0722e-04 - val_mean_absolute_error: 0.0166
# Epoch 164/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0010 - mean_absolute_error: 0.0246 - val_loss: 4.2908e-04 - val_mean_absolute_error: 0.0173
# Epoch 165/200
# 24/24 [==============================] - 0s 12ms/step - loss: 9.9311e-04 - mean_absolute_error: 0.0245 - val_loss: 6.3842e-04 - val_mean_absolute_error: 0.0223
# Epoch 166/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0010 - mean_absolute_error: 0.0244 - val_loss: 6.9677e-04 - val_mean_absolute_error: 0.0235
# Epoch 167/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0255 - val_loss: 6.8201e-04 - val_mean_absolute_error: 0.0232
# Epoch 168/200
# 24/24 [==============================] - 0s 14ms/step - loss: 9.5585e-04 - mean_absolute_error: 0.0238 - val_loss: 8.9933e-04 - val_mean_absolute_error: 0.0272
# Epoch 169/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0010 - mean_absolute_error: 0.0238 - val_loss: 4.9720e-04 - val_mean_absolute_error: 0.0192
# Epoch 170/200
# 24/24 [==============================] - 0s 13ms/step - loss: 9.7197e-04 - mean_absolute_error: 0.0237 - val_loss: 7.1440e-04 - val_mean_absolute_error: 0.0238
# Epoch 171/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0010 - mean_absolute_error: 0.0244 - val_loss: 0.0010 - val_mean_absolute_error: 0.0289
# Epoch 172/200
# 24/24 [==============================] - 0s 12ms/step - loss: 9.3013e-04 - mean_absolute_error: 0.0238 - val_loss: 2.6306e-04 - val_mean_absolute_error: 0.0123
# Epoch 173/200
# 24/24 [==============================] - 0s 12ms/step - loss: 9.2546e-04 - mean_absolute_error: 0.0228 - val_loss: 3.3760e-04 - val_mean_absolute_error: 0.0148
# Epoch 174/200
# 24/24 [==============================] - 0s 12ms/step - loss: 9.4064e-04 - mean_absolute_error: 0.0232 - val_loss: 3.3493e-04 - val_mean_absolute_error: 0.0148
# Epoch 175/200
# 24/24 [==============================] - 0s 12ms/step - loss: 9.4892e-04 - mean_absolute_error: 0.0235 - val_loss: 2.5555e-04 - val_mean_absolute_error: 0.0120
# Epoch 176/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0254 - val_loss: 3.8340e-04 - val_mean_absolute_error: 0.0162
# Epoch 177/200
# 24/24 [==============================] - 0s 12ms/step - loss: 9.2523e-04 - mean_absolute_error: 0.0232 - val_loss: 0.0013 - val_mean_absolute_error: 0.0329
# Epoch 178/200
# 24/24 [==============================] - 0s 12ms/step - loss: 9.1920e-04 - mean_absolute_error: 0.0233 - val_loss: 4.5570e-04 - val_mean_absolute_error: 0.0183
# Epoch 179/200
# 24/24 [==============================] - 0s 12ms/step - loss: 9.1291e-04 - mean_absolute_error: 0.0233 - val_loss: 2.6260e-04 - val_mean_absolute_error: 0.0120
# Epoch 180/200
# 24/24 [==============================] - 0s 14ms/step - loss: 9.2732e-04 - mean_absolute_error: 0.0229 - val_loss: 7.4800e-04 - val_mean_absolute_error: 0.0245
# Epoch 181/200
# 24/24 [==============================] - 0s 19ms/step - loss: 8.4142e-04 - mean_absolute_error: 0.0222 - val_loss: 0.0014 - val_mean_absolute_error: 0.0344
# Epoch 182/200
# 24/24 [==============================] - 0s 18ms/step - loss: 8.7451e-04 - mean_absolute_error: 0.0223 - val_loss: 2.6141e-04 - val_mean_absolute_error: 0.0124
# Epoch 183/200
# 24/24 [==============================] - 0s 17ms/step - loss: 8.8496e-04 - mean_absolute_error: 0.0228 - val_loss: 2.5156e-04 - val_mean_absolute_error: 0.0121
# Epoch 184/200
# 24/24 [==============================] - 0s 17ms/step - loss: 8.9065e-04 - mean_absolute_error: 0.0225 - val_loss: 3.9388e-04 - val_mean_absolute_error: 0.0165
# Epoch 185/200
# 24/24 [==============================] - 0s 18ms/step - loss: 8.3448e-04 - mean_absolute_error: 0.0223 - val_loss: 2.5240e-04 - val_mean_absolute_error: 0.0119
# Epoch 186/200
# 24/24 [==============================] - 0s 15ms/step - loss: 7.9570e-04 - mean_absolute_error: 0.0220 - val_loss: 3.6779e-04 - val_mean_absolute_error: 0.0159
# Epoch 187/200
# 24/24 [==============================] - 0s 12ms/step - loss: 9.9617e-04 - mean_absolute_error: 0.0239 - val_loss: 4.2038e-04 - val_mean_absolute_error: 0.0174
# Epoch 188/200
# 24/24 [==============================] - 0s 13ms/step - loss: 9.2756e-04 - mean_absolute_error: 0.0229 - val_loss: 0.0011 - val_mean_absolute_error: 0.0311
# Epoch 189/200
# 24/24 [==============================] - 0s 12ms/step - loss: 8.6827e-04 - mean_absolute_error: 0.0228 - val_loss: 2.5201e-04 - val_mean_absolute_error: 0.0122
# Epoch 190/200
# 24/24 [==============================] - 0s 14ms/step - loss: 8.2347e-04 - mean_absolute_error: 0.0219 - val_loss: 2.4634e-04 - val_mean_absolute_error: 0.0117
# Epoch 191/200
# 24/24 [==============================] - 0s 12ms/step - loss: 9.0403e-04 - mean_absolute_error: 0.0232 - val_loss: 2.4351e-04 - val_mean_absolute_error: 0.0120
# Epoch 192/200
# 24/24 [==============================] - 0s 14ms/step - loss: 8.4966e-04 - mean_absolute_error: 0.0221 - val_loss: 2.3955e-04 - val_mean_absolute_error: 0.0117
# Epoch 193/200
# 24/24 [==============================] - 0s 14ms/step - loss: 8.3168e-04 - mean_absolute_error: 0.0218 - val_loss: 3.1975e-04 - val_mean_absolute_error: 0.0146
# Epoch 194/200
# 24/24 [==============================] - 0s 13ms/step - loss: 8.6389e-04 - mean_absolute_error: 0.0223 - val_loss: 2.8925e-04 - val_mean_absolute_error: 0.0135
# Epoch 195/200
# 24/24 [==============================] - 0s 14ms/step - loss: 8.1916e-04 - mean_absolute_error: 0.0218 - val_loss: 4.6296e-04 - val_mean_absolute_error: 0.0186
# Epoch 196/200
# 24/24 [==============================] - 0s 12ms/step - loss: 8.6198e-04 - mean_absolute_error: 0.0221 - val_loss: 3.1877e-04 - val_mean_absolute_error: 0.0146
# Epoch 197/200
# 24/24 [==============================] - 0s 12ms/step - loss: 8.3849e-04 - mean_absolute_error: 0.0217 - val_loss: 7.7787e-04 - val_mean_absolute_error: 0.0252
# Epoch 198/200
# 24/24 [==============================] - 0s 15ms/step - loss: 8.5741e-04 - mean_absolute_error: 0.0219 - val_loss: 2.7047e-04 - val_mean_absolute_error: 0.0130
# Epoch 199/200
# 24/24 [==============================] - 0s 12ms/step - loss: 8.0809e-04 - mean_absolute_error: 0.0216 - val_loss: 5.0882e-04 - val_mean_absolute_error: 0.0196
# Epoch 200/200
# 24/24 [==============================] - 0s 14ms/step - loss: 8.2525e-04 - mean_absolute_error: 0.0217 - val_loss: 2.6201e-04 - val_mean_absolute_error: 0.0127

# %%
def make_predictions(model, x_train, x_test):
    train_predict = model.predict(x_train)
    test_predict = model.predict(x_test)
    return train_predict, test_predict

# %%
train_predict, test_predict = make_predictions(model, x_train, x_test)
# Out:
# 24/24 [==============================] - 1s 5ms/step
# 5/5 [==============================] - 0s 6ms/step

# %%
def inverse_transform(scaler, y_train, train_predict, y_test, test_predict):
    train_predict = scaler.inverse_transform(train_predict)
    test_predict = scaler.inverse_transform(test_predict)
    return train_predict, test_predict

# %%
train_predict, test_predict = inverse_transform(scaler, y_train, train_predict, y_test, test_predict)

# %%
def evaluate_model(y_train, train_predict, y_test, test_predict):
    train_rmse = math.sqrt(mean_squared_error(y_train, train_predict))
    test_rmse = math.sqrt(mean_squared_error(y_test, test_predict))
    print(f"Training RMSE: {train_rmse}")
    print(f"Testing RMSE: {test_rmse}")

# %%
evaluate_model(y_train, train_predict, y_test, test_predict)
# Out:
# Training RMSE: 137.66576764213946
# Testing RMSE: 182.6835719305512

# %%
def plot_predictions(original_data, train_predict, test_predict, company_name):
    look_back = 60
    train_predict_plot = np.empty_like(original_data)
    train_predict_plot[:] = np.nan
    train_predict_plot[look_back : len(train_predict) + look_back] = train_predict.flatten()

    test_predict_plot = np.empty_like(original_data)
    test_predict_plot[:] = np.nan
    test_start = len(original_data) - len(test_predict)
    test_predict_plot[test_start:] = test_predict.flatten()

    plt.figure(figsize=(15, 6))
    plt.plot(original_data, color='black', label=f"Actual {company_name} price")
    plt.plot(train_predict_plot, color='red', label=f'Predicted {company_name} price (train_set)')
    plt.plot(test_predict_plot, color='blue', label=f"Predicted {company_name} price (test_set)")
    plt.title(f"{company_name} share price")
    plt.xlabel("Time")
    plt.ylabel(f"{company_name} share price")
    plt.legend()
    plt.show()

# %%
plot_predictions(new_df, train_predict, test_predict, company_name)

# %%
predictions = model.predict(x_test)

actual_values_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))
predicted_values_inverse = scaler.inverse_transform(predictions)

comparison_df = pd.DataFrame({'Actual Close Prices': actual_values_inverse.flatten(), 'Predicted Close Prices': predicted_values_inverse.flatten()})
print(comparison_df.head())

plt.figure(figsize=(10, 5))
plt.plot(actual_values_inverse.flatten(), marker='.', label="Actual Close Prices")
plt.plot(predicted_values_inverse.flatten(), 'r', label="Predicted Close Prices")
plt.ylabel('Close Price')
plt.xlabel('Time Step')
plt.legend()
plt.title('Comparison of Actual vs Predicted Close Prices')
plt.show()
# Out:
# 5/5 [==============================] - 0s 9ms/step
#    Actual Close Prices  Predicted Close Prices
# 0           180.570007              177.742722
# 1           180.960007              179.778931
# 2           183.789993              180.627548
# 3           183.309998              182.899109
# 4           183.949997              182.959656
