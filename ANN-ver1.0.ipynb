# %%
# !pip install --upgrade mplfinance
# Out:
# Requirement already satisfied: mplfinance in /usr/local/lib/python3.10/dist-packages (0.12.10b0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mplfinance) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mplfinance) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mplfinance) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)

# %%
import numpy as np
import pandas as pd
import math
import random
import datetime as dt
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
from mplfinance.original_flavor import candlestick_ohlc
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import metrics
from sklearn.metrics import mean_squared_error
import yfinance as yf

# %%
# Downloading stock data for Apple (AAPL) from Yahoo Finance
stock_data = yf.download('AAPL', start='2020-01-01', end='2024-01-01')
specific_df = pd.DataFrame(stock_data).reset_index()
specific_df['Name'] = 'AAPL'
print(specific_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2020-01-02  74.059998  75.150002  73.797501  75.087502  73.152649
# 1 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.441460
# 2 2020-01-06  73.447502  74.989998  73.187500  74.949997  73.018684
# 3 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.675285
# 4 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.844360
#
#       Volume  Name
# 0  135480400  AAPL
# 1  146322800  AAPL
# 2  118387200  AAPL
# 3  108872000  AAPL
# 4  132079200  AAPL

# %%
matplotlib_date = mdates.date2num(specific_df['Date'])
ohlc = np.vstack((matplotlib_date, specific_df['Open'], specific_df['High'], specific_df['Low'], specific_df['Close'])).T
plt.figure(figsize=(15,6))
ax=plt.subplot()
candlestick_ohlc(ax, ohlc, width=0.6, colorup='g', colordown='r')
ax.xaxis_date()
plt.title('Candlestick Chart')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
specific_df.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2020-01-02  74.059998  75.150002  73.797501  75.087502  73.152649
# 1 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.441460
# 2 2020-01-06  73.447502  74.989998  73.187500  74.949997  73.018684
# 3 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.675285
# 4 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.844360
#
#       Volume  Name
# 0  135480400  AAPL
# 1  146322800  AAPL
# 2  118387200  AAPL
# 3  108872000  AAPL
# 4  132079200  AAPL

# %%
new_df = specific_df.reset_index()['Close']
scaler=MinMaxScaler()
scaled_data = scaler.fit_transform(np.array(new_df).reshape(-1,1))

# %%
from sklearn.model_selection import train_test_split
test_size = 0.2
train_data, test_data = train_test_split(scaled_data, test_size=test_size, shuffle=False)

# %%
def generate_sequences_and_labels(data, n_past):
    sequences = [data[i - n_past:i, 0] for i in range(n_past, len(data))]
    labels = [data[i, 0] for i in range(n_past, len(data))]
    return np.array(sequences), np.array(labels)

# %%
n_past = 60
x_train, y_train = generate_sequences_and_labels(train_data, n_past)
x_test, y_test = generate_sequences_and_labels(test_data, n_past)

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1],1)

# %%
def build_lstm_model(input_shape):
  model = Sequential()
  model.add(Dense(512, input_dim=x_train.shape[1]))
  # model.add(Dropout(0.2))
  model.add(Dense(256))
  # model.add(Dropout(0.2))
  model.add(Dense(128))
  # model.add(Dropout(0.2))
  model.add(Dense(64))
  model.add(Dropout(0.2))
  model.add(Dense(1))
  return model

# %%
def compile_lstm_model(model):
  model.compile(loss='mean_squared_error', optimizer='adam', metrics='mean_absolute_error')

# %%
def train_lstm_model(model, x_train, y_train, x_test, y_test):
  model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=200, batch_size=32, verbose=1)

# %%
model = build_lstm_model(x_train.shape[1])
compile_lstm_model(model)
train_lstm_model(model, x_train, y_train, x_test, y_test)
# Out:
# Epoch 1/200
# 24/24 [==============================] - 2s 12ms/step - loss: 1.5130 - mean_absolute_error: 0.8664 - val_loss: 0.0043 - val_mean_absolute_error: 0.0497
# Epoch 2/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0464 - mean_absolute_error: 0.1663 - val_loss: 0.0024 - val_mean_absolute_error: 0.0432
# Epoch 3/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0088 - mean_absolute_error: 0.0729 - val_loss: 0.0024 - val_mean_absolute_error: 0.0443
# Epoch 4/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0048 - mean_absolute_error: 0.0550 - val_loss: 0.0020 - val_mean_absolute_error: 0.0401
# Epoch 5/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_absolute_error: 0.0498 - val_loss: 0.0028 - val_mean_absolute_error: 0.0457
# Epoch 6/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0043 - mean_absolute_error: 0.0511 - val_loss: 0.0032 - val_mean_absolute_error: 0.0490
# Epoch 7/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_absolute_error: 0.0494 - val_loss: 0.0026 - val_mean_absolute_error: 0.0442
# Epoch 8/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0034 - mean_absolute_error: 0.0460 - val_loss: 0.0021 - val_mean_absolute_error: 0.0389
# Epoch 9/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0035 - mean_absolute_error: 0.0464 - val_loss: 9.9705e-04 - val_mean_absolute_error: 0.0266
# Epoch 10/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_absolute_error: 0.0511 - val_loss: 0.0027 - val_mean_absolute_error: 0.0454
# Epoch 11/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0039 - mean_absolute_error: 0.0484 - val_loss: 0.0010 - val_mean_absolute_error: 0.0274
# Epoch 12/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0040 - mean_absolute_error: 0.0491 - val_loss: 0.0024 - val_mean_absolute_error: 0.0427
# Epoch 13/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0033 - mean_absolute_error: 0.0442 - val_loss: 8.5425e-04 - val_mean_absolute_error: 0.0232
# Epoch 14/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0427 - val_loss: 0.0024 - val_mean_absolute_error: 0.0428
# Epoch 15/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0034 - mean_absolute_error: 0.0456 - val_loss: 7.5463e-04 - val_mean_absolute_error: 0.0223
# Epoch 16/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0028 - mean_absolute_error: 0.0418 - val_loss: 0.0010 - val_mean_absolute_error: 0.0273
# Epoch 17/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0033 - mean_absolute_error: 0.0432 - val_loss: 0.0013 - val_mean_absolute_error: 0.0311
# Epoch 18/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0033 - mean_absolute_error: 0.0435 - val_loss: 0.0012 - val_mean_absolute_error: 0.0299
# Epoch 19/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0030 - mean_absolute_error: 0.0419 - val_loss: 0.0011 - val_mean_absolute_error: 0.0280
# Epoch 20/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0421 - val_loss: 7.1016e-04 - val_mean_absolute_error: 0.0218
# Epoch 21/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0034 - mean_absolute_error: 0.0453 - val_loss: 0.0023 - val_mean_absolute_error: 0.0405
# Epoch 22/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0033 - mean_absolute_error: 0.0434 - val_loss: 6.5387e-04 - val_mean_absolute_error: 0.0203
# Epoch 23/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0420 - val_loss: 0.0011 - val_mean_absolute_error: 0.0285
# Epoch 24/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0414 - val_loss: 0.0010 - val_mean_absolute_error: 0.0275
# Epoch 25/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0420 - val_loss: 0.0014 - val_mean_absolute_error: 0.0327
# Epoch 26/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0379 - val_loss: 6.9101e-04 - val_mean_absolute_error: 0.0216
# Epoch 27/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0425 - val_loss: 0.0012 - val_mean_absolute_error: 0.0294
# Epoch 28/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0034 - mean_absolute_error: 0.0438 - val_loss: 7.7419e-04 - val_mean_absolute_error: 0.0210
# Epoch 29/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0030 - mean_absolute_error: 0.0426 - val_loss: 8.2107e-04 - val_mean_absolute_error: 0.0237
# Epoch 30/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0028 - mean_absolute_error: 0.0419 - val_loss: 0.0019 - val_mean_absolute_error: 0.0389
# Epoch 31/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0443 - val_loss: 5.6366e-04 - val_mean_absolute_error: 0.0190
# Epoch 32/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0034 - mean_absolute_error: 0.0447 - val_loss: 0.0018 - val_mean_absolute_error: 0.0387
# Epoch 33/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0412 - val_loss: 0.0031 - val_mean_absolute_error: 0.0523
# Epoch 34/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0031 - mean_absolute_error: 0.0413 - val_loss: 0.0015 - val_mean_absolute_error: 0.0324
# Epoch 35/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0031 - mean_absolute_error: 0.0426 - val_loss: 0.0024 - val_mean_absolute_error: 0.0450
# Epoch 36/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0037 - mean_absolute_error: 0.0465 - val_loss: 4.8553e-04 - val_mean_absolute_error: 0.0171
# Epoch 37/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0030 - mean_absolute_error: 0.0424 - val_loss: 6.6407e-04 - val_mean_absolute_error: 0.0193
# Epoch 38/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0028 - mean_absolute_error: 0.0398 - val_loss: 0.0017 - val_mean_absolute_error: 0.0350
# Epoch 39/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0034 - mean_absolute_error: 0.0439 - val_loss: 0.0019 - val_mean_absolute_error: 0.0392
# Epoch 40/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0025 - mean_absolute_error: 0.0382 - val_loss: 5.1739e-04 - val_mean_absolute_error: 0.0173
# Epoch 41/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0031 - mean_absolute_error: 0.0433 - val_loss: 6.2037e-04 - val_mean_absolute_error: 0.0203
# Epoch 42/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0409 - val_loss: 4.8148e-04 - val_mean_absolute_error: 0.0169
# Epoch 43/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0382 - val_loss: 4.5803e-04 - val_mean_absolute_error: 0.0168
# Epoch 44/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0033 - mean_absolute_error: 0.0442 - val_loss: 0.0024 - val_mean_absolute_error: 0.0460
# Epoch 45/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0031 - mean_absolute_error: 0.0433 - val_loss: 5.6495e-04 - val_mean_absolute_error: 0.0194
# Epoch 46/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0414 - val_loss: 9.0858e-04 - val_mean_absolute_error: 0.0260
# Epoch 47/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0031 - mean_absolute_error: 0.0428 - val_loss: 4.4097e-04 - val_mean_absolute_error: 0.0163
# Epoch 48/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0027 - mean_absolute_error: 0.0396 - val_loss: 0.0011 - val_mean_absolute_error: 0.0277
# Epoch 49/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0032 - mean_absolute_error: 0.0439 - val_loss: 0.0014 - val_mean_absolute_error: 0.0328
# Epoch 50/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0415 - val_loss: 4.5231e-04 - val_mean_absolute_error: 0.0169
# Epoch 51/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0376 - val_loss: 4.6176e-04 - val_mean_absolute_error: 0.0164
# Epoch 52/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0420 - val_loss: 0.0020 - val_mean_absolute_error: 0.0418
# Epoch 53/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0441 - val_loss: 0.0013 - val_mean_absolute_error: 0.0302
# Epoch 54/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0034 - mean_absolute_error: 0.0449 - val_loss: 4.6739e-04 - val_mean_absolute_error: 0.0164
# Epoch 55/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0398 - val_loss: 5.7960e-04 - val_mean_absolute_error: 0.0197
# Epoch 56/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0033 - mean_absolute_error: 0.0435 - val_loss: 0.0031 - val_mean_absolute_error: 0.0514
# Epoch 57/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0033 - mean_absolute_error: 0.0442 - val_loss: 5.2100e-04 - val_mean_absolute_error: 0.0182
# Epoch 58/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0032 - mean_absolute_error: 0.0434 - val_loss: 0.0015 - val_mean_absolute_error: 0.0349
# Epoch 59/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0035 - mean_absolute_error: 0.0456 - val_loss: 0.0011 - val_mean_absolute_error: 0.0281
# Epoch 60/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0416 - val_loss: 5.6230e-04 - val_mean_absolute_error: 0.0179
# Epoch 61/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0028 - mean_absolute_error: 0.0401 - val_loss: 6.1578e-04 - val_mean_absolute_error: 0.0207
# Epoch 62/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0028 - mean_absolute_error: 0.0413 - val_loss: 0.0024 - val_mean_absolute_error: 0.0456
# Epoch 63/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0030 - mean_absolute_error: 0.0420 - val_loss: 6.1040e-04 - val_mean_absolute_error: 0.0203
# Epoch 64/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0026 - mean_absolute_error: 0.0386 - val_loss: 4.0344e-04 - val_mean_absolute_error: 0.0158
# Epoch 65/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0034 - mean_absolute_error: 0.0451 - val_loss: 0.0014 - val_mean_absolute_error: 0.0346
# Epoch 66/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0034 - mean_absolute_error: 0.0450 - val_loss: 0.0011 - val_mean_absolute_error: 0.0268
# Epoch 67/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0027 - mean_absolute_error: 0.0394 - val_loss: 4.1140e-04 - val_mean_absolute_error: 0.0161
# Epoch 68/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0028 - mean_absolute_error: 0.0404 - val_loss: 0.0025 - val_mean_absolute_error: 0.0466
# Epoch 69/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0026 - mean_absolute_error: 0.0396 - val_loss: 9.1219e-04 - val_mean_absolute_error: 0.0243
# Epoch 70/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0033 - mean_absolute_error: 0.0439 - val_loss: 0.0015 - val_mean_absolute_error: 0.0333
# Epoch 71/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0029 - mean_absolute_error: 0.0427 - val_loss: 0.0011 - val_mean_absolute_error: 0.0295
# Epoch 72/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0030 - mean_absolute_error: 0.0422 - val_loss: 0.0038 - val_mean_absolute_error: 0.0585
# Epoch 73/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0033 - mean_absolute_error: 0.0433 - val_loss: 3.9588e-04 - val_mean_absolute_error: 0.0157
# Epoch 74/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0025 - mean_absolute_error: 0.0395 - val_loss: 5.8059e-04 - val_mean_absolute_error: 0.0183
# Epoch 75/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0433 - val_loss: 4.1509e-04 - val_mean_absolute_error: 0.0157
# Epoch 76/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0028 - mean_absolute_error: 0.0409 - val_loss: 7.1270e-04 - val_mean_absolute_error: 0.0207
# Epoch 77/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0427 - val_loss: 0.0031 - val_mean_absolute_error: 0.0532
# Epoch 78/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0410 - val_loss: 0.0023 - val_mean_absolute_error: 0.0446
# Epoch 79/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0033 - mean_absolute_error: 0.0442 - val_loss: 0.0018 - val_mean_absolute_error: 0.0395
# Epoch 80/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0037 - mean_absolute_error: 0.0469 - val_loss: 5.1897e-04 - val_mean_absolute_error: 0.0186
# Epoch 81/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0031 - mean_absolute_error: 0.0423 - val_loss: 4.5734e-04 - val_mean_absolute_error: 0.0163
# Epoch 82/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0422 - val_loss: 6.0734e-04 - val_mean_absolute_error: 0.0189
# Epoch 83/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0030 - mean_absolute_error: 0.0434 - val_loss: 7.9870e-04 - val_mean_absolute_error: 0.0244
# Epoch 84/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0027 - mean_absolute_error: 0.0394 - val_loss: 3.5342e-04 - val_mean_absolute_error: 0.0144
# Epoch 85/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0027 - mean_absolute_error: 0.0395 - val_loss: 0.0028 - val_mean_absolute_error: 0.0493
# Epoch 86/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0031 - mean_absolute_error: 0.0428 - val_loss: 3.5980e-04 - val_mean_absolute_error: 0.0146
# Epoch 87/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0029 - mean_absolute_error: 0.0410 - val_loss: 3.9250e-04 - val_mean_absolute_error: 0.0151
# Epoch 88/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0427 - val_loss: 9.4597e-04 - val_mean_absolute_error: 0.0267
# Epoch 89/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0025 - mean_absolute_error: 0.0386 - val_loss: 7.5879e-04 - val_mean_absolute_error: 0.0235
# Epoch 90/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0037 - mean_absolute_error: 0.0464 - val_loss: 0.0042 - val_mean_absolute_error: 0.0619
# Epoch 91/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0033 - mean_absolute_error: 0.0445 - val_loss: 0.0012 - val_mean_absolute_error: 0.0303
# Epoch 92/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0379 - val_loss: 0.0013 - val_mean_absolute_error: 0.0326
# Epoch 93/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0025 - mean_absolute_error: 0.0383 - val_loss: 4.0380e-04 - val_mean_absolute_error: 0.0159
# Epoch 94/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0427 - val_loss: 6.6709e-04 - val_mean_absolute_error: 0.0219
# Epoch 95/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0393 - val_loss: 0.0012 - val_mean_absolute_error: 0.0308
# Epoch 96/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0391 - val_loss: 0.0010 - val_mean_absolute_error: 0.0263
# Epoch 97/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0387 - val_loss: 0.0012 - val_mean_absolute_error: 0.0313
# Epoch 98/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0376 - val_loss: 4.9483e-04 - val_mean_absolute_error: 0.0180
# Epoch 99/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0377 - val_loss: 0.0057 - val_mean_absolute_error: 0.0735
# Epoch 100/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0442 - val_loss: 0.0020 - val_mean_absolute_error: 0.0420
# Epoch 101/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0373 - val_loss: 7.4173e-04 - val_mean_absolute_error: 0.0212
# Epoch 102/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0399 - val_loss: 3.9576e-04 - val_mean_absolute_error: 0.0147
# Epoch 103/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0422 - val_loss: 0.0015 - val_mean_absolute_error: 0.0351
# Epoch 104/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0417 - val_loss: 0.0013 - val_mean_absolute_error: 0.0324
# Epoch 105/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0419 - val_loss: 0.0036 - val_mean_absolute_error: 0.0573
# Epoch 106/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0027 - mean_absolute_error: 0.0395 - val_loss: 5.7865e-04 - val_mean_absolute_error: 0.0195
# Epoch 107/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0028 - mean_absolute_error: 0.0402 - val_loss: 0.0019 - val_mean_absolute_error: 0.0385
# Epoch 108/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0373 - val_loss: 6.0889e-04 - val_mean_absolute_error: 0.0206
# Epoch 109/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0419 - val_loss: 4.4422e-04 - val_mean_absolute_error: 0.0158
# Epoch 110/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0043 - mean_absolute_error: 0.0504 - val_loss: 0.0013 - val_mean_absolute_error: 0.0320
# Epoch 111/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0412 - val_loss: 0.0024 - val_mean_absolute_error: 0.0451
# Epoch 112/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0415 - val_loss: 4.5417e-04 - val_mean_absolute_error: 0.0162
# Epoch 113/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0028 - mean_absolute_error: 0.0403 - val_loss: 5.3696e-04 - val_mean_absolute_error: 0.0191
# Epoch 114/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0034 - mean_absolute_error: 0.0450 - val_loss: 6.3990e-04 - val_mean_absolute_error: 0.0212
# Epoch 115/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0417 - val_loss: 4.0910e-04 - val_mean_absolute_error: 0.0159
# Epoch 116/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0031 - mean_absolute_error: 0.0429 - val_loss: 0.0010 - val_mean_absolute_error: 0.0281
# Epoch 117/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0392 - val_loss: 3.5688e-04 - val_mean_absolute_error: 0.0145
# Epoch 118/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0037 - mean_absolute_error: 0.0458 - val_loss: 0.0041 - val_mean_absolute_error: 0.0610
# Epoch 119/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0424 - val_loss: 3.5320e-04 - val_mean_absolute_error: 0.0147
# Epoch 120/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0424 - val_loss: 0.0024 - val_mean_absolute_error: 0.0459
# Epoch 121/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0403 - val_loss: 0.0037 - val_mean_absolute_error: 0.0580
# Epoch 122/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0373 - val_loss: 0.0017 - val_mean_absolute_error: 0.0380
# Epoch 123/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0385 - val_loss: 5.6591e-04 - val_mean_absolute_error: 0.0196
# Epoch 124/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0386 - val_loss: 0.0048 - val_mean_absolute_error: 0.0664
# Epoch 125/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0037 - mean_absolute_error: 0.0469 - val_loss: 0.0084 - val_mean_absolute_error: 0.0900
# Epoch 126/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0033 - mean_absolute_error: 0.0437 - val_loss: 4.5393e-04 - val_mean_absolute_error: 0.0162
# Epoch 127/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0434 - val_loss: 4.6180e-04 - val_mean_absolute_error: 0.0160
# Epoch 128/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0372 - val_loss: 4.0453e-04 - val_mean_absolute_error: 0.0158
# Epoch 129/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0028 - mean_absolute_error: 0.0404 - val_loss: 4.8127e-04 - val_mean_absolute_error: 0.0180
# Epoch 130/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0385 - val_loss: 0.0013 - val_mean_absolute_error: 0.0300
# Epoch 131/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0435 - val_loss: 0.0020 - val_mean_absolute_error: 0.0409
# Epoch 132/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0418 - val_loss: 3.9265e-04 - val_mean_absolute_error: 0.0151
# Epoch 133/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0025 - mean_absolute_error: 0.0390 - val_loss: 0.0028 - val_mean_absolute_error: 0.0497
# Epoch 134/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0027 - mean_absolute_error: 0.0404 - val_loss: 0.0033 - val_mean_absolute_error: 0.0550
# Epoch 135/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0037 - mean_absolute_error: 0.0453 - val_loss: 4.2191e-04 - val_mean_absolute_error: 0.0162
# Epoch 136/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0418 - val_loss: 5.1586e-04 - val_mean_absolute_error: 0.0170
# Epoch 137/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0033 - mean_absolute_error: 0.0437 - val_loss: 0.0015 - val_mean_absolute_error: 0.0354
# Epoch 138/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0027 - mean_absolute_error: 0.0393 - val_loss: 7.0018e-04 - val_mean_absolute_error: 0.0227
# Epoch 139/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0360 - val_loss: 3.7965e-04 - val_mean_absolute_error: 0.0153
# Epoch 140/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0370 - val_loss: 7.7497e-04 - val_mean_absolute_error: 0.0226
# Epoch 141/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0377 - val_loss: 4.1214e-04 - val_mean_absolute_error: 0.0160
# Epoch 142/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0391 - val_loss: 0.0016 - val_mean_absolute_error: 0.0347
# Epoch 143/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0029 - mean_absolute_error: 0.0418 - val_loss: 0.0034 - val_mean_absolute_error: 0.0552
# Epoch 144/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0034 - mean_absolute_error: 0.0441 - val_loss: 7.5984e-04 - val_mean_absolute_error: 0.0235
# Epoch 145/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0023 - mean_absolute_error: 0.0372 - val_loss: 7.6477e-04 - val_mean_absolute_error: 0.0237
# Epoch 146/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0022 - mean_absolute_error: 0.0366 - val_loss: 0.0011 - val_mean_absolute_error: 0.0294
# Epoch 147/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0023 - mean_absolute_error: 0.0370 - val_loss: 0.0013 - val_mean_absolute_error: 0.0331
# Epoch 148/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0024 - mean_absolute_error: 0.0374 - val_loss: 0.0015 - val_mean_absolute_error: 0.0346
# Epoch 149/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0027 - mean_absolute_error: 0.0398 - val_loss: 4.1389e-04 - val_mean_absolute_error: 0.0152
# Epoch 150/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0021 - mean_absolute_error: 0.0358 - val_loss: 5.2300e-04 - val_mean_absolute_error: 0.0171
# Epoch 151/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0022 - mean_absolute_error: 0.0356 - val_loss: 0.0035 - val_mean_absolute_error: 0.0568
# Epoch 152/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0024 - mean_absolute_error: 0.0383 - val_loss: 4.2664e-04 - val_mean_absolute_error: 0.0154
# Epoch 153/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0026 - mean_absolute_error: 0.0397 - val_loss: 3.8550e-04 - val_mean_absolute_error: 0.0157
# Epoch 154/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0025 - mean_absolute_error: 0.0381 - val_loss: 0.0015 - val_mean_absolute_error: 0.0355
# Epoch 155/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0025 - mean_absolute_error: 0.0371 - val_loss: 0.0044 - val_mean_absolute_error: 0.0637
# Epoch 156/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0025 - mean_absolute_error: 0.0376 - val_loss: 3.8890e-04 - val_mean_absolute_error: 0.0146
# Epoch 157/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0371 - val_loss: 0.0018 - val_mean_absolute_error: 0.0388
# Epoch 158/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0365 - val_loss: 0.0014 - val_mean_absolute_error: 0.0336
# Epoch 159/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0368 - val_loss: 5.8436e-04 - val_mean_absolute_error: 0.0203
# Epoch 160/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0347 - val_loss: 6.5430e-04 - val_mean_absolute_error: 0.0199
# Epoch 161/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0023 - mean_absolute_error: 0.0363 - val_loss: 0.0032 - val_mean_absolute_error: 0.0540
# Epoch 162/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0025 - mean_absolute_error: 0.0380 - val_loss: 3.5386e-04 - val_mean_absolute_error: 0.0149
# Epoch 163/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0432 - val_loss: 0.0041 - val_mean_absolute_error: 0.0608
# Epoch 164/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0034 - mean_absolute_error: 0.0456 - val_loss: 0.0014 - val_mean_absolute_error: 0.0332
# Epoch 165/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0376 - val_loss: 5.0594e-04 - val_mean_absolute_error: 0.0184
# Epoch 166/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0383 - val_loss: 0.0048 - val_mean_absolute_error: 0.0668
# Epoch 167/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0027 - mean_absolute_error: 0.0404 - val_loss: 5.9012e-04 - val_mean_absolute_error: 0.0198
# Epoch 168/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0027 - mean_absolute_error: 0.0391 - val_loss: 0.0018 - val_mean_absolute_error: 0.0375
# Epoch 169/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0381 - val_loss: 4.3917e-04 - val_mean_absolute_error: 0.0164
# Epoch 170/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0353 - val_loss: 0.0020 - val_mean_absolute_error: 0.0395
# Epoch 171/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0395 - val_loss: 0.0033 - val_mean_absolute_error: 0.0543
# Epoch 172/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0397 - val_loss: 0.0068 - val_mean_absolute_error: 0.0802
# Epoch 173/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0034 - mean_absolute_error: 0.0446 - val_loss: 0.0048 - val_mean_absolute_error: 0.0662
# Epoch 174/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0383 - val_loss: 8.6099e-04 - val_mean_absolute_error: 0.0252
# Epoch 175/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0395 - val_loss: 3.9012e-04 - val_mean_absolute_error: 0.0151
# Epoch 176/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0371 - val_loss: 0.0017 - val_mean_absolute_error: 0.0358
# Epoch 177/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0393 - val_loss: 4.1439e-04 - val_mean_absolute_error: 0.0156
# Epoch 178/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0020 - mean_absolute_error: 0.0339 - val_loss: 0.0016 - val_mean_absolute_error: 0.0373
# Epoch 179/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0383 - val_loss: 5.7587e-04 - val_mean_absolute_error: 0.0185
# Epoch 180/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0329 - val_loss: 6.4744e-04 - val_mean_absolute_error: 0.0213
# Epoch 181/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0347 - val_loss: 7.0865e-04 - val_mean_absolute_error: 0.0226
# Epoch 182/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0377 - val_loss: 6.6936e-04 - val_mean_absolute_error: 0.0198
# Epoch 183/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0425 - val_loss: 0.0017 - val_mean_absolute_error: 0.0362
# Epoch 184/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0386 - val_loss: 3.9269e-04 - val_mean_absolute_error: 0.0155
# Epoch 185/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0356 - val_loss: 3.7249e-04 - val_mean_absolute_error: 0.0148
# Epoch 186/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0330 - val_loss: 6.6589e-04 - val_mean_absolute_error: 0.0219
# Epoch 187/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0365 - val_loss: 3.4460e-04 - val_mean_absolute_error: 0.0144
# Epoch 188/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0019 - mean_absolute_error: 0.0335 - val_loss: 3.4748e-04 - val_mean_absolute_error: 0.0144
# Epoch 189/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0327 - val_loss: 3.3684e-04 - val_mean_absolute_error: 0.0140
# Epoch 190/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0330 - val_loss: 7.2396e-04 - val_mean_absolute_error: 0.0233
# Epoch 191/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0339 - val_loss: 0.0013 - val_mean_absolute_error: 0.0308
# Epoch 192/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0034 - mean_absolute_error: 0.0445 - val_loss: 0.0085 - val_mean_absolute_error: 0.0906
# Epoch 193/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0034 - mean_absolute_error: 0.0454 - val_loss: 0.0017 - val_mean_absolute_error: 0.0348
# Epoch 194/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0348 - val_loss: 4.2578e-04 - val_mean_absolute_error: 0.0164
# Epoch 195/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0340 - val_loss: 0.0016 - val_mean_absolute_error: 0.0367
# Epoch 196/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0347 - val_loss: 0.0021 - val_mean_absolute_error: 0.0425
# Epoch 197/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0018 - mean_absolute_error: 0.0323 - val_loss: 4.2607e-04 - val_mean_absolute_error: 0.0166
# Epoch 198/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0022 - mean_absolute_error: 0.0353 - val_loss: 0.0024 - val_mean_absolute_error: 0.0459
# Epoch 199/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0392 - val_loss: 4.3076e-04 - val_mean_absolute_error: 0.0168
# Epoch 200/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0321 - val_loss: 7.6219e-04 - val_mean_absolute_error: 0.0235

# %%
def make_predictions(model, x_train, x_test):
    train_predict = model.predict(x_train)
    test_predict = model.predict(x_test)
    return train_predict, test_predict

# %%
train_predict, test_predict = make_predictions(model, x_train, x_test)
# Out:
# 24/24 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step

# %%
def inverse_transform(scaler, y_train, train_predict, y_test, test_predict):
    train_predict = scaler.inverse_transform(train_predict)
    test_predict = scaler.inverse_transform(test_predict)
    return train_predict, test_predict

# %%
train_predict, test_predict = inverse_transform(scaler, y_train, train_predict, y_test, test_predict)

# %%
def evaluate_model(y_train, train_predict, y_test, test_predict):
    train_rmse = math.sqrt(mean_squared_error(y_train, train_predict))
    test_rmse = math.sqrt(mean_squared_error(y_test, test_predict))
    print(f"Training RMSE: {train_rmse}")
    print(f"Testing RMSE: {test_rmse}")

# %%
evaluate_model(y_train, train_predict, y_test, test_predict)
# Out:
# Training RMSE: 136.22782424724366
# Testing RMSE: 180.54394051359444

# %%
def plot_predictions(original_data, train_predict, test_predict, company_name):
    look_back = 60
    train_predict_plot = np.empty_like(original_data)
    train_predict_plot[:] = np.nan
    train_predict_plot[look_back : len(train_predict) + look_back] = train_predict.flatten()

    test_predict_plot = np.empty_like(original_data)
    test_predict_plot[:] = np.nan
    test_start = len(original_data) - len(test_predict)
    test_predict_plot[test_start:] = test_predict.flatten()

    plt.figure(figsize=(15, 6))
    plt.plot(original_data, color='black', label=f"Actual {company_name} price")
    plt.plot(train_predict_plot, color='red', label=f'Predicted {company_name} price (train_set)')
    plt.plot(test_predict_plot, color='blue', label=f"Predicted {company_name} price (test_set)")
    plt.title(f"{company_name} share price")
    plt.xlabel("Time")
    plt.ylabel(f"{company_name} share price")
    plt.legend()
    plt.show()

# %%
plot_predictions(new_df, train_predict, test_predict, company_name)

# %%
predictions = model.predict(x_test)

actual_values_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))
predicted_values_inverse = scaler.inverse_transform(predictions)

comparison_df = pd.DataFrame({'Actual Close Prices': actual_values_inverse.flatten(), 'Predicted Close Prices': predicted_values_inverse.flatten()})
print(comparison_df.head())

plt.figure(figsize=(10, 5))
plt.plot(actual_values_inverse.flatten(), marker='.', label="Actual Close Prices")
plt.plot(predicted_values_inverse.flatten(), 'r', label="Predicted Close Prices")
plt.ylabel('Close Price')
plt.xlabel('Time Step')
plt.legend()
plt.title('Comparison of Actual vs Predicted Close Prices')
plt.show()
# Out:
# 5/5 [==============================] - 0s 2ms/step
#    Actual Close Prices  Predicted Close Prices
# 0           180.570007              175.902283
# 1           180.960007              176.680679
# 2           183.789993              177.500320
# 3           183.309998              178.802811
# 4           183.949997              179.886246
